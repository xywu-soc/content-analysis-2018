# %% [markdown]
# # Week 2 - Corpus Linguistics
#
# This week, we take text corpora that we have developed, spidered, scraped, and encoded, and we find and count words and simple phrases and properties of those counts (e.g., word frequency distributions). Initially, we model how to search corpora for keywords or phrases. Next, we examine the distributions of terms and phrases across a corpus, and the corelation between different words and phrase counts. In order to do this effectively, we coarsely disambiguate words based of part-of-speech (POS) tagging, and normalize them through stemming and lemmatization. Next we distinguish *important* words and phrase within the corpus, and image them with Wordls! Then we calculate word frequenceis, conditional frequences (the frequency of word *shock* conditional on the presence of word *awe*), and statistically significant collocations of lengths 2 through $n$. Finally, we calculate and visualize Differences (Divergences and Distances) between the word frequency distributions from two corpora.
#
# For this notebook we will be using the following packages

# %%
#Special module written for this class
#This provides access to data and to helper functions from previous weeks
import lucem_illud #pip install git+git://github.com/Computational-Content-Analysis-2018/lucem_illud.git

#All these packages need to be installed from pip
import requests #for http requests
import nltk #the Natural Language Toolkit
import pandas #gives us DataFrames
import matplotlib.pyplot as plt #For graphics
import wordcloud #Makes word clouds
import numpy as np #For divergences/distances
import scipy #For divergences/distances
import seaborn as sns #makes our plots look nicer
import sklearn.manifold #For a manifold plot
from nltk.corpus import stopwords #For stopwords
import json #For API responses
import urllib.parse #For joining urls

#This 'magic' command makes the plots work better
#in the notebook, don't use it outside of a notebook
# %matplotlib inline

# %% [markdown]
# # Retrieving exemplary corpora
#
# To get started we will need some examples. Let's start by downloading one of the corpuses from `nltk`, a Natural Language Toolkit developed by computational linguists at the University of Pennsylvania. Let's take a look at how that works.
#
# First we can get a list of works available from the Gutenburg corpus, with the [corpus module](http://www.nltk.org/api/nltk.corpus.html). To do this we will need to tell nltk where the data are, and download them if need be.

# %%
#You should have them already downloaded in the data directory
try:
    #adding path for both local and server, only one of these will actually be used at a time
    nltk.data.path.append('/project2/macs60000/shared_data/nltk')
    nltk.data.path.append('../data')
    #Check that everything is in place
    nltk.corpus.gutenberg.fileids()
except LookupError:
    print("You have to download all the documents")
    print("Downloading to ../data this should only take a couple minutes")
    nltk.download('all', download_dir = '../data')
    nltk.data.path.append('../data')
#If you haven't downloaded the copura then you will have to run `nltk.download()`
print(nltk.corpus.gutenberg.fileids())
print(len(nltk.corpus.gutenberg.fileids()))
# Out:
# ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']
# 18

# %% [markdown]
# We can also look at the individual works

# %%
nltk.corpus.gutenberg.raw('shakespeare-macbeth.txt')[2000:4000]
# Out:
# "es,\nBut the Norweyan Lord, surueying vantage,\nWith furbusht Armes, and new supplyes of men,\nBegan a fresh assault\n\n   King. Dismay'd not this our Captaines, Macbeth and\nBanquoh?\n  Cap. Yes, as Sparrowes, Eagles;\nOr the Hare, the Lyon:\nIf I say sooth, I must report they were\nAs Cannons ouer-charg'd with double Cracks,\nSo they doubly redoubled stroakes vpon the Foe:\nExcept they meant to bathe in reeking Wounds,\nOr memorize another Golgotha,\nI cannot tell: but I am faint,\nMy Gashes cry for helpe\n\n   King. So well thy words become thee, as thy wounds,\nThey smack of Honor both: Goe get him Surgeons.\nEnter Rosse and Angus.\n\nWho comes here?\n  Mal. The worthy Thane of Rosse\n\n   Lenox. What a haste lookes through his eyes?\nSo should he looke, that seemes to speake things strange\n\n   Rosse. God saue the King\n\n   King. Whence cam'st thou, worthy Thane?\n  Rosse. From Fiffe, great King,\nWhere the Norweyan Banners flowt the Skie,\nAnd fanne our people cold.\nNorway himselfe, with terrible numbers,\nAssisted by that most disloyall Traytor,\nThe Thane of Cawdor, began a dismall Conflict,\nTill that Bellona's Bridegroome, lapt in proofe,\nConfronted him with selfe-comparisons,\nPoint against Point, rebellious Arme 'gainst Arme,\nCurbing his lauish spirit: and to conclude,\nThe Victorie fell on vs\n\n   King. Great happinesse\n\n   Rosse. That now Sweno, the Norwayes King,\nCraues composition:\nNor would we deigne him buriall of his men,\nTill he disbursed, at Saint Colmes ynch,\nTen thousand Dollars, to our generall vse\n\n   King. No more that Thane of Cawdor shall deceiue\nOur Bosome interest: Goe pronounce his present death,\nAnd with his former Title greet Macbeth\n\n   Rosse. Ile see it done\n\n   King. What he hath lost, Noble Macbeth hath wonne.\n\nExeunt.\n\n\nScena Tertia.\n\nThunder. Enter the three Witches.\n\n  1. Where hast thou beene, Sister?\n  2. Killing Swine\n\n   3. Sister, where thou?\n  1. A Saylors Wife had Chestnuts in her Lappe,\nAnd mouncht, & mouncht, and mouncht:\nGiue me, quoth I.\nAroynt thee, "

# %% [markdown]
# All the listed works have been nicely marked up and classified for us so we can do much better than just looking at raw text.

# %%
print(nltk.corpus.gutenberg.words('shakespeare-macbeth.txt'))
print(nltk.corpus.gutenberg.sents('shakespeare-macbeth.txt'))
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Macbeth', 'by', ...]
# [['[', 'The', 'Tragedie', 'of', 'Macbeth', 'by', 'William', 'Shakespeare', '1603', ']'], ['Actus', 'Primus', '.'], ...]

# %% [markdown]
# # Counting words
#
# If we want to do some analysis we can start by simply counting the number of times each word occurs within the corpus.

# %%
def wordCounter(wordLst):
    wordCounts = {}
    for word in wordLst:
        #We usually need to normalize the case
        wLower = word.lower()
        if wLower in wordCounts:
            wordCounts[wLower] += 1
        else:
            wordCounts[wLower] = 1
    #convert to DataFrame
    countsForFrame = {'word' : [], 'count' : []}
    for w, c in wordCounts.items():
        countsForFrame['word'].append(w)
        countsForFrame['count'].append(c)
    return pandas.DataFrame(countsForFrame)

countedWords = wordCounter(nltk.corpus.gutenberg.words('shakespeare-macbeth.txt'))
countedWords[:10]
# Out:
#    count         word
# 0      4            [
# 1    650          the
# 2      2     tragedie
# 3    338           of
# 4     62      macbeth
# 5     49           by
# 6      1      william
# 7      1  shakespeare
# 8      1         1603
# 9      4            ]

# %% [markdown]
# Notice how `wordCounter()` is not a very complicated function. That is because the hard parts have already been done by `nltk`. If we were using unprocessed text we would have to tokenize and determine what to do with the non-word characters.
#
# nltk also offers a built-in way for getting a frequency distribution from a list of words:

# %%
words = [word.lower() for word in nltk.corpus.gutenberg.words('shakespeare-macbeth.txt')]
freq = nltk.FreqDist(words)
print (freq['macbeth'])
# Out:
# 62

# %% [markdown]
# Lets sort and plot our counts to investigate the shape of our word frequency distribution.
#
# First we need to sort the words by count.

# %%
#Doing this in place (changing the original DataFrame) as we don't need the unsorted DataFrame
countedWords.sort_values('count', ascending=False, inplace=True)
countedWords[:100]
# Out:
#      count    word
# 29    1962       ,
# 12    1235       .
# 1      650     the
# 36     637       '
# 16     546     and
# 64     477       :
# 54     384      to
# 56     348       i
# 3      338      of
# 27     241       ?
# 84     241       a
# 43     238    that
# 153    224       d
# 487    206     you
# 110    203      my
# 28     201      in
# 66     188      is
# 242    165     not
# 122    161      it
# 55     153    with
# 95     146     his
# 45     137      be
# 474    137    macb
# 37     131       s
# 501    126    your
# 196    123     our
# 413    122    haue
# 162    120     but
# 87     118    what
# 391    113      me
# ..     ...     ...
# 105     49    good
# 630     49     was
# 5       49      by
# 289     49   rosse
# 880     48    lady
# 478     48       t
# 567     48    them
# 529     46    time
# 250     45      if
# 104     43    like
# 386     43     her
# 297     42  should
# 306     42      st
# 453     42     did
# 735     42     let
# 116     41     say
# 22      40    when
# 473     39  banquo
# 254     39    were
# 49      39   where
# 468     39    make
# 198     38       o
# 230     38    lord
# 129     38     doe
# 665     37     tis
# 30      37      or
# 21      36       1
# 252     36    must
# 489     35     may
# 38      35    done
#
# [100 rows x 2 columns]

# %% [markdown]
# Punctuation and very common words (articles 'a' and 'the'; prepositions 'of' and 'to') make up the most common values, but this isn't very interesting and can actually get in the way of our analysis. We may remove these 'function words' by removing according to a stopword list, setting some frequency threshold, or using a weighting scheme (like tf.idf) to decrease their influence (all modeled later in this tutorial).

# %%
#Creating a figure and axis lets us do things like change the scaling or add a title
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(range(len(countedWords)), countedWords['count'])
plt.show()

# %% [markdown]
# This shows that likelihood of a word occurring is inversely proportional to its rank. This effect is called [Zipf's Law](https://en.wikipedia.org/wiki/Zipf%27s_law), and suggests that the most frequent word will occur approximately twice as often as the second most frequent word, three times as often as the third most frequent word, etc. Zipf's law is most easily observed by plotting the data on a log-log graph, with the axes being log (rank order) and log (frequency) resulting in a linear relationship.

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(range(len(countedWords)), countedWords['count'])
ax.set_yscale('log')
ax.set_xscale('log')
plt.show()

# %% [markdown]
# (The same relationship occurs in many other rankings, such as population ranks of cities, corporation sizes, income rankings, etc.)
#
# The distribution was imagined by Zipf to be driven by a principle of 'least effort' where speakers did not work any harder than necessary to communicate a given idea, but the basis for this relationship is still not well understood and conforms at least as well to a process of [preferential attachment](https://en.wikipedia.org/wiki/Preferential_attachment) whereby people disproportionately attend to popular words.
#
# There are many other properties of words we can examine. First lets look surrounding words with the concordance. To do this we need to load the text into a `ConcordanceIndex`

# %%
macbethIndex = nltk.text.ConcordanceIndex(nltk.corpus.gutenberg.words('shakespeare-macbeth.txt'))

# %% [markdown]
# Then we can retrieve all the words that cooccur with a word in a given word window. Let's first look at `'macbeth'`.

# %%
macbethIndex.print_concordance('macbeth')
# Out:
# No matches

# %% [markdown]
# Weird?! `'macbeth'` doesn't occur anywhere in the the text. What happened?
#
# `ConcordanceIndex` is case sensitive, lets try looking for `'Macbeth'`

# %%
macbethIndex.print_concordance('Macbeth')
# Out:
# Displaying 25 of 61 matches:
#                                   Macbeth by William Shakespeare 1603 ] Act
#  the Heath 3 . There to meet with Macbeth 1 . I come , Gray - Malkin All .
# but all ' s too weake : For braue Macbeth ( well hee deserues that Name ) D
# smay ' d not this our Captaines , Macbeth and Banquoh ? Cap . Yes , as Spar
# , And with his former Title greet Macbeth Rosse . Ile see it done King . Wh
#  King . What he hath lost , Noble Macbeth hath wonne . Exeunt . Scena Terti
# ithin . 3 . A Drumme , a Drumme : Macbeth doth come All . The weyward Siste
# , the Charme ' s wound vp . Enter Macbeth and Banquo . Macb . So foule and
# an : what are you ? 1 . All haile Macbeth , haile to thee Thane of Glamis 2
# hee Thane of Glamis 2 . All haile Macbeth , haile to thee Thane of Cawdor 3
# hee Thane of Cawdor 3 . All haile Macbeth , that shalt be King hereafter Ba
# . Hayle 3 . Hayle 1 . Lesser than Macbeth , and greater 2 . Not so happy ,
# hough thou be none : So all haile Macbeth , and Banquo 1 . Banquo , and Mac
# eth , and Banquo 1 . Banquo , and Macbeth , all haile Macb . Stay you imper
# he King hath happily receiu ' d , Macbeth , The newes of thy successe : and
# gh the roughest Day Banq . Worthy Macbeth , wee stay vpon your leysure Macb
# I built An absolute Trust . Enter Macbeth , Banquo , Rosse , and Angus . O
# ke , To cry , hold , hold . Enter Macbeth . Great Glamys , worthy Cawdor ,
# ruice ouer the Stage . Then enter Macbeth Macb . If it were done , when ' t
# re giues way to in repose . Enter Macbeth , and a Seruant with a Torch . Gi
# hether they liue , or dye . Enter Macbeth . Macb . Who ' s there ? what hoa
# ard a voyce cry , Sleep no more : Macbeth does murther Sleepe , the innocen
# ore Cawdor Shall sleepe no more : Macbeth shall sleepe no more Lady . Who w
#  made a Shift to cast him . Enter Macbeth . Macd . Is thy Master stirring ?
# selues : awake , awake , Exeunt . Macbeth and Lenox . Ring the Alarum Bell

# %% [markdown]
# That's better. What about something a lot less frequent?

# %%
print(countedWords[countedWords['word'] == 'donalbaine'])
macbethIndex.print_concordance('Donalbaine')
# Out:
#     count        word
# 80      7  donalbaine
# Displaying 7 of 7 matches:
# m within . Enter King Malcome , Donalbaine , Lenox , with attendants , mee
# Enter King , Lenox , Malcolme , Donalbaine , and Attendants . King . Is ex
# rches . Enter King , Malcolme , Donalbaine , Banquo , Lenox , Macduff , Ro
#  ' th ' second Chamber ? Lady . Donalbaine Mac . This is a sorry sight Lad
# er , and Treason , Banquo , and Donalbaine : Malcolme awake , Shake off th
# to brag of . Enter Malcolme and Donalbaine . Donal . What is amisse ? Macb
# were subborned , Malcolme , and Donalbaine the Kings two Sonnes Are stolne

# %% [markdown]
# # Getting and working with raw text
#
# First, we will retrieve a collection of press releases from a *GitHub API* that archived them, based on a number of analyses by Justin Grimmer, a political scientist whose work we will read next week, and who will be joining the University of Chicago next July!
#
# GitHub API requests are made to `'https://api.github.com/'` and responses are in JSON, similar to Tumblr's API.
#
# We will get the information on [github.com/lintool/GrimmerSenatePressReleases](https://github.com/lintool/GrimmerSenatePressReleases) as it contains a nice set documents.

# %%
r = requests.get('https://api.github.com/repos/lintool/GrimmerSenatePressReleases')
senateReleasesData = json.loads(r.text)
print(senateReleasesData.keys())
print(senateReleasesData['description'])
# Out:
# dict_keys(['id', 'name', 'full_name', 'owner', 'private', 'html_url', 'description', 'fork', 'url', 'forks_url', 'keys_url', 'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url', 'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url', 'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url', 'languages_url', 'stargazers_url', 'contributors_url', 'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url', 'comments_url', 'issue_comment_url', 'contents_url', 'compare_url', 'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url', 'milestones_url', 'notifications_url', 'labels_url', 'releases_url', 'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url', 'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size', 'stargazers_count', 'watchers_count', 'language', 'has_issues', 'has_projects', 'has_downloads', 'has_wiki', 'has_pages', 'forks_count', 'mirror_url', 'archived', 'open_issues_count', 'license', 'forks', 'open_issues', 'watchers', 'default_branch', 'network_count', 'subscribers_count'])
# Grimmer's Senate Press Releases

# %% [markdown]
# What we are interested in here is the `'contents_url'`

# %%
print(senateReleasesData['contents_url'])
# Out:
# https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/{+path}

# %% [markdown]
# We can use this to get any or all of the files from the repo.

# %%
r = requests.get('https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Whitehouse')
whitehouseLinks = json.loads(r.text)
whitehouseLinks[0]
# Out:
# {'_links': {'git': 'https://api.github.com/repos/lintool/GrimmerSenatePressReleases/git/blobs/f524289ee563dca58690c8d36c23dce5dbd9962a',
#   'html': 'https://github.com/lintool/GrimmerSenatePressReleases/blob/master/raw/Whitehouse/10Apr2007Whitehouse123.txt',
#   'self': 'https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Whitehouse/10Apr2007Whitehouse123.txt?ref=master'},
#  'download_url': 'https://raw.githubusercontent.com/lintool/GrimmerSenatePressReleases/master/raw/Whitehouse/10Apr2007Whitehouse123.txt',
#  'git_url': 'https://api.github.com/repos/lintool/GrimmerSenatePressReleases/git/blobs/f524289ee563dca58690c8d36c23dce5dbd9962a',
#  'html_url': 'https://github.com/lintool/GrimmerSenatePressReleases/blob/master/raw/Whitehouse/10Apr2007Whitehouse123.txt',
#  'name': '10Apr2007Whitehouse123.txt',
#  'path': 'raw/Whitehouse/10Apr2007Whitehouse123.txt',
#  'sha': 'f524289ee563dca58690c8d36c23dce5dbd9962a',
#  'size': 2206,
#  'type': 'file',
#  'url': 'https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Whitehouse/10Apr2007Whitehouse123.txt?ref=master'}

# %% [markdown]
# Now we have a list of information about Whitehouse press releases. Let's look at one of them.

# %%
r = requests.get(whitehouseLinks[0]['download_url'])
whitehouseRelease = r.text
print(whitehouseRelease[:1000])
len(whitehouseRelease)
# Out:
# SEN. WHITEHOUSE SHARES WESTERLY GIRL'S STORY IN PUSH FOR STEM CELL RESEARCH
#   Sharing the story of Lila Barber, a 12 year old girl from Westerly, Sen. Sheldon Whitehouse (D-R.I.) on Tuesday, April 10, 2007, illustrated the hope stem cell research can offer in a speech on the Senate floor in favor of legislation to expand federal funding for stem cell research.
#    Whitehouse met Lila two weeks ago. She was diagnosed two years ago with osteosarcoma, a cancerous bone condition, and last year underwent cadaver bone transplant surgery. The procedure saved her leg and is helping her remain cancer-free, but the transplanted tissue will not grow with her and likely will break down over time. Stem cell research, Whitehouse explained, could vastly improve the care of patients like Lila by allowing surgeons to enhance transplants with a patient's own stem cells, which could replace the lost bone and cartilage, or grow entirely new replacement bones and joints.
#    "Stem cell research gives hope
# 2206

# %% [markdown]
# Now we have a string of correctly encoded text, similar to those we constructed from last week's assignment. For analysis of its words, next we need to tokenize it, or to split it into a sequence of tokens or word instances.

# %%
whTokens = nltk.word_tokenize(whitehouseRelease)
whTokens[10:30]
# Out:
# ['STEM',
#  'CELL',
#  'RESEARCH',
#  'Sharing',
#  'the',
#  'story',
#  'of',
#  'Lila',
#  'Barber',
#  ',',
#  'a',
#  '12',
#  'year',
#  'old',
#  'girl',
#  'from',
#  'Westerly',
#  ',',
#  'Sen.',
#  'Sheldon']

# %% [markdown]
# `whTokens` is a list of 'words' constructed from nltk's `word_tokenize` method built on the [Penn Treebank tokenizer](http://www.nltk.org/api/nltk.tokenize.html#module-nltk.tokenize.treebank). While it's better than `.split(' ')`, a general python string method that splits on whitespace, it is not perfect. There are many different ways to tokenize a string. `word_tokenize` is unfortunately unaware of sentences and is essentially a complicated regular expression (regex) run across the string.
#
# If we want to find sentences we can use something like `nltk.sent_tokenize()`, which implements the [Punkt Sentence tokenizer](http://www.nltk.org/api/nltk.tokenize.html#nltk.tokenize.punkt.PunktSentenceTokenizer), a machine learning based algorithm that works well for many European languages.
#
# We could also use the [Stanford tokenizer](http://www.nltk.org/api/nltk.tokenize.html#module-nltk.tokenize.stanford) or construct our own regex with [`RegexpTokenizer()`](http://www.nltk.org/api/nltk.tokenize.html#module-nltk.tokenize.regexp). Picking the correct tokenizer is important as the tokens form the base of our analysis.
#
# For our purposes in this example, the Penn Treebank tokenizer is fine.
#
# To use the list of tokens in `nltk`, and take advantage of functions like `concordance`, shown above, we can convert it into a `Text`.

# %%
whText = nltk.Text(whTokens)

whitehouseIndex = nltk.text.ConcordanceIndex(whText) 
whitehouseIndex.print_concordance('Whitehouse')
# Out:
# Displaying 5 of 5 matches:
# rl from Westerly , Sen. Sheldon Whitehouse ( D-R.I. ) on Tuesday , April 1
# unding for stem cell research . Whitehouse met Lila two weeks ago . She wa
# ver time . Stem cell research , Whitehouse explained , could vastly improv
# ch might help or even cure , '' Whitehouse said . Whitehouse also praised
# ven cure , '' Whitehouse said . Whitehouse also praised the efforts of Rho

# %% [markdown]
# *Note* that the `Text` class is for doing rapid, exploratory analysis. It provides an easy interface to many of the operations we want to do, but it does not allow us much control over the particular operations it glosses. When you are doing a more complete analysis, you should be using the module specifically designed for that task instead of the shortcut method `Text` provides, e.g. use  [`collocations` Module](http://www.nltk.org/api/nltk.html#module-nltk.collocations) instead of `.collocations()`.
#
# Now that we have gotten this loaded, let's glance at few features we will delve into more deeply later.
#
# For example, we can find words that statistically tend to occur together and typically have a composite, idiomatic meaning irreducible to the semantics of its component words. We will do this later with more control over exactly how these are identified.

# %%
whText.collocations()
# Out:
# Rhode Island; stem cells; cell research; Cell Enhancement; Enhancement
# Act; President Bush; Stem Cell; stem cell; Stem cell

# %% [markdown]
# Or we can pick a word (or words) and find what words tend to occur around it.

# %%
whText.common_contexts(['stem'])
# Out:
# for_cell hope_cell ._cell own_cells ``_cell of_cell on_cells the_cell
# embryonic_cells

# %% [markdown]
# We can also just count the number of times the word occurs.

# %%
whText.count('cell')
# Out:
# 5

# %% [markdown]
# We can also plot each time a set of words occurs.

# %%
sns.reset_orig() #Seaborn messes with this plot, disabling it
whText.dispersion_plot(['Sen.','stem', 'cell', 'federal' ,'Lila', 'Barber', 'Whitehouse'])
sns.set() #Re-enabling seaborn

# %% [markdown]
# If we want to do an analysis of all the Whitehouse press releases we will first need to obtain them. By looking at the API we can see the the URL we want is [https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Whitehouse](https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Whitehouse), so we can create a function to scrape the individual files.
#
# If you want to know more about downloading from APIs, refer back to the 1st notebook.

# %%
def getGithubFiles(target, maxFiles = 100):
    #We are setting a max so our examples don't take too long to run
    #For converting to a DataFrame
    releasesDict = {
        'name' : [], #The name of the file
        'text' : [], #The text of the file, watch out for binary files
        'path' : [], #The path in the git repo to the file
        'html_url' : [], #The url to see the file on Github
        'download_url' : [], #The url to download the file
    }

    #Get the directory information from Github
    r = requests.get(target)
    filesLst = json.loads(r.text)

    for fileDict in filesLst[:maxFiles]:
        #These are provided by the directory
        releasesDict['name'].append(fileDict['name'])
        releasesDict['path'].append(fileDict['path'])
        releasesDict['html_url'].append(fileDict['html_url'])
        releasesDict['download_url'].append(fileDict['download_url'])

        #We need to download the text though
        text = requests.get(fileDict['download_url']).text
        releasesDict['text'].append(text)

    return pandas.DataFrame(releasesDict)

whReleases = getGithubFiles('https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Whitehouse', maxFiles = 10)
whReleases[:5]
# Out:
#                                         download_url  \
# 0  https://raw.githubusercontent.com/lintool/Grim...
# 1  https://raw.githubusercontent.com/lintool/Grim...
# 2  https://raw.githubusercontent.com/lintool/Grim...
# 3  https://raw.githubusercontent.com/lintool/Grim...
# 4  https://raw.githubusercontent.com/lintool/Grim...
#
#                                             html_url  \
# 0  https://github.com/lintool/GrimmerSenatePressR...
# 1  https://github.com/lintool/GrimmerSenatePressR...
# 2  https://github.com/lintool/GrimmerSenatePressR...
# 3  https://github.com/lintool/GrimmerSenatePressR...
# 4  https://github.com/lintool/GrimmerSenatePressR...
#
#                          name                                       path  \
# 0  10Apr2007Whitehouse123.txt  raw/Whitehouse/10Apr2007Whitehouse123.txt
# 1    10Apr2008Whitehouse2.txt    raw/Whitehouse/10Apr2008Whitehouse2.txt
# 2    10Apr2008Whitehouse3.txt    raw/Whitehouse/10Apr2008Whitehouse3.txt
# 3   10Aug2007Whitehouse78.txt   raw/Whitehouse/10Aug2007Whitehouse78.txt
# 4   10Jan2008Whitehouse35.txt   raw/Whitehouse/10Jan2008Whitehouse35.txt
#
#                                                 text
# 0  SEN. WHITEHOUSE SHARES WESTERLY GIRL'S STORY I...
# 1  SEN. WHITEHOUSE SAYS PRESIDENT BUSH MUST BEGIN...
# 2  EPA MUST REVIEW LEGAL PROCESS TO ROOT OUT POLI...
# 3  R.I. SENATORS PRAISE SEN. DENIAL OF LNG FACILI...
# 4  SEN. WHITEHOUSE COMMENTS ON ONE-YEAR ANNIVERSA...

# %% [markdown]
# If you are having trouble downloading the data uncomment this next cell

# %%
#whReleases = pandas.read_csv('../data/whReleases.csv')

# %% [markdown]
# Now we have all the texts in a DataFrame we can look at a few things.
#
# First let's tokenize the texts with the same tokenizer as we used before. We will just save the tokens as a list for now; no need to convert to `Text`s.

# %%
whReleases['tokenized_text'] = whReleases['text'].apply(lambda x: nltk.word_tokenize(x))

# %% [markdown]
# Now lets see how long each of the press releases is:

# %%
whReleases['word_counts'] = whReleases['tokenized_text'].apply(lambda x: len(x))
whReleases['word_counts']
# Out:
# 0    397
# 1    344
# 2    553
# 3    216
# 4    257
# 5    380
# 6    270
# 7    521
# 8    484
# 9    482
# Name: word_counts, dtype: int64

# %% [markdown]
# ## <span style="color:red">*Exercise 1*</span>
#
# <span style="color:red">Construct cells immediately below this that input and interrogate a corpus relating to your anticipated final project. Turn your text into an nltk `Text` object, and explore all of the features examined above, and others that relate to better understanding your corpus in relation to your research question. </span>

# %%
# Import packages that have not been imported above
from bs4 import BeautifulSoup
import re

# Scrape the webpage of "house music" on Wikipedia, and look for the distribution of its
# word counts, as well as the words/contexts that tend to appear with the phrase "house music"

# Create a function to get the text and clean it
def get_clean_text(url, tag, concept):
    '''
    This functions scrapes texts from the given url with the given tag.
    
    Inputs:
        url: a string, url of the website
        tag: a string, the tag in html
        concept: a string, the file name used to store the texts
    
    Output:
        texts: a list of strings, with each string representing texts of one tag
    '''
    texts = []
    
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    pTags = soup.findAll(tag)
    for item in pTags:
        temp = item.text
        if temp != '':
            temp = re.sub('\[[0-9]+\]', '', temp)# discard the marks of footnote
            texts.append(temp)
    
    # Write the text into a file
    with open('../data/{}.txt'.format(concept), 'w') as f:
        for item in texts:
            f.write("{}\n".format(item))
    
    # Concatenate the strings into one string
    texts_all = texts[0]
    for i in range(1, len(texts)):
        texts_all = texts_all + ' ' + texts[i]
    
    return texts_all

# Scrape the Wikipedia page for "house music"
url = 'https://en.wikipedia.org/wiki/House_music'
texts_all = get_clean_text(url, 'p', 'house_music')

# %%
# Tokenize, keep all the original words and punctuations
hm_tokens = nltk.word_tokenize(texts_all)

# Count words, sort by descending order, and write in a Pandas

# %%
# Count words, sort by descending order, and write in a Pandas Dataframe
hm_words = {}
for word in hm_tokens:
    hm_words[word] = hm_words.get(word, 0) + 1
hm_counts = {'word':[], 'word_count':[]}
for item in sorted(hm_words, key=hm_words.get, reverse=True):
    hm_counts['word'].append(item)
    hm_counts['word_count'].append(hm_words[item])
hm_df = pandas.DataFrame(hm_counts)
hm_df
# Out:
#                word  word_count
# 0                 ,         460
# 1               the         309
# 2                 .         260
# 3               and         252
# 4             house         168
# 5                of         143
# 6                ``         123
# 7                in         122
# 8                ''         121
# 9             music         115
# 10               to         103
# 11                a          87
# 12               as          85
# 13               's          75
# 14               by          65
# 15              was          64
# 16              The          62
# 17             with          53
# 18             such          50
# 19          Chicago          47
# 20                (          47
# 21                )          47
# 22             from          41
# 23            dance          39
# 24               on          37
# 25             were          36
# 26              DJs          34
# 27             that          32
# 28               DJ          31
# 29               In          31
# ...             ...         ...
# 1855       addition           1
# 1856  reunification           1
# 1857   contemporary           1
# 1858           turn           1
# 1859            add           1
# 1860           mass           1
# 1861       Tropical           1
# 1862           onto           1
# 1863             40           1
# 1864        Singles           1
# 1865           2015           1
# 1866           Kygo           1
# 1867          Jonas           1
# 1868           Blue           1
# 1869      mid-2010s           1
# 1870           seen           1
# 1871         Korean           1
# 1872          K-pop           1
# 1873              f           1
# 1874              x           1
# 1875          Walls           1
# 1876         Chosen           1
# 1877            Few           1
# 1878     celebrates           1
# 1879     birthplace           1
# 1880        Started           1
# 1881      gathering           1
# 1882        friends           1
# 1883       families           1
# 1884   performances           1
#
# [1885 rows x 2 columns]

# %%
# Create a figure of the raw counts
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(range(len(hm_counts['word_count'])), hm_counts['word_count'])
plt.title('Figure 1: Raw Counts of Tokenized Words')
plt.xlabel('Rank Order of Words')
plt.ylabel('Frequency')
plt.savefig('Figure_1.jpg')
plt.show()

# %%
# Create a log-log graph
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(range(len(hm_counts['word_count'])), hm_counts['word_count'])
ax.set_yscale('log')
ax.set_xscale('log')
plt.title('Figure 2: Log-log Counts of Tokenized Words')
plt.xlabel('Log(Rank Order)')
plt.ylabel('Log(Frequency)')
plt.savefig('Figure_2.jpg')
plt.show()

# %%
# Get concordance of word "house"
hmText = nltk.Text(hm_tokens)
hmIndex = nltk.text.ConcordanceIndex(hmText) 
hmIndex.print_concordance('house')
# Out:
# Displaying 25 of 168 matches:
# Chicago in the early 1980s . Early house music was generally characterized
#  and synthesized basslines . While house displayed several characteristics
# ord producer-created dance music , house was more electronic and minimalist
#  mechanical , repetitive rhythm of house was more important than the song i
# an the song itself ; indeed , many house songs were instrumental , with no
# cenes . In the mid-to-late 1980s , house music became popular in Europe as
# th America , and Australia . Early house music had commercial success in Eu
# s . Since the early to mid-1990s , house music has been infused into mainst
# he late 1980s , many local Chicago house music artists suddenly found thems
# m the soulful and atmospheric deep house to the more minimalistic microhous
# ng fusion subgenres , such as euro house , tech house , electro house and j
# genres , such as euro house , tech house , electro house and jump house . O
#  euro house , tech house , electro house and jump house . One subgenre , ac
# ech house , electro house and jump house . One subgenre , acid house , was
# d jump house . One subgenre , acid house , was based around the squelchy ,
# uccess in the early to mid-1990s , house music grew even larger during the
# ing the second wave of progressive house ( 1999–2001 ) . The genre has rema
# popular subgenres , notably ghetto house , deep house , future house and te
# nres , notably ghetto house , deep house , future house and tech house . As
# ghetto house , deep house , future house and tech house . As of 2016 , hous
# deep house , future house and tech house . As of 2016 , house music remains
# ouse and tech house . As of 2016 , house music remains popular in both club
# e 1990s to the 2010s , progressive house artists and performers such as Daf
# se of 909 brought new attention to house . House music is created by DJs an
# nstruments . The song structure of house music songs typically involves an

# %%
# Get collocations
hmText.collocations()
# Out:
# house music; New York; Frankie Knuckles; citation needed; Ron Hardy;
# Marshall Jefferson; drum machine; Derrick May; acid house; Kevin
# Saunderson; Magic Orchestra; Yellow Magic; dance music; drum machines;
# Juan Atkins; Music Box; Calvin Harris; Dada Nada; Daft Punk; Los
# Angeles

# %%
# Get words around
hmText.common_contexts(['house'])
# Out:
# *START*_music early_music while_displayed ,_was of_was many_songs
# ._music ,_music the_'' chicago_music deep_to euro_, tech_, electro_and
# jump_. acid_, progressive_( ghetto_, deep_, future_and

# %%
# Create the Lexical Dispersion Plot
sns.reset_orig() #Seaborn messes with this plot, disabling it
hmText.dispersion_plot(['house', 'music', 'transgressive', 'crime', 'Chicago', 'urban', 'club', 'dance'])
sns.set() #Re-enabling seaborn

# %%
# Create a list of urls
url_lst = ['https://en.wikipedia.org/wiki/Blues', \
           'https://en.wikipedia.org/wiki/House_music', \
           'https://en.wikipedia.org/wiki/Gospel_music', \
           'https://en.wikipedia.org/wiki/Hip_hop_music', \
           'https://en.wikipedia.org/wiki/Country_music', \
           'https://en.wikipedia.org/wiki/Popular_music']

filename_lst = ['blues_music', 'house_music', 'gospel_music', 'hip_hop_music', 'country_music',\
                'popular_music']

# Get texts
music_texts = {'music_type':[], 'text':[]}
for i in range(len(url_lst)):
    music_texts['text'].append(get_clean_text(url_lst[i], 'p', filename_lst[i]))
    music_texts['music_type'].append(filename_lst[i])
music_df = pandas.DataFrame(music_texts)

# %%
# Get the word counts of Wikipedia description for several music types
music_df['tokenized_text'] = music_df['text'].apply(lambda x: nltk.word_tokenize(x))
music_df['word_counts'] = music_df['tokenized_text'].apply(lambda x: len(x))
music_df['word_counts']
# Out:
# 0     9513
# 1     7366
# 2     2537
# 3    14782
# 4    13191
# 5     3634
# Name: word_counts, dtype: int64

# %% [markdown]
# # Filtering and normalizing text
#
# As we want to start comparing the different releases we may choose to do a bit of filtering and normalizing that will allow us to focus on what we most care about. We can first make all of the words lower case, then drop the non-word tokens. Next, we can remove some 'stop words', stem the remaining words to remove suffixes, prefixes and (in some languages) infixes, or lemmatize tokens by intelligently grouping inflected or variant forms of the same word (e.g., with a stemmer and a dictionary).
#
# To begin this process, we will first define a function to work over the tokenized lists, then another to add normalized tokens to a new column.

# %% [markdown]
# Nltk has a built-in list of stopwords. They are already imported in the import section. Let's first take a look at what they are.

# %%
print(', '.join(stopwords.words('english')))
# Out:
# i, me, my, myself, we, our, ours, ourselves, you, you're, you've, you'll, you'd, your, yours, yourself, yourselves, he, him, his, himself, she, she's, her, hers, herself, it, it's, its, itself, they, them, their, theirs, themselves, what, which, who, whom, this, that, that'll, these, those, am, is, are, was, were, be, been, being, have, has, had, having, do, does, did, doing, a, an, the, and, but, if, or, because, as, until, while, of, at, by, for, with, about, against, between, into, through, during, before, after, above, below, to, from, up, down, in, out, on, off, over, under, again, further, then, once, here, there, when, where, why, how, all, any, both, each, few, more, most, other, some, such, no, nor, not, only, own, same, so, than, too, very, s, t, can, will, just, don, don't, should, should've, now, d, ll, m, o, re, ve, y, ain, aren, aren't, couldn, couldn't, didn, didn't, doesn, doesn't, hadn, hadn't, hasn, hasn't, haven, haven't, isn, isn't, ma, mightn, mightn't, mustn, mustn't, needn, needn't, shan, shan't, shouldn, shouldn't, wasn, wasn't, weren, weren't, won, won't, wouldn, wouldn't

# %% [markdown]
# We can remove these stopwords from the analysis by fiat, but we could also take a more principled approach by looking at the frequency distribution of words and selecting a specific cut-off associated with the preservation of 'meaningful words' identified upon inspection. Alternatively, we could automatically set a cut-off by rule, such as removal of all words more frequent then the most frequent verb, or the most frequent noun (not pronoun), or some term of central interest.

# %% [markdown]
# Lets generate our own stop list now.

# %%
countsDict = {}
for word in whReleases['tokenized_text'].sum():
    if word in countsDict:
        countsDict[word] += 1
    else:
        countsDict[word] = 1
word_counts = sorted(countsDict.items(), key = lambda x : x[1], reverse = True)
word_counts[:20]
# Out:
# [('the', 179),
#  (',', 173),
#  ('.', 136),
#  ('of', 112),
#  ('to', 112),
#  ('and', 108),
#  ('in', 64),
#  ('a', 61),
#  ("'s", 50),
#  ('that', 41),
#  ('our', 39),
#  ('for', 35),
#  ('on', 33),
#  ('is', 33),
#  ('Whitehouse', 31),
#  ('``', 30),
#  ('Iraq', 28),
#  ('Bush', 27),
#  ('President', 25),
#  ('(', 24)]

# %% [markdown]
# We can look at this and pick the cutoff, usually it is at the first noun. So we will cut all words before `'Whitehouse'`.

# %%
#The stop list is then all words that occur before the first noun
stop_words_freq = []
for word, count in word_counts:
    if word == 'Whitehouse':
        break
    else:
        stop_words_freq.append(word)
stop_words_freq
wordnet = nltk.stem.WordNetLemmatizer()
wordnet.lemmatize('are')
# Out:
# 'are'

# %% [markdown]
# Now we can create our function to normalize the tokens

# %%
stop_words_nltk = stopwords.words('english')
#stop_words = ["the","it","she","he", "a"] #Uncomment this line if you want to use your own list of stopwords.

#The stemmers and lemmers need to be initialized before bing run
porter = nltk.stem.porter.PorterStemmer()
snowball = nltk.stem.snowball.SnowballStemmer('english')
wordnet = nltk.stem.WordNetLemmatizer()

def normlizeTokens(tokenLst, stopwordLst = None, stemmer = None, lemmer = None):
    #We can use a generator here as we just need to iterate over it

    #Lowering the case and removing non-words
    workingIter = (w.lower() for w in tokenLst if w.isalpha())

    #Now we can use the semmer, if provided
    if stemmer is not None:
        workingIter = (stemmer.stem(w) for w in workingIter)
        
    #And the lemmer
    if lemmer is not None:
        workingIter = (lemmer.lemmatize(w) for w in workingIter)
    
    #And remove the stopwords
    if stopwordLst is not None:
        workingIter = (w for w in workingIter if w not in stopwordLst)
    #We will return a list with the stopwords removed
    return list(workingIter)

whReleases['normalized_tokens'] = whReleases['tokenized_text'].apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, stemmer = porter))

whReleases['normalized_tokens_count'] = whReleases['normalized_tokens'].apply(lambda x: len(x))

whReleases
# Out:
#                                         download_url  \
# 0  https://raw.githubusercontent.com/lintool/Grim...
# 1  https://raw.githubusercontent.com/lintool/Grim...
# 2  https://raw.githubusercontent.com/lintool/Grim...
# 3  https://raw.githubusercontent.com/lintool/Grim...
# 4  https://raw.githubusercontent.com/lintool/Grim...
# 5  https://raw.githubusercontent.com/lintool/Grim...
# 6  https://raw.githubusercontent.com/lintool/Grim...
# 7  https://raw.githubusercontent.com/lintool/Grim...
# 8  https://raw.githubusercontent.com/lintool/Grim...
# 9  https://raw.githubusercontent.com/lintool/Grim...
#
#                                             html_url  \
# 0  https://github.com/lintool/GrimmerSenatePressR...
# 1  https://github.com/lintool/GrimmerSenatePressR...
# 2  https://github.com/lintool/GrimmerSenatePressR...
# 3  https://github.com/lintool/GrimmerSenatePressR...
# 4  https://github.com/lintool/GrimmerSenatePressR...
# 5  https://github.com/lintool/GrimmerSenatePressR...
# 6  https://github.com/lintool/GrimmerSenatePressR...
# 7  https://github.com/lintool/GrimmerSenatePressR...
# 8  https://github.com/lintool/GrimmerSenatePressR...
# 9  https://github.com/lintool/GrimmerSenatePressR...
#
#                          name                                       path  \
# 0  10Apr2007Whitehouse123.txt  raw/Whitehouse/10Apr2007Whitehouse123.txt
# 1    10Apr2008Whitehouse2.txt    raw/Whitehouse/10Apr2008Whitehouse2.txt
# 2    10Apr2008Whitehouse3.txt    raw/Whitehouse/10Apr2008Whitehouse3.txt
# 3   10Aug2007Whitehouse78.txt   raw/Whitehouse/10Aug2007Whitehouse78.txt
# 4   10Jan2008Whitehouse35.txt   raw/Whitehouse/10Jan2008Whitehouse35.txt
# 5    10Mar2008Whitehouse8.txt    raw/Whitehouse/10Mar2008Whitehouse8.txt
# 6   10Sep2007Whitehouse72.txt   raw/Whitehouse/10Sep2007Whitehouse72.txt
# 7  11Apr2007Whitehouse122.txt  raw/Whitehouse/11Apr2007Whitehouse122.txt
# 8  11Jan2007Whitehouse161.txt  raw/Whitehouse/11Jan2007Whitehouse161.txt
# 9    11Mar2008Whitehouse7.txt    raw/Whitehouse/11Mar2008Whitehouse7.txt
#
#                                                 text  \
# 0  SEN. WHITEHOUSE SHARES WESTERLY GIRL'S STORY I...
# 1  SEN. WHITEHOUSE SAYS PRESIDENT BUSH MUST BEGIN...
# 2  EPA MUST REVIEW LEGAL PROCESS TO ROOT OUT POLI...
# 3  R.I. SENATORS PRAISE SEN. DENIAL OF LNG FACILI...
# 4  SEN. WHITEHOUSE COMMENTS ON ONE-YEAR ANNIVERSA...
# 5  SENS. REED, WHITEHOUSE WELCOME RHODE ISLAND ST...
# 6  REP. WHITEHOUSE ISSUES STATEMENT ON GEN. PETRA...
# 7  SEN. WHITEHOUSE URGES BUSH FOR NEW DIRECTION I...
# 8  SENS. REED, WHITEHOUSE URGE PORTUGAL TO RECONS...
# 9  WHITEHOUSE UNVEILS 'BUSH DEBT': $7.7 TRILLION ...
#
#                                       tokenized_text  word_counts  \
# 0  [SEN., WHITEHOUSE, SHARES, WESTERLY, GIRL, 'S,...          397
# 1  [SEN., WHITEHOUSE, SAYS, PRESIDENT, BUSH, MUST...          344
# 2  [EPA, MUST, REVIEW, LEGAL, PROCESS, TO, ROOT, ...          553
# 3  [R.I, ., SENATORS, PRAISE, SEN, ., DENIAL, OF,...          216
# 4  [SEN., WHITEHOUSE, COMMENTS, ON, ONE-YEAR, ANN...          257
# 5  [SENS, ., REED, ,, WHITEHOUSE, WELCOME, RHODE,...          380
# 6  [REP., WHITEHOUSE, ISSUES, STATEMENT, ON, GEN....          270
# 7  [SEN., WHITEHOUSE, URGES, BUSH, FOR, NEW, DIRE...          521
# 8  [SENS, ., REED, ,, WHITEHOUSE, URGE, PORTUGAL,...          484
# 9  [WHITEHOUSE, UNVEILS, 'BUSH, DEBT, ', :, $, 7....          482
#
#                                    normalized_tokens  normalized_tokens_count
# 0  [whitehous, share, westerli, girl, stori, push...                      231
# 1  [whitehous, say, presid, bush, must, begin, br...                      171
# 2  [epa, must, review, legal, process, root, poli...                      305
# 3  [senat, prais, sen, denial, lng, facil, permit...                      115
# 4  [whitehous, comment, anniversari, presid, bush...                      132
# 5  [sen, reed, whitehous, welcom, rhode, island, ...                      195
# 6  [whitehous, issu, statement, petraeu, iraq, re...                      118
# 7  [whitehous, urg, bush, new, direct, iraq, shel...                      257
# 8  [sen, reed, whitehous, urg, portug, reconsid, ...                      254
# 9  [whitehous, unveil, debt, trillion, foregon, s...                      260

# %% [markdown]
# The stemmer we use here is called the [Porter Stemmer](http://www.nltk.org/api/nltk.stem.html#module-nltk.stem.porter), there are many others, including another good one by the same person (Martin Porter) called the [Snowball Stemmer](http://www.nltk.org/api/nltk.stem.html#module-nltk.stem.snowball) or 'another stemmer' called the [Lancaster Stemmer](http://www.nltk.org/_modules/nltk/stem/lancaster.html). We can also normalize our words by lemmatizing them, or matching word variants or inflected forms to a common morpheme in a dictionary like [WordNet](https://wordnet.princeton.edu) through intelligent stemming rules. (The WordNet function `morphy` returns the given word if it cannot be matched to a word in the dictionary).
#
# Now that it is cleaned we start analyzing the dataset. We can start by finding frequency distributions for the dataset. Lets start looking at all the press releases together. The [`ConditionalFreqDist`](http://www.nltk.org/api/nltk.html#nltk.probability.ConditionalProbDist) class reads in an iterable of tuples, the first element is the condition and the second the focal word. For starters, we will use word lengths as the conditions, but tags or clusters will provide more useful results.

# %%
#.sum() adds together the lists from each row into a single list
whcfdist = nltk.ConditionalFreqDist(((len(w), w) for w in whReleases['normalized_tokens'].sum()))

#print the number of words
print(whcfdist.N())
# Out:
# 2038

# %% [markdown]
# From this we can lookup the distributions of different word lengths

# %%
whcfdist[3].plot()

# %% [markdown]
# See that the most frequent 3-character word is "thi". But what is "thi"? It is actually "this" stemmed by the Porter Stemmer.

# %%
porter = nltk.stem.porter.PorterStemmer()
print (porter.stem('this'))
# Out:
# thi

# %% [markdown]
# Let's try with the Snowball Stemer. See that "this" is corretly stemmed as a 4-character word.

# %%
print (snowball.stem('this'))

whReleases['normalized_tokens'] = whReleases['tokenized_text'].apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, stemmer = snowball))
whReleases['normalized_tokens_count'] = whReleases['normalized_tokens'].apply(lambda x: len(x))
whcfdist = nltk.ConditionalFreqDist(((len(w), w) for w in whReleases['normalized_tokens'].sum()))
whcfdist[3].plot()
# Out:
# this

# %% [markdown]
# We can also create a Conditional Probability Distribution or [`ConditionalProbDist`](http://www.nltk.org/api/nltk.html#nltk.probability.ConditionalProbDist) from the `ConditionalFreqDist`. To do this, however, we need a model for the probability distribution. A simple model is [`ELEProbDist`](http://www.nltk.org/api/nltk.html#nltk.probability.ELEProbDist) which gives the expected likelihood estimate for the probability distribution of the experiment used to generate the observed frequency distribution.

# %%
whcpdist = nltk.ConditionalProbDist(whcfdist, nltk.ELEProbDist)

#print the most common 2 letter word
print(whcpdist[2].max())

#And its probability
print(whcpdist[2].prob(whcpdist[2].max()))
# Out:
# us
# 0.6470588235294118

# %% [markdown]
# Length is one feature of a word, but there are many more important features we care about. Another critical feature is a word's role in the sentence, or its part of speech (POS). Here, we will be classifying words according to their part of speech (POS), using the [`nltk.pos_tag()`](http://www.nltk.org/api/nltk.tag.html#nltk.tag.pos_tag). The tags used here are those from the [Brown Corpus tagset](http://www.scs.leeds.ac.uk/amalgam/tagsets/brown.html).

# %%
whReleases['normalized_tokens_POS'] = [nltk.pos_tag(t) for t in whReleases['normalized_tokens']]

# %% [markdown]
# This gives us a new column with the part of speech as a short initialism and the word in a tuple, exactly how the `nltk.ConditionalFreqDist()` function wants them. We can now construct another conditional frequency distribution.

# %%
whcfdist_WordtoPOS = nltk.ConditionalFreqDist(whReleases['normalized_tokens_POS'].sum())
list(whcfdist_WordtoPOS.items())[:10]
# Out:
# [('whitehous', FreqDist({'JJ': 39, 'NN': 1})),
#  ('share', FreqDist({'NN': 4})),
#  ('wester', FreqDist({'NN': 1, 'RBR': 1})),
#  ('girl', FreqDist({'NN': 2})),
#  ('stori', FreqDist({'FW': 2})),
#  ('push', FreqDist({'NN': 2})),
#  ('stem', FreqDist({'NN': 12})),
#  ('cell', FreqDist({'NN': 9, 'VBP': 3})),
#  ('research', FreqDist({'NN': 9})),
#  ('lila', FreqDist({'CD': 1, 'JJ': 1, 'NN': 2}))]

# %% [markdown]
# This gives the frequency of each word as each part of speech...which can be uninformative and boring.

# %%
whcfdist_WordtoPOS['administr'].plot()

# %% [markdown]
# What we want is the converse; the frequency of each part of speech for each word.

# %%
whcfdist_POStoWord = nltk.ConditionalFreqDist((p, w) for w, p in whReleases['normalized_tokens_POS'].sum())

# %% [markdown]
# We can now identify and collect all of the superlative adjectives

# %%
whcfdist_POStoWord['JJS']
# Out:
# FreqDist({'best': 1, 'strongest': 2})

# %% [markdown]
# Or look at the most common nouns

# %%
whcfdist_POStoWord['NN'].most_common(5)
# Out:
# [('bush', 24), ('presid', 23), ('iraq', 22), ('rhode', 18), ('island', 18)]

# %% [markdown]
# Or plot the base form verbs against their number of occurrences

# %%
whcfdist_POStoWord['VB'].plot()

# %% [markdown]
# We can then do a similar analysis of the word probabilities

# %%
whcpdist_POStoWord = nltk.ConditionalProbDist(whcfdist_POStoWord, nltk.ELEProbDist)

#print the most common nouns
print(whcpdist_POStoWord['NN'].max())

#And its probability
print(whcpdist_POStoWord['NN'].prob(whcpdist_POStoWord['NN'].max()))
# Out:
# bush
# 0.017844136926438457

# %% [markdown]
# We can even create a...wait for it...*WORD CLOUD* or Wordl to gaze at and draw mystical, approximate inferences about important nouns and verbs in our corpus:

# %%
wc = wordcloud.WordCloud(background_color="white", max_words=500, width= 1000, height = 1000, mode ='RGBA', scale=.5).generate(' '.join(whReleases['normalized_tokens'].sum()))
plt.imshow(wc)
plt.axis("off")
plt.savefig("whitehouse_word_cloud.pdf", format = 'pdf')

# %% [markdown]
# ## <span style="color:red">*Exercise 2*</span>
#
# <span style="color:red">Construct cells immediately below this that filter, stem and lemmatize the tokens in your corpus, and then creates plots (with titles and labels) that map the word frequency distribution, word probability distribution, and at least two conditional probability distributions that help us better understand the social and cultural game underlying the production of your corpus. Create a wordl of words (or normalized words) and add a few vague comments about what mysteries are revealed through it.</span>

# %%
# In the previous exercise, I already constructed the list of tokenized words
# as hm_tokens, the dictionary to count frequency of every word as hm_words,
# and the Pandas DataFrame to store words and corresponding frequencies with
# descending order of count as hm_df

# Check the words distribution to find my own list of stop words
hm_df.iloc[:20]
# Out:
#        word  word_count
# 0         ,         460
# 1       the         309
# 2         .         260
# 3       and         252
# 4     house         168
# 5        of         143
# 6        ``         123
# 7        in         122
# 8        ''         121
# 9     music         115
# 10       to         103
# 11        a          87
# 12       as          85
# 13       's          75
# 14       by          65
# 15      was          64
# 16      The          62
# 17     with          53
# 18     such          50
# 19  Chicago          47

# %%
# Find it hard decide the cutoff manually, since the first noun appers too
# early. Use the built in stop words instead.
stop_words_nltk = stopwords.words('english')

# %%
# Initialize the stemmers and lemmers
porter = nltk.stem.porter.PorterStemmer()
snowball = nltk.stem.snowball.SnowballStemmer('english')
wordnet = nltk.stem.WordNetLemmatizer()

# Construct a function to filter, stem, and lemmatize the tokens
def normlizeTokens(tokenLst, stopwordLst=None, stemmer=None, lemmer=None):
    # Lower the case and remove non-words
    workingIter = (w.lower() for w in tokenLst if w.isalpha())
    # Apply stemmer
    if stemmer is not None:
        workingIter = (stemmer.stem(w) for w in workingIter)        
    # Apply lemmer
    if lemmer is not None:
        workingIter = (lemmer.lemmatize(w) for w in workingIter)    
    # Remove the stopwords
    if stopwordLst is not None:
        workingIter = (w for w in workingIter if w not in stopwordLst)
    # Return the modified tokens
    return list(workingIter)

# %%
# Normalize Tokens
music_df['normalized_tokens'] = music_df['tokenized_text'].\
    apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, \
                                   stemmer = porter))
music_df['normalized_tokens_count'] = music_df['normalized_tokens'].\
    apply(lambda x: len(x))
music_df
# Out:
#       music_type                                               text  \
# 0    blues_music  Blues is a music genre and musical form origin...
# 1    house_music  House music is a genre of electronic music cre...
# 2   gospel_music  Gospel music is a genre of Christian music. Th...
# 3  hip_hop_music  Hip hop music, also called hip-hop or rap musi...
# 4  country_music  Country (or country and western) is a musical ...
# 5  popular_music  Popular music is music with wide appeal that i...
#
#                                       tokenized_text  word_counts  \
# 0  [Blues, is, a, music, genre, and, musical, for...         9513
# 1  [House, music, is, a, genre, of, electronic, m...         7366
# 2  [Gospel, music, is, a, genre, of, Christian, m...         2537
# 3  [Hip, hop, music, ,, also, called, hip-hop, or...        14782
# 4  [Country, (, or, country, and, western, ), is,...        13191
# 5  [Popular, music, is, music, with, wide, appeal...         3634
#
#                                    normalized_tokens  normalized_tokens_count
# 0  [blue, music, genr, music, form, origin, afric...                     4990
# 1  [hous, music, genr, electron, music, creat, cl...                     3832
# 2  [gospel, music, genr, christian, music, creati...                     1323
# 3  [hip, hop, music, also, call, rap, music, musi...                     7717
# 4  [countri, countri, western, music, genr, origi...                     6882
# 5  [popular, music, music, wide, appeal, typic, d...                     1942

# %%
# Get frequency distribution, and plot
# However, since there are too many words in the corpora, the plot would look ugly
# Still, we could see the curved and dramatically declined distribution
music_fdist = nltk.FreqDist(music_df['normalized_tokens'].sum())
music_fdist.plot(title='Figure 3: Frequency Distribution of the Whole Corpora')

# %%
# Try to plot the frequency distribution of the corpus of House Music
# But again, there are too many words, which makes the plot hard to see clearly.
# But it still have the same distribution.
music_fdist1 = nltk.FreqDist(music_df['normalized_tokens'].iloc[1])
music_fdist1.plot(title='Figure 4: Frequency Distribution of the House Music Corpus')

# %%
# Get probability distribution
total_count = 0
word_prob = {}
for k, v in music_fdist.items():
    total_count += v
for k, v in music_fdist.items():
    word_prob[k] = v/total_count

word_prob
# Out:
# {'blue': 0.014164730570336506,
#  'music': 0.03305103799745185,
#  'genr': 0.005321142171925354,
#  'form': 0.0028854080791426216,
#  'origin': 0.002061005770816158,
#  'african': 0.001761223113242899,
#  'american': 0.0023607884283894176,
#  'deep': 0.0007494566439331485,
#  'south': 0.000974293637113093,
#  'unit': 0.0014239676234729822,
#  'state': 0.0019860601064228436,
#  'around': 0.001049239301506408,
#  'end': 0.0007119838117364911,
#  'centuri': 0.00131154912688301,
#  'develop': 0.0024357340927827326,
#  'root': 0.0009368208049164356,
#  'tradit': 0.002510679757176047,
#  'work': 0.0008618751405231207,
#  'song': 0.007494566439331485,
#  'spiritu': 0.0005620924829498613,
#  'folk': 0.0014239676234729822,
#  'white': 0.001236603462489695,
#  'european': 0.00029978265757325936,
#  'heritag': 0.00014989132878662968,
#  'incorpor': 0.0005995653151465187,
#  'field': 0.0003372554897699168,
#  'holler': 0.00011241849658997227,
#  'shout': 0.000262309825376602,
#  'chant': 0.00029978265757325936,
#  'rhyme': 0.0005620924829498613,
#  'simpl': 0.000262309825376602,
#  'narr': 0.00011241849658997227,
#  'ballad': 0.0005995653151465187,
#  'ubiquit': 0.00011241849658997227,
#  'jazz': 0.0010117664693097504,
#  'rhythm': 0.0011616577980963802,
#  'rock': 0.004496739863598891,
#  'roll': 0.0011616577980963802,
#  'character': 0.000524619650753204,
#  'pattern': 0.00029978265757325936,
#  'scale': 0.0004871468185565465,
#  'specif': 0.00037472832196657423,
#  'chord': 0.0007494566439331485,
#  'progress': 0.0009368208049164356,
#  'common': 0.0004871468185565465,
#  'note': 0.0013490219590796672,
#  'worri': 0.00011241849658997227,
#  'usual': 0.0008244023083264633,
#  'third': 0.0005995653151465187,
#  'fifth': 0.00029978265757325936,
#  'flatten': 0.00029978265757325936,
#  'pitch': 3.747283219665742e-05,
#  'also': 0.004871468185565465,
#  'essenti': 0.00011241849658997227,
#  'part': 0.0012740762946863524,
#  'sound': 0.0037472832196657423,
#  'shuffl': 0.00022483699317994455,
#  'walk': 0.00014989132878662968,
#  'bass': 0.0011616577980963802,
#  'reinforc': 0.00011241849658997227,
#  'repetit': 0.0004496739863598891,
#  'effect': 0.0005620924829498613,
#  'known': 0.0023607884283894176,
#  'groov': 0.0004496739863598891,
#  'lyric': 0.0022483699317994454,
#  'line': 0.001236603462489695,
#  'instrument': 0.0015738589522596117,
#  'earli': 0.005920707487071873,
#  'vers': 0.0006745109795398336,
#  'consist': 0.0005620924829498613,
#  'singl': 0.002210897099602788,
#  'repeat': 0.0004871468185565465,
#  'four': 0.0007119838117364911,
#  'time': 0.0028104624147493066,
#  'wa': 0.013565165255189988,
#  'onli': 0.0010117664693097504,
#  'first': 0.004646631192385521,
#  'decad': 0.0014614404556696394,
#  'current': 0.00022483699317994455,
#  'structur': 0.0005620924829498613,
#  'becam': 0.004084538709435659,
#  'standard': 0.00041220115416323167,
#  'aab': 0.00011241849658997227,
#  'sung': 0.00018736416098328712,
#  'bar': 0.000524619650753204,
#  'next': 0.00029978265757325936,
#  'longer': 0.000262309825376602,
#  'conclud': 7.494566439331484e-05,
#  'last': 0.0004496739863598891,
#  'frequent': 0.0003372554897699168,
#  'took': 0.00037472832196657423,
#  'loos': 0.00022483699317994455,
#  'often': 0.002398261260586075,
#  'relat': 0.0003372554897699168,
#  'racial': 0.00018736416098328712,
#  'discrimin': 7.494566439331484e-05,
#  'challeng': 0.00011241849658997227,
#  'experienc': 0.00018736416098328712,
#  'mani': 0.0031477179045192234,
#  'element': 0.0015738589522596117,
#  'format': 0.00022483699317994455,
#  'use': 0.00509630517874541,
#  'trace': 0.000262309825376602,
#  'back': 0.0008993479727197782,
#  'africa': 0.0004496739863598891,
#  'close': 0.0004496739863598891,
#  'religi': 0.0004496739863598891,
#  'commun': 0.0010867121337030652,
#  'appear': 0.0007869294761298058,
#  'date': 0.00018736416098328712,
#  'slaveri': 0.00014989132878662968,
#  'later': 0.0019111144420295286,
#  'juke': 0.00011241849658997227,
#  'joint': 0.00011241849658997227,
#  'associ': 0.0011991306302930375,
#  'newli': 0.00014989132878662968,
#  'acquir': 0.00011241849658997227,
#  'freedom': 0.00011241849658997227,
#  'former': 0.0006745109795398336,
#  'slave': 0.00018736416098328712,
#  'chronicl': 3.747283219665742e-05,
#  'began': 0.0023607884283894176,
#  'report': 0.00018736416098328712,
#  'dawn': 0.00011241849658997227,
#  'public': 0.0008993479727197782,
#  'sheet': 0.0004871468185565465,
#  'ha': 0.003972120212845687,
#  'sinc': 0.0006745109795398336,
#  'evolv': 0.00041220115416323167,
#  'unaccompani': 7.494566439331484e-05,
#  'vocal': 0.0013864947912763247,
#  'oral': 0.00022483699317994455,
#  'wide': 0.0008244023083264633,
#  'varieti': 0.00041220115416323167,
#  'style': 0.006782582627594994,
#  'subgenr': 0.0011991306302930375,
#  'includ': 0.0037847560518623996,
#  'countri': 0.015176497039646256,
#  'delta': 0.00029978265757325936,
#  'piedmont': 7.494566439331484e-05,
#  'well': 0.0022858427639961027,
#  'urban': 0.0010117664693097504,
#  'chicago': 0.0028479352469459643,
#  'west': 0.0014614404556696394,
#  'coast': 0.0011241849658997227,
#  'world': 0.0013864947912763247,
#  'war': 0.0007119838117364911,
#  'ii': 0.0004496739863598891,
#  'mark': 0.0004871468185565465,
#  'transit': 0.000262309825376602,
#  'acoust': 0.00029978265757325936,
#  'electr': 0.000974293637113093,
#  'open': 0.00041220115416323167,
#  'wider': 0.00029978265757325936,
#  'audienc': 0.001948587274226186,
#  'especi': 0.0007494566439331485,
#  'listen': 0.0007869294761298058,
#  'hybrid': 0.0003372554897699168,
#  'call': 0.002210897099602788,
#  'blend': 0.0006745109795398336,
#  'term': 0.0016488046166529267,
#  'may': 0.000974293637113093,
#  'come': 0.0003372554897699168,
#  'devil': 0.00029978265757325936,
#  'mean': 0.00041220115416323167,
#  'melancholi': 0.00011241849658997227,
#  'sad': 3.747283219665742e-05,
#  'thi': 0.004646631192385521,
#  'sens': 0.00011241849658997227,
#  'georg': 0.0007119838117364911,
#  'colman': 3.747283219665742e-05,
#  'farc': 3.747283219665742e-05,
#  'phrase': 0.00029978265757325936,
#  'deriv': 0.00022483699317994455,
#  'britain': 0.00022483699317994455,
#  'refer': 0.0008993479727197782,
#  'intens': 0.00011241849658997227,
#  'visual': 3.747283219665742e-05,
#  'hallucin': 3.747283219665742e-05,
#  'accompani': 0.0008618751405231207,
#  'sever': 0.001236603462489695,
#  'alcohol': 0.00011241849658997227,
#  'withdraw': 3.747283219665742e-05,
#  'went': 0.0005620924829498613,
#  'lost': 0.00022483699317994455,
#  'came': 0.0007119838117364911,
#  'agit': 3.747283219665742e-05,
#  'depress': 0.00022483699317994455,
#  'drink': 0.00011241849658997227,
#  'surviv': 3.747283219665742e-05,
#  'law': 0.00018736416098328712,
#  'prohibit': 3.747283219665742e-05,
#  'sale': 0.0006745109795398336,
#  'sunday': 7.494566439331484e-05,
#  'though': 0.00037472832196657423,
#  'older': 0.00022483699317994455,
#  'attest': 7.494566439331484e-05,
#  'print': 0.00014989132878662968,
#  'hart': 0.00014989132878662968,
#  'wand': 0.00011241849658997227,
#  'dalla': 0.00018736416098328712,
#  'copyright': 3.747283219665742e-05,
#  'composit': 0.00037472832196657423,
#  'describ': 0.0007494566439331485,
#  'mood': 0.00018736416098328712,
#  'sourc': 0.00029978265757325936,
#  'flat': 0.00011241849658997227,
#  'microton': 3.747283219665742e-05,
#  'oxford': 3.747283219665742e-05,
#  'english': 0.000262309825376602,
#  'dictionari': 7.494566439331484e-05,
#  'claim': 0.00029978265757325936,
#  'led': 0.0005995653151465187,
#  'name': 0.0007869294761298058,
#  'probabl': 0.00014989132878662968,
#  'two': 0.0010867121337030652,
#  'publish': 0.0005995653151465187,
#  'saint': 7.494566439331484e-05,
#  'loui': 0.00037472832196657423,
#  'handi': 0.0003372554897699168,
#  'wrote': 0.0003372554897699168,
#  'adopt': 0.00029978265757325936,
#  'convent': 0.00018736416098328712,
#  'avoid': 3.747283219665742e-05,
#  'monotoni': 3.747283219665742e-05,
#  'three': 0.0006370381473431762,
#  'follow': 0.0011241849658997227,
#  'closer': 7.494566439331484e-05,
#  'rhythmic': 0.0007119838117364911,
#  'talk': 0.00029978265757325936,
#  'melodi': 0.0006370381473431762,
#  'singer': 0.002098478603012816,
#  'voic': 0.0004871468185565465,
#  'hi': 0.0044592670314022335,
#  'person': 0.00029978265757325936,
#  'woe': 7.494566439331484e-05,
#  'harsh': 3.747283219665742e-05,
#  'realiti': 0.00014989132878662968,
#  'love': 0.0007494566439331485,
#  'cruelti': 3.747283219665742e-05,
#  'polic': 0.00011241849658997227,
#  'offic': 7.494566439331484e-05,
#  'oppress': 0.00014989132878662968,
#  'hand': 0.00041220115416323167,
#  'hard': 0.000524619650753204,
#  'suggest': 0.00022483699317994455,
#  'igbo': 0.00011241849658997227,
#  'becaus': 0.0006745109795398336,
#  'reput': 3.747283219665742e-05,
#  'throughout': 0.0006370381473431762,
#  'plantat': 3.747283219665742e-05,
#  'america': 0.0006745109795398336,
#  'melanchol': 7.494566439331484e-05,
#  'outlook': 3.747283219665742e-05,
#  'life': 0.0006745109795398336,
#  'enslav': 7.494566439331484e-05,
#  'troubl': 0.00011241849658997227,
#  'within': 0.001049239301506408,
#  'societi': 0.0003372554897699168,
#  'instanc': 0.00018736416098328712,
#  'blind': 0.00041220115416323167,
#  'lemon': 7.494566439331484e-05,
#  'jefferson': 0.0003372554897699168,
#  'rise': 0.000524619650753204,
#  'high': 0.00029978265757325936,
#  'water': 0.0004871468185565465,
#  'tell': 0.00018736416098328712,
#  'great': 0.0007119838117364911,
#  'mississippi': 0.0005995653151465187,
#  'flood': 0.00018736416098328712,
#  'although': 0.0008244023083264633,
#  'gain': 0.0008993479727197782,
#  'miseri': 3.747283219665742e-05,
#  'could': 0.001049239301506408,
#  'humor': 0.00011241849658997227,
#  'raunchi': 3.747283219665742e-05,
#  'hokum': 3.747283219665742e-05,
#  'celebr': 0.00029978265757325936,
#  'comed': 3.747283219665742e-05,
#  'content': 0.00029978265757325936,
#  'boister': 7.494566439331484e-05,
#  'farcic': 3.747283219665742e-05,
#  'perform': 0.0037472832196657423,
#  'tampa': 0.00018736416098328712,
#  'red': 0.0004496739863598891,
#  'classic': 0.0005995653151465187,
#  'tight': 7.494566439331484e-05,
#  'like': 0.0024357340927827326,
#  'sli': 3.747283219665742e-05,
#  'wordplay': 0.00011241849658997227,
#  'doubl': 0.00011241849658997227,
#  'someon': 7.494566439331484e-05,
#  'coupl': 7.494566439331484e-05,
#  'salaci': 3.747283219665742e-05,
#  'physic': 3.747283219665742e-05,
#  'familiar': 0.00011241849658997227,
#  'sexual': 0.00018736416098328712,
#  'explicit': 7.494566439331484e-05,
#  'dirti': 0.00014989132878662968,
#  'slightli': 3.747283219665742e-05,
#  'simpler': 7.494566439331484e-05,
#  'postwar': 7.494566439331484e-05,
#  'tend': 0.00018736416098328712,
#  'focu': 0.00014989132878662968,
#  'relationship': 0.00011241849658997227,
#  'theme': 0.000524619650753204,
#  'prewar': 0.00011241849658997227,
#  'econom': 0.0004496739863598891,
#  'farm': 3.747283219665742e-05,
#  'gambl': 7.494566439331484e-05,
#  'magic': 0.000262309825376602,
#  'drought': 7.494566439331484e-05,
#  'less': 0.00041220115416323167,
#  'writer': 0.00011241849658997227,
#  'ed': 7.494566439331484e-05,
#  'moral': 0.00011241849658997227,
#  'yoruba': 3.747283219665742e-05,
#  'mytholog': 3.747283219665742e-05,
#  'play': 0.0032976092333058533,
#  'cite': 0.00022483699317994455,
#  'robert': 0.0003372554897699168,
#  'johnson': 0.0004496739863598891,
#  'cross': 0.00041220115416323167,
#  'road': 0.00018736416098328712,
#  'thinli': 3.747283219665742e-05,
#  'veil': 3.747283219665742e-05,
#  'eleggua': 3.747283219665742e-05,
#  'orisha': 3.747283219665742e-05,
#  'charg': 3.747283219665742e-05,
#  'crossroad': 3.747283219665742e-05,
#  'howev': 0.00131154912688301,
#  'christian': 0.0006370381473431762,
#  'influenc': 0.004047065877239002,
#  'far': 0.0004496739863598891,
#  'obviou': 3.747283219665742e-05,
#  'repertoir': 7.494566439331484e-05,
#  'semin': 7.494566439331484e-05,
#  'artist': 0.007194783781758226,
#  'charley': 0.00011241849658997227,
#  'patton': 0.00011241849658997227,
#  'skip': 0.00018736416098328712,
#  'jame': 0.0006745109795398336,
#  'reverend': 7.494566439331484e-05,
#  'gari': 0.00022483699317994455,
#  'davi': 0.00022483699317994455,
#  'willi': 0.0005620924829498613,
#  'exampl': 0.0011241849658997227,
#  'categor': 0.00014989132878662968,
#  'musician': 0.0022858427639961027,
#  'clearli': 7.494566439331484e-05,
#  'belong': 0.00011241849658997227,
#  'cyclic': 3.747283219665742e-05,
#  'mirror': 0.00011241849658997227,
#  'respons': 0.0004871468185565465,
#  'scheme': 0.00018736416098328712,
#  'commonli': 0.00029978265757325936,
#  'found': 0.0011991306302930375,
#  'dure': 0.0033725548976991683,
#  'defin': 0.0003372554897699168,
#  'particular': 0.0005995653151465187,
#  'popular': 0.008356441579854606,
#  'bessi': 0.00011241849658997227,
#  'smith': 0.0004871468185565465,
#  'spread': 0.0004871468185565465,
#  'across': 0.00041220115416323167,
#  'industri': 0.0011991306302930375,
#  'still': 0.0007869294761298058,
#  'consid': 0.0007494566439331485,
#  'long': 0.0006370381473431762,
#  'mind': 7.494566439331484e-05,
#  'big': 0.001049239301506408,
#  'bill': 0.0005995653151465187,
#  'broonzi': 0.00011241849658997227,
#  'key': 0.0007119838117364911,
#  'highway': 3.747283219665742e-05,
#  'ray': 0.0004496739863598891,
#  'charl': 0.00041220115416323167,
#  'sweet': 3.747283219665742e-05,
#  'herbi': 0.00011241849658997227,
#  'hancock': 7.494566439331484e-05,
#  'watermelon': 3.747283219665742e-05,
#  'man': 0.000524619650753204,
#  'idiosyncrat': 3.747283219665742e-05,
#  'number': 0.0015738589522596117,
#  'occasion': 0.00011241849658997227,
#  'sit': 3.747283219665742e-05,
#  'top': 0.0016488046166529267,
#  'walter': 0.00018736416098328712,
#  'vinson': 3.747283219665742e-05,
#  'basic': 0.00022483699317994455,
#  'framework': 7.494566439331484e-05,
#  'reflect': 0.0004871468185565465,
#  'harmon': 0.00029978265757325936,
#  'signatur': 0.00029978265757325936,
#  'typic': 0.0004496739863598891,
#  'set': 0.00022483699317994455,
#  'differ': 0.0007119838117364911,
#  'label': 0.001761223113242899,
#  'roman': 3.747283219665742e-05,
#  'degre': 7.494566439331484e-05,
#  'c': 0.00014989132878662968,
#  'tonic': 7.494566439331484e-05,
#  'f': 0.00011241849658997227,
#  'subdomin': 7.494566439331484e-05,
#  'iv': 0.00014989132878662968,
#  'domin': 0.0007869294761298058,
#  'v': 3.747283219665742e-05,
#  'turnaround': 7.494566439331484e-05,
#  'begin': 0.0007119838117364911,
#  'gener': 0.0015363861200629544,
#  'beat': 0.0018736416098328712,
#  'tenth': 3.747283219665742e-05,
#  'final': 7.494566439331484e-05,
#  'given': 0.00018736416098328712,
#  'instrumentalist': 7.494566439331484e-05,
#  'break': 0.000974293637113093,
#  'harmoni': 0.00029978265757325936,
#  'extrem': 7.494566439331484e-05,
#  'complex': 0.00022483699317994455,
#  'sometim': 0.0005620924829498613,
#  'defi': 3.747283219665742e-05,
#  'analysi': 7.494566439331484e-05,
#  'much': 0.0007869294761298058,
#  'seventh': 0.00041220115416323167,
#  'interv': 0.00011241849658997227,
#  'characterist': 0.00029978265757325936,
#  'popularli': 7.494566439331484e-05,
#  'seven': 0.00018736416098328712,
#  'add': 0.00018736416098328712,
#  'frequenc': 7.494566439331484e-05,
#  'ratio': 7.494566439331484e-05,
#  'fundament': 3.747283219665742e-05,
#  'ani': 0.00037472832196657423,
#  'western': 0.002023532938619501,
#  'diaton': 3.747283219665742e-05,
#  'conveni': 3.747283219665742e-05,
#  'necess': 3.747283219665742e-05,
#  'approxim': 3.747283219665742e-05,
#  'minor': 0.000262309825376602,
#  'distinguish': 0.00011241849658997227,
#  'major': 0.0014614404556696394,
#  'special': 0.00014989132878662968,
#  'bent': 3.747283219665742e-05,
#  'tone': 0.00029978265757325936,
#  'replac': 0.00029978265757325936,
#  'natur': 0.000524619650753204,
#  'ad': 0.00029978265757325936,
#  'case': 0.00014989132878662968,
#  'fourth': 0.00018736416098328712,
#  'intermitt': 3.747283219665742e-05,
#  'revolutionari': 3.747283219665742e-05,
#  'aspect': 0.00022483699317994455,
#  'even': 0.000974293637113093,
#  'togeth': 0.0004871468185565465,
#  'directli': 0.000262309825376602,
#  'adjac': 3.747283219665742e-05,
#  'second': 0.0007869294761298058,
#  'slide': 0.0003372554897699168,
#  'similar': 0.0006745109795398336,
#  'grace': 0.00011241849658997227,
#  'allow': 0.0003372554897699168,
#  'moment': 7.494566439331484e-05,
#  'express': 0.0005620924829498613,
#  'cadenc': 0.00011241849658997227,
#  'embellish': 3.747283219665742e-05,
#  'central': 3.747283219665742e-05,
#  'role': 0.0007494566439331485,
#  'swing': 0.0005995653151465187,
#  'simplest': 3.747283219665742e-05,
#  'clearest': 3.747283219665742e-05,
#  'r': 0.0004871468185565465,
#  'b': 0.000974293637113093,
#  'wave': 0.00037472832196657423,
#  'start': 0.0013864947912763247,
#  'riff': 0.00011241849658997227,
#  'string': 0.0004496739863598891,
#  'guitar': 0.002398261260586075,
#  'drum': 0.0016113317844562692,
#  'feel': 0.0003372554897699168,
#  'creat': 0.0018736416098328712,
#  'dow': 0.00011241849658997227,
#  'da': 0.00022483699317994455,
#  'dump': 0.00011241849658997227,
#  'uneven': 3.747283219665742e-05,
#  'swung': 3.747283219665742e-05,
#  'eighth': 3.747283219665742e-05,
#  'steadi': 7.494566439331484e-05,
#  'stepwis': 3.747283219665742e-05,
#  'quarter': 3.747283219665742e-05,
#  'motion': 7.494566439331484e-05,
#  'sixth': 0.00018736416098328712,
#  'antonio': 7.494566439331484e-05,
#  'maggio': 3.747283219665742e-05,
#  'got': 0.0004496739863598891,
#  'word': 0.000262309825376602,
#  'memphi': 0.000524619650753204,
#  'year': 0.002061005770816158,
#  'record': 0.010529865847260737,
#  'mami': 7.494566439331484e-05,
#  'rendit': 0.00014989132878662968,
#  'perri': 7.494566439331484e-05,
#  'bradford': 3.747283219665742e-05,
#  'crazi': 7.494566439331484e-05,
#  'earlier': 0.00022483699317994455,
#  'poorli': 3.747283219665742e-05,
#  'document': 0.00014989132878662968,
#  'partli': 0.00011241849658997227,
#  'academ': 7.494566439331484e-05,
#  'circl': 7.494566439331484e-05,
#  'low': 0.00011241849658997227,
#  'rate': 0.00011241849658997227,
#  'literaci': 3.747283219665742e-05,
#  'among': 0.001049239301506408,
#  'rural': 0.0006370381473431762,
#  'southern': 0.001236603462489695,
#  'texa': 0.0005620924829498613,
#  'written': 0.00041220115416323167,
#  'peabodi': 3.747283219665742e-05,
#  'mention': 0.00018736416098328712,
#  'clarksdal': 3.747283219665742e-05,
#  'gate': 0.00018736416098328712,
#  'thoma': 0.0003372554897699168,
#  'observ': 7.494566439331484e-05,
#  'coincid': 0.00014989132878662968,
#  'recollect': 3.747283219665742e-05,
#  'jelli': 3.747283219665742e-05,
#  'morton': 0.00011241849658997227,
#  'said': 0.0004871468185565465,
#  'heard': 0.0005620924829498613,
#  'new': 0.0052087236753353815,
#  'orlean': 0.00014989132878662968,
#  'rainey': 0.00011241849658997227,
#  'rememb': 3.747283219665742e-05,
#  'hear': 0.000262309825376602,
#  'missouri': 0.00011241849658997227,
#  'tutwil': 3.747283219665742e-05,
#  'extens': 0.00014989132878662968,
#  'research': 0.00018736416098328712,
#  'howard': 0.00014989132878662968,
#  'odum': 7.494566439331484e-05,
#  'antholog': 3.747283219665742e-05,
#  'lafayett': 3.747283219665742e-05,
#  'counti': 7.494566439331484e-05,
#  'newton': 0.000262309825376602,
#  'georgia': 0.00041220115416323167,
#  'noncommerci': 3.747283219665742e-05,
#  'paul': 0.00041220115416323167,
#  'oliv': 7.494566439331484e-05,
#  'made': 0.000974293637113093,
#  'purpos': 0.00014989132878662968,
#  'veri': 0.0005620924829498613,
#  'avail': 0.0004496739863598891,
#  'lawrenc': 0.00014989132878662968,
#  'gellert': 3.747283219665742e-05,
#  'gordon': 0.00014989132878662968,
#  'head': 7.494566439331484e-05,
#  'archiv': 3.747283219665742e-05,
#  'librari': 0.00011241849658997227,
#  'congress': 7.494566439331484e-05,
#  'successor': 7.494566439331484e-05,
#  'john': 0.001049239301506408,
#  'lomax': 0.00011241849658997227,
#  'son': 0.00022483699317994455,
#  'alan': 0.000262309825376602,
#  'larg': 0.0010117664693097504,
#  'testifi': 3.747283219665742e-05,
#  'huge': 0.00022483699317994455,
#  'ring': 0.00011241849658997227,
#  'exist': 0.00022483699317994455,
#  'befor': 0.0006370381473431762,
#  'lead': 0.0005620924829498613,
#  'belli': 3.747283219665742e-05,
#  'henri': 0.00011241849658997227,
#  'show': 0.0014239676234729822,
#  'distinct': 0.0006370381473431762,
#  'social': 0.0008618751405231207,
#  'reason': 0.00029978265757325936,
#  'fulli': 7.494566439331484e-05,
#  'emancip': 0.00011241849658997227,
#  'act': 0.0008993479727197782,
#  'period': 0.0008618751405231207,
#  'establish': 0.0006370381473431762,
#  'place': 0.0006745109795398336,
#  'black': 0.002210897099602788,
#  'danc': 0.002735516750355992,
#  'day': 0.0005995653151465187,
#  'correspond': 3.747283219665742e-05,
#  'sharecrop': 3.747283219665742e-05,
#  'agricultur': 3.747283219665742e-05,
#  'product': 0.0010867121337030652,
#  'expans': 0.00011241849658997227,
#  'railroad': 7.494566439331484e-05,
#  'scholar': 7.494566439331484e-05,
#  'move': 0.0008993479727197782,
#  'group': 0.002135951435209473,
#  'individu': 0.00022483699317994455,
#  'argu': 0.00011241849658997227,
#  'peopl': 0.0016488046166529267,
#  'accord': 0.0005620924829498613,
#  'levin': 7.494566439331484e-05,
#  'direct': 0.00029978265757325936,
#  'nation': 0.0012740762946863524,
#  'ideolog': 3.747283219665742e-05,
#  'emphasi': 7.494566439331484e-05,
#  'upon': 0.00022483699317994455,
#  'booker': 0.00011241849658997227,
#  'washington': 0.00018736416098328712,
#  'teach': 7.494566439331484e-05,
#  'psycholog': 3.747283219665742e-05,
#  'accultur': 3.747283219665742e-05,
#  'way': 0.0008618751405231207,
#  'would': 0.0018736416098328712,
#  'imposs': 7.494566439331484e-05,
#  'hardli': 3.747283219665742e-05,
#  'surpris': 0.00011241849658997227,
#  'secular': 0.00014989132878662968,
#  'shape': 0.00022483699317994455,
#  'idiosyncrasi': 7.494566439331484e-05,
#  'present': 0.00037472832196657423,
#  'creation': 0.00018736416098328712,
#  'modern': 0.0006370381473431762,
#  'function': 3.747283219665742e-05,
#  'without': 0.000262309825376602,
#  'unbound': 3.747283219665742e-05,
#  'formal': 0.00014989132878662968,
#  'expand': 0.00022483699317994455,
#  'solo': 0.0011991306302930375,
#  'laden': 3.747283219665742e-05,
#  'emot': 0.00018736416098328712,
#  'import': 0.0013490219590796672,
#  'region': 0.0008618751405231207,
#  'variat': 0.00014989132878662968,
#  'seen': 0.00037472832196657423,
#  'base': 0.0011241849658997227,
#  'transform': 0.00018736416098328712,
#  'interplay': 3.747283219665742e-05,
#  'bear': 7.494566439331484e-05,
#  'resembl': 3.747283219665742e-05,
#  'melod': 0.00029978265757325936,
#  'griot': 0.00014989132878662968,
#  'faint': 3.747283219665742e-05,
#  'tenuou': 3.747283219665742e-05,
#  'addit': 0.0004871468185565465,
#  'theori': 3.747283219665742e-05,
#  'might': 0.00014989132878662968,
#  'nativ': 0.00029978265757325936,
#  'pow': 3.747283219665742e-05,
#  'wow': 3.747283219665742e-05,
#  'identifi': 0.00011241849658997227,
#  'ancestor': 3.747283219665742e-05,
#  'predat': 7.494566439331484e-05,
#  'negro': 0.00018736416098328712,
#  'compos': 0.0006370381473431762,
#  'samuel': 3.747283219665742e-05,
#  'suit': 7.494566439331484e-05,
#  'piano': 0.000524619650753204,
#  'contain': 0.000262309825376602,
#  'diddley': 0.00011241849658997227,
#  'bow': 3.747283219665742e-05,
#  'homemad': 3.747283219665742e-05,
#  'twentieth': 7.494566439331484e-05,
#  'banjo': 0.00037472832196657423,
#  'help': 0.0011241849658997227,
#  'transfer': 3.747283219665742e-05,
#  'techniqu': 0.0005620924829498613,
#  'vocabulari': 3.747283219665742e-05,
#  'seem': 7.494566439331484e-05,
#  'halam': 3.747283219665742e-05,
#  'akont': 3.747283219665742e-05,
#  'wolof': 3.747283219665742e-05,
#  'fula': 3.747283219665742e-05,
#  'mandinka': 3.747283219665742e-05,
#  'quit': 0.00018736416098328712,
#  'margin': 0.00018736416098328712,
#  'limit': 0.00022483699317994455,
#  'papa': 3.747283219665742e-05,
#  'charli': 0.0004496739863598891,
#  'jackson': 0.0004496739863598891,
#  'gu': 7.494566439331484e-05,
#  'cannon': 7.494566439331484e-05,
#  'ethiopian': 3.747283219665742e-05,
#  'air': 0.00018736416098328712,
#  'minstrel': 3.747283219665742e-05,
#  'ragtim': 0.00022483699317994455,
#  'better': 0.00011241849658997227,
#  'preserv': 7.494566439331484e-05,
#  'aros': 0.00014989132878662968,
#  'market': 0.0006370381473431762,
#  'categori': 0.000262309825376602,
#  'race': 0.00022483699317994455,
#  'hillbilli': 0.0004496739863598891,
#  'sell': 0.000524619650753204,
#  'respect': 0.00041220115416323167,
#  'clear': 7.494566439331484e-05,
#  'divis': 0.00011241849658997227,
#  'except': 7.494566439331484e-05,
#  'ethnic': 0.00011241849658997227,
#  'incorrectli': 3.747283219665742e-05,
#  'compani': 0.0005620924829498613,
#  'musicologist': 3.747283219665742e-05,
#  'attempt': 0.00029978265757325936,
#  'narrowli': 3.747283219665742e-05,
#  'certain': 0.000262309825376602,
#  'thought': 0.00022483699317994455,
#  'simpli': 0.00014989132878662968,
#  'notabl': 0.0007869294761298058,
#  'share': 0.00011241849658997227,
#  'themselv': 0.00037472832196657423,
#  'songster': 7.494566439331484e-05,
#  'rather': 0.00022483699317994455,
#  'notion': 7.494566439331484e-05,
#  'separ': 0.000262309825376602,
#  'migrat': 0.000262309825376602,
#  'countrysid': 0.00011241849658997227,
#  'area': 0.00041220115416323167,
#  'simultan': 7.494566439331484e-05,
#  'code': 3.747283219665742e-05,
#  'design': 0.00014989132878662968,
#  'go': 0.0004496739863598891,
#  'middl': 0.000262309825376602,
#  'sing': 0.0009368208049164356,
#  'hymn': 0.0006745109795398336,
#  'isaac': 7.494566439331484e-05,
#  'watt': 7.494566439331484e-05,
#  'definit': 0.00014989132878662968,
#  'counterpart': 0.00018736416098328712,
#  'depend': 7.494566439331484e-05,
#  'sin': 3.747283219665742e-05,
#  'therefor': 7.494566439331484e-05,
#  'segreg': 3.747283219665742e-05,
#  'gospel': 0.0037847560518623996,
#  'preacher': 3.747283219665742e-05,
#  'nevertheless': 3.747283219665742e-05,
#  'compat': 7.494566439331484e-05,
#  'produc': 0.002735516750355992,
#  'deal': 0.00029978265757325936,
#  'precipit': 3.747283219665742e-05,
#  'tin': 0.00011241849658997227,
#  'pan': 0.00018736416098328712,
#  'alley': 0.00014989132878662968,
#  'babi': 0.00011241849658997227,
#  'seal': 0.00011241849658997227,
#  'arrang': 0.000262309825376602,
#  'arti': 3.747283219665742e-05,
#  'matthew': 3.747283219665742e-05,
#  'train': 0.00014989132878662968,
#  'transcrib': 3.747283219665742e-05,
#  'orchestr': 0.00011241849658997227,
#  'almost': 0.000524619650753204,
#  'symphon': 3.747283219665742e-05,
#  'band': 0.003072772240125909,
#  'prolif': 0.00011241849658997227,
#  'father': 0.000262309825376602,
#  'fusion': 0.0005620924829498613,
#  'merger': 3.747283219665742e-05,
#  'facilit': 0.00011241849658997227,
#  'cuban': 0.0003372554897699168,
#  'habanera': 3.747283219665742e-05,
#  'reach': 0.0008618751405231207,
#  'via': 0.00011241849658997227,
#  'femal': 0.0008993479727197782,
#  'inform': 7.494566439331484e-05,
#  'entertain': 0.0005620924829498613,
#  'theater': 0.000262309825376602,
#  'organ': 0.0003372554897699168,
#  'owner': 7.494566439331484e-05,
#  'nightclub': 0.00014989132878662968,
#  'cotton': 3.747283219665742e-05,
#  'club': 0.002210897099602788,
#  'along': 0.0004496739863598891,
#  'beal': 3.747283219665742e-05,
#  'street': 0.0006370381473431762,
#  'corpor': 0.00011241849658997227,
#  'okeh': 0.00011241849658997227,
#  'paramount': 3.747283219665742e-05,
#  'grew': 0.0004496739863598891,
#  'bo': 0.00011241849658997227,
#  'carter': 0.0003372554897699168,
#  'jimmi': 0.00041220115416323167,
#  'rodger': 0.00029978265757325936,
#  'lonni': 7.494566439331484e-05,
#  'blake': 0.00014989132878662968,
#  'sylvest': 3.747283219665742e-05,
#  'weaver': 7.494566439331484e-05,
#  'fret': 3.747283219665742e-05,
#  'knife': 7.494566439331484e-05,
#  'blade': 3.747283219665742e-05,
#  'neck': 3.747283219665742e-05,
#  'bottl': 7.494566439331484e-05,
#  'polish': 0.00018736416098328712,
#  'citi': 0.002061005770816158,
#  'improvis': 0.000262309825376602,
#  'either': 0.00011241849658997227,
#  'vari': 0.000262309825376602,
#  'rootsi': 3.747283219665742e-05,
#  'spars': 3.747283219665742e-05,
#  'passion': 0.00011241849658997227,
#  'combin': 0.0007494566439331485,
#  'influenti': 0.0005995653151465187,
#  'predecessor': 7.494566439331484e-05,
#  'hous': 0.007906767593494715,
#  'mctell': 3.747283219665742e-05,
#  'boy': 0.000974293637113093,
#  'fuller': 3.747283219665742e-05,
#  'southeastern': 7.494566439331484e-05,
#  'delic': 3.747283219665742e-05,
#  'elabor': 0.00022483699317994455,
#  'fingerpick': 3.747283219665742e-05,
#  'curley': 3.747283219665742e-05,
#  'barbecu': 3.747283219665742e-05,
#  'bob': 0.0004496739863598891,
#  'hick': 7.494566439331484e-05,
#  'kokomo': 3.747283219665742e-05,
#  'arnold': 0.00022483699317994455,
#  'repres': 0.00022483699317994455,
#  'live': 0.0007119838117364911,
#  'near': 0.00018736416098328712,
#  'tennesse': 0.00037472832196657423,
#  'jug': 0.00011241849658997227,
#  'stomper': 3.747283219665742e-05,
#  'frank': 0.00014989132878662968,
#  'stoke': 3.747283219665742e-05,
#  'sleepi': 3.747283219665742e-05,
#  'est': 3.747283219665742e-05,
#  'wilkin': 3.747283219665742e-05,
#  'joe': 0.00037472832196657423,
#  'mccoy': 7.494566439331484e-05,
#  'casey': 3.747283219665742e-05,
#  'weldon': 3.747283219665742e-05,
#  'minni': 7.494566439331484e-05,
#  'unusu': 0.00029978265757325936,
#  'washboard': 3.747283219665742e-05,
#  'fiddl': 0.00022483699317994455,
#  'kazoo': 3.747283219665742e-05,
#  'mandolin': 3.747283219665742e-05,
#  'famou': 0.00037472832196657423,
#  'virtuoso': 7.494566439331484e-05,
#  'pianist': 0.00014989132878662968,
#  'slim': 0.0003372554897699168,
#  'career': 0.0008993479727197782,
#  'smoother': 3.747283219665742e-05,
#  'late': 0.00262309825376602,
#  'movement': 0.0012740762946863524,
#  'codifi': 3.747283219665742e-05,
#  'local': 0.0008244023083264633,
#  'immedi': 3.747283219665742e-05,
#  'adapt': 3.747283219665742e-05,
#  'larger': 0.00041220115416323167,
#  'aesthet': 7.494566439331484e-05,
#  'vaudevil': 0.00018736416098328712,
#  'lucil': 0.00011241849658997227,
#  'victoria': 3.747283219665742e-05,
#  'spivey': 3.747283219665742e-05,
#  'sold': 0.0004871468185565465,
#  'copi': 0.0003372554897699168,
#  'month': 0.00011241849658997227,
#  'mother': 0.00011241849658997227,
#  'sang': 0.00018736416098328712,
#  'center': 0.00029978265757325936,
#  'perhap': 0.00011241849658997227,
#  'order': 0.000262309825376602,
#  'project': 0.00018736416098328712,
#  'easili': 0.00014989132878662968,
#  'room': 0.00014989132878662968,
#  'artistri': 3.747283219665742e-05,
#  'bend': 7.494566439331484e-05,
#  'stretch': 3.747283219665742e-05,
#  'beauti': 0.00014989132878662968,
#  'power': 0.00022483699317994455,
#  'contralto': 3.747283219665742e-05,
#  'accommod': 7.494566439331484e-05,
#  'interpret': 7.494566439331484e-05,
#  'unsurpass': 3.747283219665742e-05,
#  'hegamin': 3.747283219665742e-05,
#  'woman': 0.00018736416098328712,
#  'nonetheless': 3.747283219665742e-05,
#  'purchas': 7.494566439331484e-05,
#  'buyer': 3.747283219665742e-05,
#  'blueswomen': 3.747283219665742e-05,
#  'contribut': 0.0004871468185565465,
#  'increas': 0.0004496739863598891,
#  'alter': 0.00014989132878662968,
#  'impact': 0.00022483699317994455,
#  'dramat': 3.747283219665742e-05,
#  'groan': 3.747283219665742e-05,
#  'moan': 3.747283219665742e-05,
#  'wail': 3.747283219665742e-05,
#  'women': 0.00018736416098328712,
#  'thu': 0.00018736416098328712,
#  'chang': 0.0004496739863598891,
#  'type': 0.0003372554897699168,
#  'broadway': 0.00018736416098328712,
#  'torch': 3.747283219665742e-05,
#  'eventu': 0.0005620924829498613,
#  'male': 0.00011241849658997227,
#  'era': 0.0006745109795398336,
#  'leroy': 7.494566439331484e-05,
#  'carr': 0.00011241849658997227,
#  'bluebird': 3.747283219665742e-05,
#  'wizard': 3.747283219665742e-05,
#  'scrapper': 3.747283219665742e-05,
#  'blackwel': 3.747283219665742e-05,
#  'continu': 0.0008993479727197782,
#  'brown': 0.00037472832196657423,
#  'nat': 3.747283219665742e-05,
#  'king': 0.0006370381473431762,
#  'cole': 0.00011241849658997227,
#  'anoth': 0.0008618751405231207,
#  'small': 0.00014989132878662968,
#  'combo': 3.747283219665742e-05,
#  'regular': 3.747283219665742e-05,
#  'figur': 0.00029978265757325936,
#  'ostinato': 3.747283219665742e-05,
#  'shift': 0.00022483699317994455,
#  'level': 0.00018736416098328712,
#  'left': 0.00011241849658997227,
#  'trill': 3.747283219665742e-05,
#  'decor': 3.747283219665742e-05,
#  'right': 0.000524619650753204,
#  'pioneer': 0.001049239301506408,
#  'yancey': 3.747283219665742e-05,
#  'trio': 0.00022483699317994455,
#  'albert': 0.00011241849658997227,
#  'ammon': 3.747283219665742e-05,
#  'pete': 0.00018736416098328712,
#  'mead': 3.747283219665742e-05,
#  'lux': 3.747283219665742e-05,
#  'lewi': 0.00029978265757325936,
#  'clarenc': 0.00011241849658997227,
#  'pine': 3.747283219665742e-05,
#  'earl': 0.00029978265757325936,
#  'hine': 3.747283219665742e-05,
#  'link': 7.494566439331484e-05,
#  'propuls': 3.747283219665742e-05,
#  'armstrong': 7.494566439331484e-05,
#  'trumpet': 0.00014989132878662968,
#  'smooth': 0.00022483699317994455,
#  'louisiana': 0.00011241849658997227,
#  'professor': 0.00014989132878662968,
#  'longhair': 3.747283219665742e-05,
#  'recent': 0.00029978265757325936,
#  'territori': 3.747283219665742e-05,
#  'oper': 0.00014989132878662968,
#  'kansa': 0.00011241849658997227,
#  'benni': 3.747283219665742e-05,
#  'moten': 3.747283219665742e-05,
#  'orchestra': 0.000262309825376602,
#  'jay': 0.00018736416098328712,
#  'mcshann': 3.747283219665742e-05,
#  'count': 0.00011241849658997227,
#  'basi': 0.00018736416098328712,
#  'concentr': 3.747283219665742e-05,
#  'one': 0.0036723375552724273,
#  'jump': 0.000262309825376602,
#  'jumpin': 3.747283219665742e-05,
#  'woodsid': 3.747283219665742e-05,
#  'rush': 0.00014989132878662968,
#  'sent': 3.747283219665742e-05,
#  'yesterday': 3.747283219665742e-05,
#  'tune': 0.0006370381473431762,
#  'glenn': 7.494566439331484e-05,
#  'miller': 0.00014989132878662968,
#  'boogi': 0.001049239301506408,
#  'woogi': 0.00018736416098328712,
#  'strongli': 0.00018736416098328712,
#  'saxophon': 0.00011241849658997227,
#  'brass': 0.00014989132878662968,
#  'section': 0.0006745109795398336,
#  'jazzi': 0.00014989132878662968,
#  'declamatori': 3.747283219665742e-05,
#  'jordan': 3.747283219665742e-05,
#  'turner': 7.494566439331484e-05,
#  'walker': 0.00011241849658997227,
#  'california': 0.00022483699317994455,
#  'success': 0.0033350820655025106,
#  'à': 3.747283219665742e-05,
#  'la': 0.00022483699317994455,
#  'scene': 0.002135951435209473,
#  'lo': 0.0005995653151465187,
#  'angel': 0.0005620924829498613,
#  'driven': 0.00011241849658997227,
#  'crisi': 7.494566439331484e-05,
#  'boom': 0.00018736416098328712,
#  'induc': 3.747283219665742e-05,
#  'massiv': 3.747283219665742e-05,
#  'popul': 0.0003372554897699168,
#  'signific': 0.0005995653151465187,
#  'real': 7.494566439331484e-05,
#  'incom': 7.494566439331484e-05,
#  'migrant': 3.747283219665742e-05,
#  'constitut': 7.494566439331484e-05,
#  'initi': 0.0003372554897699168,
#  'rapidli': 0.00014989132878662968,
#  'billboard': 0.0013490219590796672,
#  'magazin': 0.00041220115416323167,
#  'chart': 0.003035299407929251,
#  'strategi': 0.00011241849658997227,
#  'trend': 0.00037472832196657423,
#  'amplif': 7.494566439331484e-05,
#  'commerci': 0.001049239301506408,
#  ...}

# %%
# There are only a few words with high probablities, while most of the words have low probablities
word_lst = []
for word in sorted(word_prob, key=word_prob.get, reverse=True):
    temp = (word, word_prob[word])
    word_lst.append(temp)
x, y = zip(*word_lst) # unpack a list of pairs into two tuples
plt.hist(y, bins=100)
plt.title('Figure 5: Probability Distribution of the Whole Corpora')
plt.xlabel('Words')
plt.ylabel('Probability')
plt.show()

# %%
# Get probability distribution for the House Music Corpus
# Again, only a few words have high probabilities, while most words have low probabilities
total_count1 = 0
word_prob1 = {}
for k, v in music_fdist1.items():
    total_count1 += v
for k, v in music_fdist1.items():
    word_prob1[k] = v/total_count

word_lst = []
for word in sorted(word_prob, key=word_prob.get, reverse=True):
    temp = (word, word_prob[word])
    word_lst.append(temp)
x, y = zip(*word_lst1) # unpack a list of pairs into two tuples
plt.hist(y, bins=100)
plt.title('Figure 6: Probability Distribution of the House Music Corpus')
plt.xlabel('Words')
plt.ylabel('Probability')
plt.show()

# %%
# Get conditional frequency distribution
music_cfdist = nltk.ConditionalFreqDist(((len(w), w) for w in music_df[\
                                     'normalized_tokens'].sum()))
#print the number of words
print(music_cfdist.N())
print(music_cfdist.keys())
# Out:
# 26686
# dict_keys([4, 5, 6, 7, 8, 3, 9, 10, 2, 11, 12, 1, 15, 13, 14, 17, 16])

# %%
# Since there are too many words with low frequency, I would plot the
# conditional plot for words with high frequency
music_cfdist[11].plot(title="Figure 7: Frequency Distribution Plot for Words with Length=11")
music_cfdist[12].plot(title="Figure 8: Frequency Distribution Plot for Words with Length=12")

# %%
# Define a function to get word clouds or Wordls
def get_wc(df_obj, filename):
    wc = wordcloud.WordCloud(background_color="white", max_words=500, \
                             width= 1000, height = 1000, mode ='RGBA', \
                             scale=.5).generate(' '.join(df_obj))
    plt.imshow(wc)
    plt.axis("off")
    plt.title("Figure: Word Cloud for {} music".format(filename))
    plt.savefig('{}_word_cloud.jpg'.format(filename), format = 'jpg')
    plt.show()
# Get Word Cloud or Wordl
get_wc(music_df['normalized_tokens'].sum(), 'all_type')
get_wc(music_df['normalized_tokens'].iloc[0], 'blues')
get_wc(music_df['normalized_tokens'].iloc[1], 'house')
get_wc(music_df['normalized_tokens'].iloc[2], 'gospel')
get_wc(music_df['normalized_tokens'].iloc[3], 'hip_pop')
get_wc(music_df['normalized_tokens'].iloc[4], 'country')
get_wc(music_df['normalized_tokens'].iloc[5], 'popular')

# %% [markdown]
# The above Word Clouds show the most frequently used or most critical words for every types of music are different. Some music types have relatively dispersed distribution of important words in Wikipedia description, such as Gospel Music, Country Music, and Popular Music. And they have a lot important words, compared to the other three types of music. This pattern suggests that the meaning of these three types of music could be more complicated than the other three, and that their targeted audience might be more complex than the other three.

# %% [markdown]
# # Collocations

# %% [markdown]
# As illustrated above, we might want to find significant bigrams (two-word phrases), trigrams (three-word phrases), n-grams (*n*-word phrases) or skip-grams (noncontinguous 'phrases' with skip-length *n*). We will begin with the [`nltk.collocations.BigramCollocationFinder`](http://www.nltk.org/api/nltk.html?highlight=bigramcollocationfinder#nltk.collocations.BigramCollocationFinder) class, which can be given raw lists of strings with the `from_words()` method. By default it only looks at continuous bigrams but there is an option (`window_size`) to allow skip-grams.

# %%
whBigrams = nltk.collocations.BigramCollocationFinder.from_words(whReleases['normalized_tokens'].sum())
print("There are {} bigrams in the finder".format(whBigrams.N))
# Out:
# There are 1999 bigrams in the finder

# %% [markdown]
# To compare the bigrams we need to tell nltk what our score function is. Initially, we will look at the raw counts.

# %%
def bigramScoring(count, wordsTuple, total):
    return count

print(whBigrams.nbest(bigramScoring, 10))
# Out:
# [('rhode', 'island'), ('presid', 'bush'), ('sheldon', 'whitehous'), ('stem', 'cell'), ('whitehous', 'said'), ('bush', 'administr'), ('american', 'peopl'), ('bring', 'troop'), ('senat', 'sheldon'), ('troop', 'home')]

# %% [markdown]
# One note about how `BigramCollocationFinder` works. It doesn't use the strings internally.

# %%
birgramScores = []

def bigramPrinting(count, wordsTuple, total):
    global birgramScores
    birgramScores.append("The first word is:  {}, The second word is: {}".format(*wordsTuple))
    #Returns None so all the tuples are considered to have the same rank

whBigrams.nbest(bigramPrinting, 10)
print('\n'.join(birgramScores[:10]))
# Out:
# The first word is:  40, The second word is: 4
# The first word is:  4, The second word is: 2
# The first word is:  2, The second word is: 2
# The first word is:  2, The second word is: 2
# The first word is:  2, The second word is: 2
# The first word is:  2, The second word is: 12
# The first word is:  12, The second word is: 12
# The first word is:  12, The second word is: 9
# The first word is:  9, The second word is: 4
# The first word is:  4, The second word is: 2

# %% [markdown]
# The words are each given numeric IDs and there is a dictionary that maps the IDs to the words they represent. This is a common performance optimization.
#
# Two words can appear together by chance. Recall from  Manning and Schütze's textbook that a $t-value can be computed for each bigram to see how significant the association is. You may also want to try computing the $\chi^2$, likelihood ratio, and pointwise mutual information statistics.

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
whBigrams.score_ngrams(bigram_measures.likelihood_ratio)[:40]
# other options include student_t, chi_sq, likelihood_ratio, pmi
# Out:
# [(('rhode', 'island'), 223.9860316954852),
#  (('stem', 'cell'), 146.69971583676724),
#  (('presid', 'bush'), 124.78339903371594),
#  (('sheldon', 'whitehous'), 97.83057167237577),
#  (('unit', 'state'), 63.7408597571739),
#  (('whitehous', 'said'), 50.85365409523493),
#  (('jack', 'reed'), 46.61449955206517),
#  (('honor', 'societi'), 45.00623576992483),
#  (('american', 'peopl'), 44.4949166648486),
#  (('bring', 'troop'), 43.29082241816299),
#  (('bush', 'administr'), 42.73672706610401),
#  (('cell', 'research'), 41.25934273451902),
#  (('youth', 'program'), 38.276119099832265),
#  (('troop', 'home'), 36.87601441962918),
#  (('come', 'home'), 36.661589434392276),
#  (('senat', 'sheldon'), 36.08708619238288),
#  (('epw', 'committe'), 34.42122395939712),
#  (('potenti', 'close'), 33.7794434582587),
#  (('budget', 'resolut'), 32.192797473966614),
#  (('district', 'columbia'), 31.62701894759353),
#  (('humpti', 'dumpti'), 31.62701894759353),
#  (('jose', 'socrat'), 31.62701894759353),
#  (('prime', 'minist'), 31.62701894759353),
#  (('weaver', 'cove'), 31.62701894759353),
#  (('chang', 'cours'), 31.55001446652071),
#  (('confirm', 'hear'), 27.80793393782465),
#  (('harm', 'way'), 27.80793393782465),
#  (('interest', 'payment'), 27.80793393782465),
#  (('trillion', 'foregon'), 27.80793393782465),
#  (('foregon', 'surplus'), 26.081841503113964),
#  (('senat', 'youth'), 25.938248175532106),
#  (('consul', 'provid'), 25.75753014835219),
#  (('year', 'ago'), 25.07814446954526),
#  (('high', 'school'), 24.896902277500963),
#  (('reconsid', 'potenti'), 24.896902277500963),
#  (('one', 'thing'), 23.98985093210625),
#  (('circuit', 'court'), 23.988848928055774),
#  (('cost', 'america'), 23.988848928055774),
#  (('general', 'counsel'), 23.988848928055774),
#  (('misguid', 'polici'), 23.988848928055774)]

# %% [markdown]
# There are a few other available measures

# %%
[s for s in dir(bigram_measures) if s[0] != '_']
# Out:
# ['chi_sq',
#  'dice',
#  'fisher',
#  'jaccard',
#  'likelihood_ratio',
#  'mi_like',
#  'phi_sq',
#  'pmi',
#  'poisson_stirling',
#  'raw_freq',
#  'student_t']

# %% [markdown]
# We can also look at trigrams

# %%
trigram_measures = nltk.collocations.TrigramAssocMeasures()
whTrigrams = nltk.collocations.TrigramCollocationFinder.from_words(whReleases['normalized_tokens'].sum())
whTrigrams.score_ngrams(trigram_measures.student_t)[:20]
# Out:
# [(('bring', 'troop', 'home'), 2.449202865677887),
#  (('senat', 'sheldon', 'whitehous'), 2.4481166557834917),
#  (('stem', 'cell', 'research'), 2.2359229352888974),
#  (('whitehous', 'said', 'today'), 1.9987987990993996),
#  (('jack', 'reed', 'sheldon'), 1.7319953264758123),
#  (('senat', 'youth', 'program'), 1.7319901251233376),
#  (('unit', 'state', 'senat'), 1.73173525885207),
#  (('new', 'direct', 'iraq'), 1.7316624399174225),
#  (('reed', 'sheldon', 'whitehous'), 1.7314959966382275),
#  (('sheldon', 'whitehous', 'said'), 1.7309411857075774),
#  (('trillion', 'foregon', 'surplus'), 1.414209315486583),
#  (('reconsid', 'potenti', 'close'), 1.4142064842289084),
#  (('sent', 'clear', 'messag'), 1.414205599460885),
#  (('today', 'confirm', 'hear'), 1.4141976365486753),
#  (('select', 'committe', 'intellig'), 1.4141965748270473),
#  (('general', 'david', 'petraeus'), 1.4141923279405353),
#  (('take', 'respons', 'secur'), 1.4141923279405353),
#  (('cell', 'enhanc', 'act'), 1.4141880810540235),
#  (('respons', 'secur', 'govern'), 1.4141880810540235),
#  (('new', 'sourc', 'review'), 1.41416897006472)]

# %% [markdown]
# Or n-grams (for any number n)

# %%
Ngrams = nltk.ngrams(whReleases['normalized_tokens'].sum(), 4)
Counts = {}
for ngram in list(Ngrams):
    if ngram in Counts.keys():
        Counts[ngram] += 1
    else:
        Counts[ngram] = 1
Filtered = {}
for key in Counts.keys():
    if Counts[key] < 2:
        pass
    else:
        Filtered[key] = Counts[key]
print(Filtered)
# Out:
# {('stem', 'cell', 'research', 'whitehous'): 2, ('stem', 'cell', 'enhanc', 'act'): 2, ('begin', 'bring', 'troop', 'home'): 2, ('bring', 'troop', 'home', 'iraq'): 2, ('senat', 'sheldon', 'whitehous', 'said'): 3, ('sheldon', 'whitehous', 'said', 'today'): 3, ('member', 'senat', 'select', 'committe'): 2, ('senat', 'select', 'committe', 'intellig'): 2, ('take', 'respons', 'secur', 'govern'): 2, ('senat', 'jack', 'reed', 'sheldon'): 2, ('jack', 'reed', 'sheldon', 'whitehous'): 3, ('whitehous', 'welcom', 'rhode', 'island'): 2, ('portugues', 'american', 'citizen', 'rhode'): 2, ('american', 'citizen', 'rhode', 'island'): 2}

# %% [markdown]
# ## <span style="color:red">*Exercise 3*</span>
#
# <span style="color:red">Construct cells immediately below this that identify statistically significant bigrams, trigrams, quadgrams, higher-order *n*grams and skipgrams. Explore whether these collocations are idiomatic and so irreducible to the semantic sum of their component words. You can do this by examination of conditional frequencies (e.g., what else is 'united' besides the 'United States'). If these phrases are idiomatic, what do they suggest about the culture of the world producing them?
#
# <span style="color:red">**Stretch**: In Manning and Schütze's textbook, there Section 5.3.2 explores how to use the *t*-test to find words whose co-occurance patterns best distinguish two words. Implement that and use it to explore phrases in your corpus. For instance, you could tell what words come after "America" much more often than after "Iraq"?</span>

# %%
# Check how many bigrams are there in the corpus
musicBigrams = nltk.collocations.BigramCollocationFinder.from_words(music_df['normalized_tokens'].sum())
print("There are {} bigrams in the finder".format(musicBigrams.N))
# Out:
# There are 26686 bigrams in the finder

# %%
# Look for statistically significant bigrams with student_t: the first 20
bigram_measures = nltk.collocations.BigramAssocMeasures()
musicBigrams.score_ngrams(bigram_measures.student_t)[:20]
# Out:
# [(('hip', 'hop'), 15.714390637602063),
#  (('countri', 'music'), 10.975240009914545),
#  (('hous', 'music'), 7.265626778531044),
#  (('popular', 'music'), 6.866569028133231),
#  (('gospel', 'music'), 6.5989814273817755),
#  (('new', 'york'), 6.5232826390109135),
#  (('hop', 'music'), 5.659248522234622),
#  (('unit', 'state'), 5.463446649387575),
#  (('york', 'citi'), 4.880889340791062),
#  (('rock', 'roll'), 4.552156353290626),
#  (('music', 'wa'), 4.534587049737365),
#  (('citat', 'need'), 4.467946364994521),
#  (('drum', 'machin'), 4.463488641229139),
#  (('gangsta', 'rap'), 4.449461893892203),
#  (('music', 'genr'), 4.292936540291564),
#  (('becam', 'popular'), 4.149935133183492),
#  (('west', 'coast'), 4.112472084386583),
#  (('late', 'earli'), 4.022586851245261),
#  (('african', 'american'), 3.972260735966424),
#  (('countri', 'artist'), 3.8205709174128906)]

# %%
#musicBigrams.score_ngrams(bigram_measures.student_t)[0][1]
bigrams_prob = []
for item in musicBigrams.score_ngrams(bigram_measures.student_t):
    bigrams_prob.append(item[1])

plt.hist(bigrams_prob, bins=100)
plt.xlim(min(bigrams_prob), max(bigrams_prob))
plt.show()

# %%
# Check statistically significant bigrams with likelihood ratio: the first 20
musicBigrams.score_ngrams(bigram_measures.likelihood_ratio)[:20]
# Out:
# [(('hip', 'hop'), 2709.1838312631726),
#  (('countri', 'music'), 505.5989652790237),
#  (('new', 'york'), 467.00468999783067),
#  (('unit', 'state'), 355.76188762326734),
#  (('citat', 'need'), 302.8113694941747),
#  (('york', 'citi'), 250.30617418981996),
#  (('drum', 'machin'), 246.81027123877232),
#  (('lo', 'angel'), 220.0676949697936),
#  (('gospel', 'music'), 207.00029850258625),
#  (('gangsta', 'rap'), 205.22909436786995),
#  (('hous', 'music'), 201.84093319353275),
#  (('rock', 'roll'), 191.9675897921805),
#  (('west', 'coast'), 189.72919221952247),
#  (('afrika', 'bambaataa'), 186.5793815399179),
#  (('grandmast', 'flash'), 177.7824376347931),
#  (('honki', 'tonk'), 177.7824376347931),
#  (('popular', 'music'), 168.65247177982354),
#  (('r', 'b'), 166.02277935802124),
#  (('war', 'ii'), 160.71606091379545),
#  (('east', 'coast'), 155.34033821701397)]

# %%
# Check statistically significant trigrams with student_t: the first 20
trigram_measures = nltk.collocations.TrigramAssocMeasures()
musicTrigrams = nltk.collocations.TrigramCollocationFinder.from_words(music_df['normalized_tokens'].sum())
musicTrigrams.score_ngrams(trigram_measures.student_t)[:20]
# Out:
# [(('hip', 'hop', 'music'), 6.916077641931419),
#  (('new', 'york', 'citi'), 4.898885259000975),
#  (('world', 'war', 'ii'), 3.316621218669452),
#  (('coast', 'hip', 'hop'), 3.3157632417855947),
#  (('hip', 'hop', 'wa'), 3.306228770946415),
#  (('altern', 'hip', 'hop'), 3.1615849003499714),
#  (('hip', 'hop', 'cultur'), 3.1604102206578895),
#  (('dj', 'kool', 'herc'), 2.8284131989219774),
#  (('first', 'hip', 'hop'), 2.824251403056866),
#  (('hip', 'hop', 'artist'), 2.82196149116272),
#  (('countri', 'western', 'music'), 2.8188506556547295),
#  (('grand', 'ole', 'opri'), 2.6457510138486873),
#  (('east', 'coast', 'hip'), 2.6456660472523565),
#  (('hip', 'hop', 'movement'), 2.6445273016711917),
#  (('hip', 'hop', 'ha'), 2.6419352817792885),
#  (('countri', 'music', 'festiv'), 2.641201232802333),
#  (('hip', 'hop', 'record'), 2.635635233430913),
#  (('hop', 'music', 'wa'), 2.6006755769052003),
#  (('john', 'lee', 'hooker'), 2.4494880573763784),
#  (('late', 'earli', 'centuri'), 2.4492678308878273)]

# %%
musicTrigrams.score_ngrams(trigram_measures.student_t)[-20:]
# Out:
# [(('record', 'music', 'record'), 0.9022055380605263),
#  (('popular', 'music', 'wa'), 0.9000195573191074),
#  (('countri', 'music', 'song'), 0.8996802039348872),
#  (('blue', 'popular', 'music'), 0.8956005322282393),
#  (('music', 'gospel', 'music'), 0.8896705176163904),
#  (('countri', 'music', 'popular'), 0.8881434273873993),
#  (('rap', 'music', 'music'), 0.8656383531367923),
#  (('countri', 'music', 'record'), 0.8590506865285166),
#  (('record', 'countri', 'music'), 0.8590506865285166),
#  (('music', 'music', 'genr'), 0.8448833019953211),
#  (('music', 'blue', 'wa'), 0.8305264245140028),
#  (('music', 'wa', 'blue'), 0.8305264245140028),
#  (('blue', 'music', 'blue'), 0.823035879741141),
#  (('countri', 'music', 'blue'), 0.8103955854369369),
#  (('music', 'blue', 'countri'), 0.8103955854369369),
#  (('style', 'music', 'music'), 0.80228082859967),
#  (('hous', 'music', 'music'), 0.7695096952183997),
#  (('music', 'popular', 'music'), 0.7564012418658916),
#  (('popular', 'music', 'music'), 0.7564012418658916),
#  (('music', 'countri', 'music'), 0.5575896993528526)]

# %%
# Check statistically significant trigrams with likelihood ratio: the first 20
musicTrigrams.score_ngrams(trigram_measures.likelihood_ratio)[:20]
# Out:
# [(('hip', 'hop', 'music'), 4211.707660386341),
#  (('coast', 'hip', 'hop'), 4159.7712372980395),
#  (('altern', 'hip', 'hop'), 4157.389430355572),
#  (('hip', 'hop', 'cultur'), 4123.595445723156),
#  (('element', 'hip', 'hop'), 4111.414203201835),
#  (('hip', 'hop', 'movement'), 4110.917089887522),
#  (('school', 'hip', 'hop'), 4099.8095130244255),
#  (('hip', 'hop', 'artist'), 4094.3031526761506),
#  (('fusion', 'hip', 'hop'), 4094.053449848605),
#  (('hip', 'hop', 'ha'), 4093.5133587254504),
#  (('electro', 'hip', 'hop'), 4093.1875029123867),
#  (('subgenr', 'hip', 'hop'), 4093.0607030166216),
#  (('hip', 'hop', 'secur'), 4091.7741864640157),
#  (('first', 'hip', 'hop'), 4090.4964692056524),
#  (('diversif', 'hip', 'hop'), 4086.0757286951557),
#  (('hip', 'hop', 'bop'), 4086.0757286951557),
#  (('mainstream', 'hip', 'hop'), 4085.6124504670242),
#  (('age', 'hip', 'hop'), 4085.0238763057678),
#  (('hip', 'hop', 'group'), 4084.5877251203547),
#  (('haitian', 'hip', 'hop'), 4083.51676092529)]

# %%
# Check the most frequently used quadgrams: frequency >= 3
ngrams_4 = nltk.ngrams(music_df['normalized_tokens'].sum(), 4)
Counts_4 = {}
for ngram in list(ngrams_4):
    Counts_4[ngram] = Counts_4.get(ngram, 0) + 1
Filtered_4 = {}
for key in Counts_4.keys():
    if Counts_4[key] < 3:
        pass
    else:
        Filtered_4[key] = Counts_4[key]
print(Filtered_4)
# Out:
# {('follow', 'world', 'war', 'ii'): 4, ('hous', 'music', 'becam', 'popular'): 3, ('includ', 'dj', 'kool', 'herc'): 3, ('grandmast', 'flash', 'furiou', 'five'): 4, ('first', 'hip', 'hop', 'record'): 4, ('hip', 'hop', 'music', 'wa'): 7, ('golden', 'age', 'hip', 'hop'): 3, ('west', 'coast', 'hip', 'hop'): 4, ('east', 'coast', 'hip', 'hop'): 7, ('crossov', 'success', 'artist', 'outkast'): 3, ('success', 'artist', 'outkast', 'kany'): 3, ('artist', 'outkast', 'kany', 'west'): 3, ('sugarhil', 'gang', 'rapper', 'delight'): 4, ('hip', 'hop', 'hip', 'hop'): 3, ('hip', 'hop', 'record', 'earli'): 3, ('wa', 'certifi', 'platinum', 'sold'): 3, ('certifi', 'platinum', 'sold', 'million'): 3, ('platinum', 'sold', 'million', 'copi'): 3}

# %%
# Check the most frequently used 5-grams: frequency >= 3
ngrams_5 = nltk.ngrams(music_df['normalized_tokens'].sum(), 5)
Counts_5 = {}
for ngram in list(ngrams_5):
    Counts_5[ngram] = Counts_5.get(ngram, 0) + 1
Filtered_5 = {}
for key in Counts_5.keys():
    if Counts_5[key] < 3:
        pass
    else:
        Filtered_5[key] = Counts_5[key]
print(Filtered_5)
# Out:
# {('crossov', 'success', 'artist', 'outkast', 'kany'): 3, ('success', 'artist', 'outkast', 'kany', 'west'): 3, ('wa', 'certifi', 'platinum', 'sold', 'million'): 3, ('certifi', 'platinum', 'sold', 'million', 'copi'): 3}

# %%
# Check skipgrams
# Since there is already a built-in module of skipgram, and the suggested window_sice() doesn't
#     work in my computer, I use the module "skipgrams"
from nltk.util import skipgrams

# Check skipgrams with bigrams and 2 skips
music_skipgrams_2_2 = skipgrams(music_df['normalized_tokens'].sum(), 2, 2)
print('There are {} skipgrams with n=k=2'.format(len(list(music_skipgrams_2_2))))
music_skipgrams_2_2 = skipgrams(music_df['normalized_tokens'].sum(), 2, 2)
list(music_skipgrams_2_2)
# Out:
# There are 80052 skipgrams with n=k=2
# [('blue', 'music'),
#  ('blue', 'genr'),
#  ('blue', 'music'),
#  ('music', 'genr'),
#  ('music', 'music'),
#  ('music', 'form'),
#  ('genr', 'music'),
#  ('genr', 'form'),
#  ('genr', 'origin'),
#  ('music', 'form'),
#  ('music', 'origin'),
#  ('music', 'african'),
#  ('form', 'origin'),
#  ('form', 'african'),
#  ('form', 'american'),
#  ('origin', 'african'),
#  ('origin', 'american'),
#  ('origin', 'deep'),
#  ('african', 'american'),
#  ('african', 'deep'),
#  ('african', 'south'),
#  ('american', 'deep'),
#  ('american', 'south'),
#  ('american', 'unit'),
#  ('deep', 'south'),
#  ('deep', 'unit'),
#  ('deep', 'state'),
#  ('south', 'unit'),
#  ('south', 'state'),
#  ('south', 'around'),
#  ('unit', 'state'),
#  ('unit', 'around'),
#  ('unit', 'end'),
#  ('state', 'around'),
#  ('state', 'end'),
#  ('state', 'centuri'),
#  ('around', 'end'),
#  ('around', 'centuri'),
#  ('around', 'genr'),
#  ('end', 'centuri'),
#  ('end', 'genr'),
#  ('end', 'develop'),
#  ('centuri', 'genr'),
#  ('centuri', 'develop'),
#  ('centuri', 'root'),
#  ('genr', 'develop'),
#  ('genr', 'root'),
#  ('genr', 'african'),
#  ('develop', 'root'),
#  ('develop', 'african'),
#  ('develop', 'music'),
#  ('root', 'african'),
#  ('root', 'music'),
#  ('root', 'tradit'),
#  ('african', 'music'),
#  ('african', 'tradit'),
#  ('african', 'work'),
#  ('music', 'tradit'),
#  ('music', 'work'),
#  ('music', 'song'),
#  ('tradit', 'work'),
#  ('tradit', 'song'),
#  ('tradit', 'spiritu'),
#  ('work', 'song'),
#  ('work', 'spiritu'),
#  ('work', 'folk'),
#  ('song', 'spiritu'),
#  ('song', 'folk'),
#  ('song', 'music'),
#  ('spiritu', 'folk'),
#  ('spiritu', 'music'),
#  ('spiritu', 'white'),
#  ('folk', 'music'),
#  ('folk', 'white'),
#  ('folk', 'american'),
#  ('music', 'white'),
#  ('music', 'american'),
#  ('music', 'european'),
#  ('white', 'american'),
#  ('white', 'european'),
#  ('white', 'heritag'),
#  ('american', 'european'),
#  ('american', 'heritag'),
#  ('american', 'blue'),
#  ('european', 'heritag'),
#  ('european', 'blue'),
#  ('european', 'incorpor'),
#  ('heritag', 'blue'),
#  ('heritag', 'incorpor'),
#  ('heritag', 'spiritu'),
#  ('blue', 'incorpor'),
#  ('blue', 'spiritu'),
#  ('blue', 'work'),
#  ('incorpor', 'spiritu'),
#  ('incorpor', 'work'),
#  ('incorpor', 'song'),
#  ('spiritu', 'work'),
#  ('spiritu', 'song'),
#  ('spiritu', 'field'),
#  ('work', 'song'),
#  ('work', 'field'),
#  ('work', 'holler'),
#  ('song', 'field'),
#  ('song', 'holler'),
#  ('song', 'shout'),
#  ('field', 'holler'),
#  ('field', 'shout'),
#  ('field', 'chant'),
#  ('holler', 'shout'),
#  ('holler', 'chant'),
#  ('holler', 'rhyme'),
#  ('shout', 'chant'),
#  ('shout', 'rhyme'),
#  ('shout', 'simpl'),
#  ('chant', 'rhyme'),
#  ('chant', 'simpl'),
#  ('chant', 'narr'),
#  ('rhyme', 'simpl'),
#  ('rhyme', 'narr'),
#  ('rhyme', 'ballad'),
#  ('simpl', 'narr'),
#  ('simpl', 'ballad'),
#  ('simpl', 'blue'),
#  ('narr', 'ballad'),
#  ('narr', 'blue'),
#  ('narr', 'form'),
#  ('ballad', 'blue'),
#  ('ballad', 'form'),
#  ('ballad', 'ubiquit'),
#  ('blue', 'form'),
#  ('blue', 'ubiquit'),
#  ('blue', 'jazz'),
#  ('form', 'ubiquit'),
#  ('form', 'jazz'),
#  ('form', 'rhythm'),
#  ('ubiquit', 'jazz'),
#  ('ubiquit', 'rhythm'),
#  ('ubiquit', 'blue'),
#  ('jazz', 'rhythm'),
#  ('jazz', 'blue'),
#  ('jazz', 'rock'),
#  ('rhythm', 'blue'),
#  ('rhythm', 'rock'),
#  ('rhythm', 'roll'),
#  ('blue', 'rock'),
#  ('blue', 'roll'),
#  ('blue', 'character'),
#  ('rock', 'roll'),
#  ('rock', 'character'),
#  ('rock', 'pattern'),
#  ('roll', 'character'),
#  ('roll', 'pattern'),
#  ('roll', 'blue'),
#  ('character', 'pattern'),
#  ('character', 'blue'),
#  ('character', 'scale'),
#  ('pattern', 'blue'),
#  ('pattern', 'scale'),
#  ('pattern', 'specif'),
#  ('blue', 'scale'),
#  ('blue', 'specif'),
#  ('blue', 'chord'),
#  ('scale', 'specif'),
#  ('scale', 'chord'),
#  ('scale', 'progress'),
#  ('specif', 'chord'),
#  ('specif', 'progress'),
#  ('specif', 'blue'),
#  ('chord', 'progress'),
#  ('chord', 'blue'),
#  ('chord', 'common'),
#  ('progress', 'blue'),
#  ('progress', 'common'),
#  ('progress', 'blue'),
#  ('blue', 'common'),
#  ('blue', 'blue'),
#  ('blue', 'note'),
#  ('common', 'blue'),
#  ('common', 'note'),
#  ('common', 'worri'),
#  ('blue', 'note'),
#  ('blue', 'worri'),
#  ('blue', 'note'),
#  ('note', 'worri'),
#  ('note', 'note'),
#  ('note', 'usual'),
#  ('worri', 'note'),
#  ('worri', 'usual'),
#  ('worri', 'third'),
#  ('note', 'usual'),
#  ('note', 'third'),
#  ('note', 'fifth'),
#  ('usual', 'third'),
#  ('usual', 'fifth'),
#  ('usual', 'flatten'),
#  ('third', 'fifth'),
#  ('third', 'flatten'),
#  ('third', 'pitch'),
#  ('fifth', 'flatten'),
#  ('fifth', 'pitch'),
#  ('fifth', 'also'),
#  ('flatten', 'pitch'),
#  ('flatten', 'also'),
#  ('flatten', 'essenti'),
#  ('pitch', 'also'),
#  ('pitch', 'essenti'),
#  ('pitch', 'part'),
#  ('also', 'essenti'),
#  ('also', 'part'),
#  ('also', 'sound'),
#  ('essenti', 'part'),
#  ('essenti', 'sound'),
#  ('essenti', 'blue'),
#  ('part', 'sound'),
#  ('part', 'blue'),
#  ('part', 'shuffl'),
#  ('sound', 'blue'),
#  ('sound', 'shuffl'),
#  ('sound', 'walk'),
#  ('blue', 'shuffl'),
#  ('blue', 'walk'),
#  ('blue', 'bass'),
#  ('shuffl', 'walk'),
#  ('shuffl', 'bass'),
#  ('shuffl', 'reinforc'),
#  ('walk', 'bass'),
#  ('walk', 'reinforc'),
#  ('walk', 'rhythm'),
#  ('bass', 'reinforc'),
#  ('bass', 'rhythm'),
#  ('bass', 'form'),
#  ('reinforc', 'rhythm'),
#  ('reinforc', 'form'),
#  ('reinforc', 'repetit'),
#  ('rhythm', 'form'),
#  ('rhythm', 'repetit'),
#  ('rhythm', 'effect'),
#  ('form', 'repetit'),
#  ('form', 'effect'),
#  ('form', 'known'),
#  ('repetit', 'effect'),
#  ('repetit', 'known'),
#  ('repetit', 'groov'),
#  ('effect', 'known'),
#  ('effect', 'groov'),
#  ('effect', 'blue'),
#  ('known', 'groov'),
#  ('known', 'blue'),
#  ('known', 'genr'),
#  ('groov', 'blue'),
#  ('groov', 'genr'),
#  ('groov', 'also'),
#  ('blue', 'genr'),
#  ('blue', 'also'),
#  ('blue', 'character'),
#  ('genr', 'also'),
#  ('genr', 'character'),
#  ('genr', 'lyric'),
#  ('also', 'character'),
#  ('also', 'lyric'),
#  ('also', 'bass'),
#  ('character', 'lyric'),
#  ('character', 'bass'),
#  ('character', 'line'),
#  ('lyric', 'bass'),
#  ('lyric', 'line'),
#  ('lyric', 'instrument'),
#  ('bass', 'line'),
#  ('bass', 'instrument'),
#  ('bass', 'earli'),
#  ('line', 'instrument'),
#  ('line', 'earli'),
#  ('line', 'tradit'),
#  ('instrument', 'earli'),
#  ('instrument', 'tradit'),
#  ('instrument', 'blue'),
#  ('earli', 'tradit'),
#  ('earli', 'blue'),
#  ('earli', 'vers'),
#  ('tradit', 'blue'),
#  ('tradit', 'vers'),
#  ('tradit', 'consist'),
#  ('blue', 'vers'),
#  ('blue', 'consist'),
#  ('blue', 'singl'),
#  ('vers', 'consist'),
#  ('vers', 'singl'),
#  ('vers', 'line'),
#  ('consist', 'singl'),
#  ('consist', 'line'),
#  ('consist', 'repeat'),
#  ('singl', 'line'),
#  ('singl', 'repeat'),
#  ('singl', 'four'),
#  ('line', 'repeat'),
#  ('line', 'four'),
#  ('line', 'time'),
#  ('repeat', 'four'),
#  ('repeat', 'time'),
#  ('repeat', 'wa'),
#  ('four', 'time'),
#  ('four', 'wa'),
#  ('four', 'onli'),
#  ('time', 'wa'),
#  ('time', 'onli'),
#  ('time', 'first'),
#  ('wa', 'onli'),
#  ('wa', 'first'),
#  ('wa', 'decad'),
#  ('onli', 'first'),
#  ('onli', 'decad'),
#  ('onli', 'centuri'),
#  ('first', 'decad'),
#  ('first', 'centuri'),
#  ('first', 'common'),
#  ('decad', 'centuri'),
#  ('decad', 'common'),
#  ('decad', 'current'),
#  ('centuri', 'common'),
#  ('centuri', 'current'),
#  ('centuri', 'structur'),
#  ('common', 'current'),
#  ('common', 'structur'),
#  ('common', 'becam'),
#  ('current', 'structur'),
#  ('current', 'becam'),
#  ('current', 'standard'),
#  ('structur', 'becam'),
#  ('structur', 'standard'),
#  ('structur', 'aab'),
#  ('becam', 'standard'),
#  ('becam', 'aab'),
#  ('becam', 'pattern'),
#  ('standard', 'aab'),
#  ('standard', 'pattern'),
#  ('standard', 'consist'),
#  ('aab', 'pattern'),
#  ('aab', 'consist'),
#  ('aab', 'line'),
#  ('pattern', 'consist'),
#  ('pattern', 'line'),
#  ('pattern', 'sung'),
#  ('consist', 'line'),
#  ('consist', 'sung'),
#  ('consist', 'four'),
#  ('line', 'sung'),
#  ('line', 'four'),
#  ('line', 'first'),
#  ('sung', 'four'),
#  ('sung', 'first'),
#  ('sung', 'bar'),
#  ('four', 'first'),
#  ('four', 'bar'),
#  ('four', 'repetit'),
#  ('first', 'bar'),
#  ('first', 'repetit'),
#  ('first', 'next'),
#  ('bar', 'repetit'),
#  ('bar', 'next'),
#  ('bar', 'four'),
#  ('repetit', 'next'),
#  ('repetit', 'four'),
#  ('repetit', 'longer'),
#  ('next', 'four'),
#  ('next', 'longer'),
#  ('next', 'conclud'),
#  ('four', 'longer'),
#  ('four', 'conclud'),
#  ('four', 'line'),
#  ('longer', 'conclud'),
#  ('longer', 'line'),
#  ('longer', 'last'),
#  ('conclud', 'line'),
#  ('conclud', 'last'),
#  ('conclud', 'bar'),
#  ('line', 'last'),
#  ('line', 'bar'),
#  ('line', 'earli'),
#  ('last', 'bar'),
#  ('last', 'earli'),
#  ('last', 'blue'),
#  ('bar', 'earli'),
#  ('bar', 'blue'),
#  ('bar', 'frequent'),
#  ('earli', 'blue'),
#  ('earli', 'frequent'),
#  ('earli', 'took'),
#  ('blue', 'frequent'),
#  ('blue', 'took'),
#  ('blue', 'form'),
#  ('frequent', 'took'),
#  ('frequent', 'form'),
#  ('frequent', 'loos'),
#  ('took', 'form'),
#  ('took', 'loos'),
#  ('took', 'narr'),
#  ('form', 'loos'),
#  ('form', 'narr'),
#  ('form', 'often'),
#  ('loos', 'narr'),
#  ('loos', 'often'),
#  ('loos', 'relat'),
#  ('narr', 'often'),
#  ('narr', 'relat'),
#  ('narr', 'racial'),
#  ('often', 'relat'),
#  ('often', 'racial'),
#  ('often', 'discrimin'),
#  ('relat', 'racial'),
#  ('relat', 'discrimin'),
#  ('relat', 'challeng'),
#  ('racial', 'discrimin'),
#  ('racial', 'challeng'),
#  ('racial', 'experienc'),
#  ('discrimin', 'challeng'),
#  ('discrimin', 'experienc'),
#  ('discrimin', 'mani'),
#  ('challeng', 'experienc'),
#  ('challeng', 'mani'),
#  ('challeng', 'element'),
#  ('experienc', 'mani'),
#  ('experienc', 'element'),
#  ('experienc', 'format'),
#  ('mani', 'element'),
#  ('mani', 'format'),
#  ('mani', 'use'),
#  ('element', 'format'),
#  ('element', 'use'),
#  ('element', 'blue'),
#  ('format', 'use'),
#  ('format', 'blue'),
#  ('format', 'note'),
#  ('use', 'blue'),
#  ('use', 'note'),
#  ('use', 'trace'),
#  ('blue', 'note'),
#  ('blue', 'trace'),
#  ('blue', 'back'),
#  ('note', 'trace'),
#  ('note', 'back'),
#  ('note', 'music'),
#  ('trace', 'back'),
#  ('trace', 'music'),
#  ('trace', 'africa'),
#  ('back', 'music'),
#  ('back', 'africa'),
#  ('back', 'origin'),
#  ('music', 'africa'),
#  ('music', 'origin'),
#  ('music', 'blue'),
#  ('africa', 'origin'),
#  ('africa', 'blue'),
#  ('africa', 'also'),
#  ('origin', 'blue'),
#  ('origin', 'also'),
#  ('origin', 'close'),
#  ('blue', 'also'),
#  ('blue', 'close'),
#  ('blue', 'relat'),
#  ('also', 'close'),
#  ('also', 'relat'),
#  ('also', 'religi'),
#  ('close', 'relat'),
#  ('close', 'religi'),
#  ('close', 'music'),
#  ('relat', 'religi'),
#  ('relat', 'music'),
#  ('relat', 'commun'),
#  ('religi', 'music'),
#  ('religi', 'commun'),
#  ('religi', 'spiritu'),
#  ('music', 'commun'),
#  ('music', 'spiritu'),
#  ('music', 'first'),
#  ('commun', 'spiritu'),
#  ('commun', 'first'),
#  ('commun', 'appear'),
#  ('spiritu', 'first'),
#  ('spiritu', 'appear'),
#  ('spiritu', 'blue'),
#  ('first', 'appear'),
#  ('first', 'blue'),
#  ('first', 'often'),
#  ('appear', 'blue'),
#  ('appear', 'often'),
#  ('appear', 'date'),
#  ('blue', 'often'),
#  ('blue', 'date'),
#  ('blue', 'end'),
#  ('often', 'date'),
#  ('often', 'end'),
#  ('often', 'slaveri'),
#  ('date', 'end'),
#  ('date', 'slaveri'),
#  ('date', 'later'),
#  ('end', 'slaveri'),
#  ('end', 'later'),
#  ('end', 'develop'),
#  ('slaveri', 'later'),
#  ('slaveri', 'develop'),
#  ('slaveri', 'juke'),
#  ('later', 'develop'),
#  ('later', 'juke'),
#  ('later', 'joint'),
#  ('develop', 'juke'),
#  ('develop', 'joint'),
#  ('develop', 'associ'),
#  ('juke', 'joint'),
#  ('juke', 'associ'),
#  ('juke', 'newli'),
#  ('joint', 'associ'),
#  ('joint', 'newli'),
#  ('joint', 'acquir'),
#  ('associ', 'newli'),
#  ('associ', 'acquir'),
#  ('associ', 'freedom'),
#  ('newli', 'acquir'),
#  ('newli', 'freedom'),
#  ('newli', 'former'),
#  ('acquir', 'freedom'),
#  ('acquir', 'former'),
#  ('acquir', 'slave'),
#  ('freedom', 'former'),
#  ('freedom', 'slave'),
#  ('freedom', 'chronicl'),
#  ('former', 'slave'),
#  ('former', 'chronicl'),
#  ('former', 'began'),
#  ('slave', 'chronicl'),
#  ('slave', 'began'),
#  ('slave', 'report'),
#  ('chronicl', 'began'),
#  ('chronicl', 'report'),
#  ('chronicl', 'blue'),
#  ('began', 'report'),
#  ('began', 'blue'),
#  ('began', 'music'),
#  ('report', 'blue'),
#  ('report', 'music'),
#  ('report', 'dawn'),
#  ('blue', 'music'),
#  ('blue', 'dawn'),
#  ('blue', 'centuri'),
#  ('music', 'dawn'),
#  ('music', 'centuri'),
#  ('music', 'first'),
#  ('dawn', 'centuri'),
#  ('dawn', 'first'),
#  ('dawn', 'public'),
#  ('centuri', 'first'),
#  ('centuri', 'public'),
#  ('centuri', 'blue'),
#  ('first', 'public'),
#  ('first', 'blue'),
#  ('first', 'sheet'),
#  ('public', 'blue'),
#  ('public', 'sheet'),
#  ('public', 'music'),
#  ('blue', 'sheet'),
#  ('blue', 'music'),
#  ('blue', 'wa'),
#  ('sheet', 'music'),
#  ('sheet', 'wa'),
#  ('sheet', 'blue'),
#  ('music', 'wa'),
#  ('music', 'blue'),
#  ('music', 'ha'),
#  ('wa', 'blue'),
#  ('wa', 'ha'),
#  ('wa', 'sinc'),
#  ('blue', 'ha'),
#  ('blue', 'sinc'),
#  ('blue', 'evolv'),
#  ('ha', 'sinc'),
#  ('ha', 'evolv'),
#  ('ha', 'unaccompani'),
#  ('sinc', 'evolv'),
#  ('sinc', 'unaccompani'),
#  ('sinc', 'vocal'),
#  ('evolv', 'unaccompani'),
#  ('evolv', 'vocal'),
#  ('evolv', 'music'),
#  ('unaccompani', 'vocal'),
#  ('unaccompani', 'music'),
#  ('unaccompani', 'oral'),
#  ('vocal', 'music'),
#  ('vocal', 'oral'),
#  ('vocal', 'tradit'),
#  ('music', 'oral'),
#  ('music', 'tradit'),
#  ('music', 'slave'),
#  ('oral', 'tradit'),
#  ('oral', 'slave'),
#  ('oral', 'wide'),
#  ('tradit', 'slave'),
#  ('tradit', 'wide'),
#  ('tradit', 'varieti'),
#  ('slave', 'wide'),
#  ('slave', 'varieti'),
#  ('slave', 'style'),
#  ('wide', 'varieti'),
#  ('wide', 'style'),
#  ('wide', 'subgenr'),
#  ('varieti', 'style'),
#  ('varieti', 'subgenr'),
#  ('varieti', 'blue'),
#  ('style', 'subgenr'),
#  ('style', 'blue'),
#  ('style', 'subgenr'),
#  ('subgenr', 'blue'),
#  ('subgenr', 'subgenr'),
#  ('subgenr', 'includ'),
#  ('blue', 'subgenr'),
#  ('blue', 'includ'),
#  ('blue', 'countri'),
#  ('subgenr', 'includ'),
#  ('subgenr', 'countri'),
#  ('subgenr', 'blue'),
#  ('includ', 'countri'),
#  ('includ', 'blue'),
#  ('includ', 'delta'),
#  ('countri', 'blue'),
#  ('countri', 'delta'),
#  ('countri', 'blue'),
#  ('blue', 'delta'),
#  ('blue', 'blue'),
#  ('blue', 'piedmont'),
#  ('delta', 'blue'),
#  ('delta', 'piedmont'),
#  ('delta', 'blue'),
#  ('blue', 'piedmont'),
#  ('blue', 'blue'),
#  ('blue', 'well'),
#  ('piedmont', 'blue'),
#  ('piedmont', 'well'),
#  ('piedmont', 'urban'),
#  ('blue', 'well'),
#  ('blue', 'urban'),
#  ('blue', 'blue'),
#  ('well', 'urban'),
#  ('well', 'blue'),
#  ('well', 'style'),
#  ('urban', 'blue'),
#  ('urban', 'style'),
#  ('urban', 'chicago'),
#  ('blue', 'style'),
#  ('blue', 'chicago'),
#  ('blue', 'blue'),
#  ('style', 'chicago'),
#  ('style', 'blue'),
#  ('style', 'west'),
#  ('chicago', 'blue'),
#  ('chicago', 'west'),
#  ('chicago', 'coast'),
#  ('blue', 'west'),
#  ('blue', 'coast'),
#  ('blue', 'blue'),
#  ('west', 'coast'),
#  ('west', 'blue'),
#  ('west', 'world'),
#  ('coast', 'blue'),
#  ('coast', 'world'),
#  ('coast', 'war'),
#  ('blue', 'world'),
#  ('blue', 'war'),
#  ('blue', 'ii'),
#  ('world', 'war'),
#  ('world', 'ii'),
#  ('world', 'mark'),
#  ('war', 'ii'),
#  ('war', 'mark'),
#  ('war', 'transit'),
#  ('ii', 'mark'),
#  ('ii', 'transit'),
#  ('ii', 'acoust'),
#  ('mark', 'transit'),
#  ('mark', 'acoust'),
#  ('mark', 'electr'),
#  ('transit', 'acoust'),
#  ('transit', 'electr'),
#  ('transit', 'blue'),
#  ('acoust', 'electr'),
#  ('acoust', 'blue'),
#  ('acoust', 'progress'),
#  ('electr', 'blue'),
#  ('electr', 'progress'),
#  ('electr', 'open'),
#  ('blue', 'progress'),
#  ('blue', 'open'),
#  ('blue', 'blue'),
#  ('progress', 'open'),
#  ('progress', 'blue'),
#  ('progress', 'music'),
#  ('open', 'blue'),
#  ('open', 'music'),
#  ('open', 'wider'),
#  ('blue', 'music'),
#  ('blue', 'wider'),
#  ('blue', 'audienc'),
#  ('music', 'wider'),
#  ('music', 'audienc'),
#  ('music', 'especi'),
#  ('wider', 'audienc'),
#  ('wider', 'especi'),
#  ('wider', 'white'),
#  ('audienc', 'especi'),
#  ('audienc', 'white'),
#  ('audienc', 'listen'),
#  ('especi', 'white'),
#  ('especi', 'listen'),
#  ('especi', 'hybrid'),
#  ('white', 'listen'),
#  ('white', 'hybrid'),
#  ('white', 'form'),
#  ('listen', 'hybrid'),
#  ('listen', 'form'),
#  ('listen', 'call'),
#  ('hybrid', 'form'),
#  ('hybrid', 'call'),
#  ('hybrid', 'blue'),
#  ('form', 'call'),
#  ('form', 'blue'),
#  ('form', 'rock'),
#  ('call', 'blue'),
#  ('call', 'rock'),
#  ('call', 'develop'),
#  ('blue', 'rock'),
#  ('blue', 'develop'),
#  ('blue', 'blend'),
#  ('rock', 'develop'),
#  ('rock', 'blend'),
#  ('rock', 'blue'),
#  ('develop', 'blend'),
#  ('develop', 'blue'),
#  ('develop', 'style'),
#  ('blend', 'blue'),
#  ('blend', 'style'),
#  ('blend', 'rock'),
#  ('blue', 'style'),
#  ('blue', 'rock'),
#  ('blue', 'music'),
#  ('style', 'rock'),
#  ('style', 'music'),
#  ('style', 'term'),
#  ('rock', 'music'),
#  ('rock', 'term'),
#  ('rock', 'blue'),
#  ('music', 'term'),
#  ('music', 'blue'),
#  ('music', 'may'),
#  ('term', 'blue'),
#  ('term', 'may'),
#  ('term', 'come'),
#  ('blue', 'may'),
#  ('blue', 'come'),
#  ('blue', 'blue'),
#  ('may', 'come'),
#  ('may', 'blue'),
#  ('may', 'devil'),
#  ('come', 'blue'),
#  ('come', 'devil'),
#  ('come', 'mean'),
#  ('blue', 'devil'),
#  ('blue', 'mean'),
#  ('blue', 'melancholi'),
#  ('devil', 'mean'),
#  ('devil', 'melancholi'),
#  ('devil', 'sad'),
#  ('mean', 'melancholi'),
#  ('mean', 'sad'),
#  ('mean', 'earli'),
#  ('melancholi', 'sad'),
#  ('melancholi', 'earli'),
#  ('melancholi', 'use'),
#  ('sad', 'earli'),
#  ('sad', 'use'),
#  ('sad', 'term'),
#  ('earli', 'use'),
#  ('earli', 'term'),
#  ('earli', 'thi'),
#  ('use', 'term'),
#  ('use', 'thi'),
#  ('use', 'sens'),
#  ('term', 'thi'),
#  ('term', 'sens'),
#  ('term', 'georg'),
#  ('thi', 'sens'),
#  ('thi', 'georg'),
#  ('thi', 'colman'),
#  ('sens', 'georg'),
#  ('sens', 'colman'),
#  ('sens', 'farc'),
#  ('georg', 'colman'),
#  ('georg', 'farc'),
#  ('georg', 'blue'),
#  ('colman', 'farc'),
#  ('colman', 'blue'),
#  ('colman', 'devil'),
#  ('farc', 'blue'),
#  ('farc', 'devil'),
#  ('farc', 'phrase'),
#  ('blue', 'devil'),
#  ('blue', 'phrase'),
#  ('blue', 'blue'),
#  ('devil', 'phrase'),
#  ('devil', 'blue'),
#  ('devil', 'devil'),
#  ('phrase', 'blue'),
#  ('phrase', 'devil'),
#  ('phrase', 'may'),
#  ('blue', 'devil'),
#  ('blue', 'may'),
#  ('blue', 'also'),
#  ('devil', 'may'),
#  ('devil', 'also'),
#  ('devil', 'deriv'),
#  ('may', 'also'),
#  ('may', 'deriv'),
#  ('may', 'britain'),
#  ('also', 'deriv'),
#  ('also', 'britain'),
#  ('also', 'term'),
#  ('deriv', 'britain'),
#  ('deriv', 'term'),
#  ('deriv', 'refer'),
#  ('britain', 'term'),
#  ('britain', 'refer'),
#  ('britain', 'intens'),
#  ('term', 'refer'),
#  ('term', 'intens'),
#  ('term', 'visual'),
#  ('refer', 'intens'),
#  ('refer', 'visual'),
#  ('refer', 'hallucin'),
#  ('intens', 'visual'),
#  ('intens', 'hallucin'),
#  ('intens', 'accompani'),
#  ('visual', 'hallucin'),
#  ('visual', 'accompani'),
#  ('visual', 'sever'),
#  ('hallucin', 'accompani'),
#  ('hallucin', 'sever'),
#  ('hallucin', 'alcohol'),
#  ('accompani', 'sever'),
#  ('accompani', 'alcohol'),
#  ('accompani', 'withdraw'),
#  ('sever', 'alcohol'),
#  ('sever', 'withdraw'),
#  ('sever', 'time'),
#  ('alcohol', 'withdraw'),
#  ('alcohol', 'time'),
#  ('alcohol', 'went'),
#  ('withdraw', 'time'),
#  ('withdraw', 'went'),
#  ('withdraw', 'phrase'),
#  ('time', 'went'),
#  ('time', 'phrase'),
#  ('time', 'lost'),
#  ('went', 'phrase'),
#  ('went', 'lost'),
#  ('went', 'refer'),
#  ('phrase', 'lost'),
#  ('phrase', 'refer'),
#  ('phrase', 'devil'),
#  ('lost', 'refer'),
#  ('lost', 'devil'),
#  ('lost', 'came'),
#  ('refer', 'devil'),
#  ('refer', 'came'),
#  ('refer', 'mean'),
#  ('devil', 'came'),
#  ('devil', 'mean'),
#  ('devil', 'state'),
#  ('came', 'mean'),
#  ('came', 'state'),
#  ('came', 'agit'),
#  ('mean', 'state'),
#  ('mean', 'agit'),
#  ('mean', 'depress'),
#  ('state', 'agit'),
#  ('state', 'depress'),
#  ('state', 'unit'),
#  ('agit', 'depress'),
#  ('agit', 'unit'),
#  ('agit', 'state'),
#  ('depress', 'unit'),
#  ('depress', 'state'),
#  ('depress', 'term'),
#  ('unit', 'state'),
#  ('unit', 'term'),
#  ('unit', 'blue'),
#  ('state', 'term'),
#  ('state', 'blue'),
#  ('state', 'wa'),
#  ('term', 'blue'),
#  ('term', 'wa'),
#  ('term', 'associ'),
#  ('blue', 'wa'),
#  ('blue', 'associ'),
#  ('blue', 'drink'),
#  ('wa', 'associ'),
#  ('wa', 'drink'),
#  ('wa', 'alcohol'),
#  ('associ', 'drink'),
#  ('associ', 'alcohol'),
#  ('associ', 'mean'),
#  ('drink', 'alcohol'),
#  ('drink', 'mean'),
#  ('drink', 'surviv'),
#  ('alcohol', 'mean'),
#  ('alcohol', 'surviv'),
#  ('alcohol', 'phrase'),
#  ('mean', 'surviv'),
#  ('mean', 'phrase'),
#  ('mean', 'blue'),
#  ('surviv', 'phrase'),
#  ('surviv', 'blue'),
#  ('surviv', 'law'),
#  ('phrase', 'blue'),
#  ('phrase', 'law'),
#  ('phrase', 'prohibit'),
#  ('blue', 'law'),
#  ('blue', 'prohibit'),
#  ('blue', 'sale'),
#  ('law', 'prohibit'),
#  ('law', 'sale'),
#  ('law', 'alcohol'),
#  ('prohibit', 'sale'),
#  ('prohibit', 'alcohol'),
#  ('prohibit', 'sunday'),
#  ('sale', 'alcohol'),
#  ('sale', 'sunday'),
#  ('sale', 'though'),
#  ('alcohol', 'sunday'),
#  ('alcohol', 'though'),
#  ('alcohol', 'use'),
#  ('sunday', 'though'),
#  ('sunday', 'use'),
#  ('sunday', 'phrase'),
#  ('though', 'use'),
#  ('though', 'phrase'),
#  ('though', 'music'),
#  ('use', 'phrase'),
#  ('use', 'music'),
#  ('use', 'may'),
#  ('phrase', 'music'),
#  ('phrase', 'may'),
#  ('phrase', 'older'),
#  ('music', 'may'),
#  ('music', 'older'),
#  ('music', 'ha'),
#  ('may', 'older'),
#  ('may', 'ha'),
#  ('may', 'attest'),
#  ('older', 'ha'),
#  ('older', 'attest'),
#  ('older', 'print'),
#  ('ha', 'attest'),
#  ('ha', 'print'),
#  ('ha', 'sinc'),
#  ('attest', 'print'),
#  ('attest', 'sinc'),
#  ('attest', 'hart'),
#  ('print', 'sinc'),
#  ('print', 'hart'),
#  ('print', 'wand'),
#  ('sinc', 'hart'),
#  ('sinc', 'wand'),
#  ('sinc', 'dalla'),
#  ('hart', 'wand'),
#  ('hart', 'dalla'),
#  ('hart', 'blue'),
#  ('wand', 'dalla'),
#  ('wand', 'blue'),
#  ('wand', 'becam'),
#  ('dalla', 'blue'),
#  ('dalla', 'becam'),
#  ('dalla', 'first'),
#  ('blue', 'becam'),
#  ('blue', 'first'),
#  ('blue', 'copyright'),
#  ('becam', 'first'),
#  ('becam', 'copyright'),
#  ('becam', 'blue'),
#  ('first', 'copyright'),
#  ('first', 'blue'),
#  ('first', 'composit'),
#  ('copyright', 'blue'),
#  ('copyright', 'composit'),
#  ('copyright', 'lyric'),
#  ('blue', 'composit'),
#  ('blue', 'lyric'),
#  ('blue', 'phrase'),
#  ('composit', 'lyric'),
#  ('composit', 'phrase'),
#  ('composit', 'often'),
#  ('lyric', 'phrase'),
#  ('lyric', 'often'),
#  ('lyric', 'use'),
#  ('phrase', 'often'),
#  ...]

# %%
# Check skipgrams with trigrams and 2 skips
music_skipgrams_3_2 = skipgrams(music_df['normalized_tokens'].sum(), 3, 2)
print('There are {} skipgrams with n=3, k=2'.format(len(list(music_skipgrams_3_2))))
music_skipgrams_3_2 = skipgrams(music_df['normalized_tokens'].sum(), 3, 2)
list(music_skipgrams_3_2)
# Out:
# There are 160096 skipgrams with n=3, k=2
# [('blue', 'music', 'genr'),
#  ('blue', 'music', 'music'),
#  ('blue', 'music', 'form'),
#  ('blue', 'genr', 'music'),
#  ('blue', 'genr', 'form'),
#  ('blue', 'music', 'form'),
#  ('music', 'genr', 'music'),
#  ('music', 'genr', 'form'),
#  ('music', 'genr', 'origin'),
#  ('music', 'music', 'form'),
#  ('music', 'music', 'origin'),
#  ('music', 'form', 'origin'),
#  ('genr', 'music', 'form'),
#  ('genr', 'music', 'origin'),
#  ('genr', 'music', 'african'),
#  ('genr', 'form', 'origin'),
#  ('genr', 'form', 'african'),
#  ('genr', 'origin', 'african'),
#  ('music', 'form', 'origin'),
#  ('music', 'form', 'african'),
#  ('music', 'form', 'american'),
#  ('music', 'origin', 'african'),
#  ('music', 'origin', 'american'),
#  ('music', 'african', 'american'),
#  ('form', 'origin', 'african'),
#  ('form', 'origin', 'american'),
#  ('form', 'origin', 'deep'),
#  ('form', 'african', 'american'),
#  ('form', 'african', 'deep'),
#  ('form', 'american', 'deep'),
#  ('origin', 'african', 'american'),
#  ('origin', 'african', 'deep'),
#  ('origin', 'african', 'south'),
#  ('origin', 'american', 'deep'),
#  ('origin', 'american', 'south'),
#  ('origin', 'deep', 'south'),
#  ('african', 'american', 'deep'),
#  ('african', 'american', 'south'),
#  ('african', 'american', 'unit'),
#  ('african', 'deep', 'south'),
#  ('african', 'deep', 'unit'),
#  ('african', 'south', 'unit'),
#  ('american', 'deep', 'south'),
#  ('american', 'deep', 'unit'),
#  ('american', 'deep', 'state'),
#  ('american', 'south', 'unit'),
#  ('american', 'south', 'state'),
#  ('american', 'unit', 'state'),
#  ('deep', 'south', 'unit'),
#  ('deep', 'south', 'state'),
#  ('deep', 'south', 'around'),
#  ('deep', 'unit', 'state'),
#  ('deep', 'unit', 'around'),
#  ('deep', 'state', 'around'),
#  ('south', 'unit', 'state'),
#  ('south', 'unit', 'around'),
#  ('south', 'unit', 'end'),
#  ('south', 'state', 'around'),
#  ('south', 'state', 'end'),
#  ('south', 'around', 'end'),
#  ('unit', 'state', 'around'),
#  ('unit', 'state', 'end'),
#  ('unit', 'state', 'centuri'),
#  ('unit', 'around', 'end'),
#  ('unit', 'around', 'centuri'),
#  ('unit', 'end', 'centuri'),
#  ('state', 'around', 'end'),
#  ('state', 'around', 'centuri'),
#  ('state', 'around', 'genr'),
#  ('state', 'end', 'centuri'),
#  ('state', 'end', 'genr'),
#  ('state', 'centuri', 'genr'),
#  ('around', 'end', 'centuri'),
#  ('around', 'end', 'genr'),
#  ('around', 'end', 'develop'),
#  ('around', 'centuri', 'genr'),
#  ('around', 'centuri', 'develop'),
#  ('around', 'genr', 'develop'),
#  ('end', 'centuri', 'genr'),
#  ('end', 'centuri', 'develop'),
#  ('end', 'centuri', 'root'),
#  ('end', 'genr', 'develop'),
#  ('end', 'genr', 'root'),
#  ('end', 'develop', 'root'),
#  ('centuri', 'genr', 'develop'),
#  ('centuri', 'genr', 'root'),
#  ('centuri', 'genr', 'african'),
#  ('centuri', 'develop', 'root'),
#  ('centuri', 'develop', 'african'),
#  ('centuri', 'root', 'african'),
#  ('genr', 'develop', 'root'),
#  ('genr', 'develop', 'african'),
#  ('genr', 'develop', 'music'),
#  ('genr', 'root', 'african'),
#  ('genr', 'root', 'music'),
#  ('genr', 'african', 'music'),
#  ('develop', 'root', 'african'),
#  ('develop', 'root', 'music'),
#  ('develop', 'root', 'tradit'),
#  ('develop', 'african', 'music'),
#  ('develop', 'african', 'tradit'),
#  ('develop', 'music', 'tradit'),
#  ('root', 'african', 'music'),
#  ('root', 'african', 'tradit'),
#  ('root', 'african', 'work'),
#  ('root', 'music', 'tradit'),
#  ('root', 'music', 'work'),
#  ('root', 'tradit', 'work'),
#  ('african', 'music', 'tradit'),
#  ('african', 'music', 'work'),
#  ('african', 'music', 'song'),
#  ('african', 'tradit', 'work'),
#  ('african', 'tradit', 'song'),
#  ('african', 'work', 'song'),
#  ('music', 'tradit', 'work'),
#  ('music', 'tradit', 'song'),
#  ('music', 'tradit', 'spiritu'),
#  ('music', 'work', 'song'),
#  ('music', 'work', 'spiritu'),
#  ('music', 'song', 'spiritu'),
#  ('tradit', 'work', 'song'),
#  ('tradit', 'work', 'spiritu'),
#  ('tradit', 'work', 'folk'),
#  ('tradit', 'song', 'spiritu'),
#  ('tradit', 'song', 'folk'),
#  ('tradit', 'spiritu', 'folk'),
#  ('work', 'song', 'spiritu'),
#  ('work', 'song', 'folk'),
#  ('work', 'song', 'music'),
#  ('work', 'spiritu', 'folk'),
#  ('work', 'spiritu', 'music'),
#  ('work', 'folk', 'music'),
#  ('song', 'spiritu', 'folk'),
#  ('song', 'spiritu', 'music'),
#  ('song', 'spiritu', 'white'),
#  ('song', 'folk', 'music'),
#  ('song', 'folk', 'white'),
#  ('song', 'music', 'white'),
#  ('spiritu', 'folk', 'music'),
#  ('spiritu', 'folk', 'white'),
#  ('spiritu', 'folk', 'american'),
#  ('spiritu', 'music', 'white'),
#  ('spiritu', 'music', 'american'),
#  ('spiritu', 'white', 'american'),
#  ('folk', 'music', 'white'),
#  ('folk', 'music', 'american'),
#  ('folk', 'music', 'european'),
#  ('folk', 'white', 'american'),
#  ('folk', 'white', 'european'),
#  ('folk', 'american', 'european'),
#  ('music', 'white', 'american'),
#  ('music', 'white', 'european'),
#  ('music', 'white', 'heritag'),
#  ('music', 'american', 'european'),
#  ('music', 'american', 'heritag'),
#  ('music', 'european', 'heritag'),
#  ('white', 'american', 'european'),
#  ('white', 'american', 'heritag'),
#  ('white', 'american', 'blue'),
#  ('white', 'european', 'heritag'),
#  ('white', 'european', 'blue'),
#  ('white', 'heritag', 'blue'),
#  ('american', 'european', 'heritag'),
#  ('american', 'european', 'blue'),
#  ('american', 'european', 'incorpor'),
#  ('american', 'heritag', 'blue'),
#  ('american', 'heritag', 'incorpor'),
#  ('american', 'blue', 'incorpor'),
#  ('european', 'heritag', 'blue'),
#  ('european', 'heritag', 'incorpor'),
#  ('european', 'heritag', 'spiritu'),
#  ('european', 'blue', 'incorpor'),
#  ('european', 'blue', 'spiritu'),
#  ('european', 'incorpor', 'spiritu'),
#  ('heritag', 'blue', 'incorpor'),
#  ('heritag', 'blue', 'spiritu'),
#  ('heritag', 'blue', 'work'),
#  ('heritag', 'incorpor', 'spiritu'),
#  ('heritag', 'incorpor', 'work'),
#  ('heritag', 'spiritu', 'work'),
#  ('blue', 'incorpor', 'spiritu'),
#  ('blue', 'incorpor', 'work'),
#  ('blue', 'incorpor', 'song'),
#  ('blue', 'spiritu', 'work'),
#  ('blue', 'spiritu', 'song'),
#  ('blue', 'work', 'song'),
#  ('incorpor', 'spiritu', 'work'),
#  ('incorpor', 'spiritu', 'song'),
#  ('incorpor', 'spiritu', 'field'),
#  ('incorpor', 'work', 'song'),
#  ('incorpor', 'work', 'field'),
#  ('incorpor', 'song', 'field'),
#  ('spiritu', 'work', 'song'),
#  ('spiritu', 'work', 'field'),
#  ('spiritu', 'work', 'holler'),
#  ('spiritu', 'song', 'field'),
#  ('spiritu', 'song', 'holler'),
#  ('spiritu', 'field', 'holler'),
#  ('work', 'song', 'field'),
#  ('work', 'song', 'holler'),
#  ('work', 'song', 'shout'),
#  ('work', 'field', 'holler'),
#  ('work', 'field', 'shout'),
#  ('work', 'holler', 'shout'),
#  ('song', 'field', 'holler'),
#  ('song', 'field', 'shout'),
#  ('song', 'field', 'chant'),
#  ('song', 'holler', 'shout'),
#  ('song', 'holler', 'chant'),
#  ('song', 'shout', 'chant'),
#  ('field', 'holler', 'shout'),
#  ('field', 'holler', 'chant'),
#  ('field', 'holler', 'rhyme'),
#  ('field', 'shout', 'chant'),
#  ('field', 'shout', 'rhyme'),
#  ('field', 'chant', 'rhyme'),
#  ('holler', 'shout', 'chant'),
#  ('holler', 'shout', 'rhyme'),
#  ('holler', 'shout', 'simpl'),
#  ('holler', 'chant', 'rhyme'),
#  ('holler', 'chant', 'simpl'),
#  ('holler', 'rhyme', 'simpl'),
#  ('shout', 'chant', 'rhyme'),
#  ('shout', 'chant', 'simpl'),
#  ('shout', 'chant', 'narr'),
#  ('shout', 'rhyme', 'simpl'),
#  ('shout', 'rhyme', 'narr'),
#  ('shout', 'simpl', 'narr'),
#  ('chant', 'rhyme', 'simpl'),
#  ('chant', 'rhyme', 'narr'),
#  ('chant', 'rhyme', 'ballad'),
#  ('chant', 'simpl', 'narr'),
#  ('chant', 'simpl', 'ballad'),
#  ('chant', 'narr', 'ballad'),
#  ('rhyme', 'simpl', 'narr'),
#  ('rhyme', 'simpl', 'ballad'),
#  ('rhyme', 'simpl', 'blue'),
#  ('rhyme', 'narr', 'ballad'),
#  ('rhyme', 'narr', 'blue'),
#  ('rhyme', 'ballad', 'blue'),
#  ('simpl', 'narr', 'ballad'),
#  ('simpl', 'narr', 'blue'),
#  ('simpl', 'narr', 'form'),
#  ('simpl', 'ballad', 'blue'),
#  ('simpl', 'ballad', 'form'),
#  ('simpl', 'blue', 'form'),
#  ('narr', 'ballad', 'blue'),
#  ('narr', 'ballad', 'form'),
#  ('narr', 'ballad', 'ubiquit'),
#  ('narr', 'blue', 'form'),
#  ('narr', 'blue', 'ubiquit'),
#  ('narr', 'form', 'ubiquit'),
#  ('ballad', 'blue', 'form'),
#  ('ballad', 'blue', 'ubiquit'),
#  ('ballad', 'blue', 'jazz'),
#  ('ballad', 'form', 'ubiquit'),
#  ('ballad', 'form', 'jazz'),
#  ('ballad', 'ubiquit', 'jazz'),
#  ('blue', 'form', 'ubiquit'),
#  ('blue', 'form', 'jazz'),
#  ('blue', 'form', 'rhythm'),
#  ('blue', 'ubiquit', 'jazz'),
#  ('blue', 'ubiquit', 'rhythm'),
#  ('blue', 'jazz', 'rhythm'),
#  ('form', 'ubiquit', 'jazz'),
#  ('form', 'ubiquit', 'rhythm'),
#  ('form', 'ubiquit', 'blue'),
#  ('form', 'jazz', 'rhythm'),
#  ('form', 'jazz', 'blue'),
#  ('form', 'rhythm', 'blue'),
#  ('ubiquit', 'jazz', 'rhythm'),
#  ('ubiquit', 'jazz', 'blue'),
#  ('ubiquit', 'jazz', 'rock'),
#  ('ubiquit', 'rhythm', 'blue'),
#  ('ubiquit', 'rhythm', 'rock'),
#  ('ubiquit', 'blue', 'rock'),
#  ('jazz', 'rhythm', 'blue'),
#  ('jazz', 'rhythm', 'rock'),
#  ('jazz', 'rhythm', 'roll'),
#  ('jazz', 'blue', 'rock'),
#  ('jazz', 'blue', 'roll'),
#  ('jazz', 'rock', 'roll'),
#  ('rhythm', 'blue', 'rock'),
#  ('rhythm', 'blue', 'roll'),
#  ('rhythm', 'blue', 'character'),
#  ('rhythm', 'rock', 'roll'),
#  ('rhythm', 'rock', 'character'),
#  ('rhythm', 'roll', 'character'),
#  ('blue', 'rock', 'roll'),
#  ('blue', 'rock', 'character'),
#  ('blue', 'rock', 'pattern'),
#  ('blue', 'roll', 'character'),
#  ('blue', 'roll', 'pattern'),
#  ('blue', 'character', 'pattern'),
#  ('rock', 'roll', 'character'),
#  ('rock', 'roll', 'pattern'),
#  ('rock', 'roll', 'blue'),
#  ('rock', 'character', 'pattern'),
#  ('rock', 'character', 'blue'),
#  ('rock', 'pattern', 'blue'),
#  ('roll', 'character', 'pattern'),
#  ('roll', 'character', 'blue'),
#  ('roll', 'character', 'scale'),
#  ('roll', 'pattern', 'blue'),
#  ('roll', 'pattern', 'scale'),
#  ('roll', 'blue', 'scale'),
#  ('character', 'pattern', 'blue'),
#  ('character', 'pattern', 'scale'),
#  ('character', 'pattern', 'specif'),
#  ('character', 'blue', 'scale'),
#  ('character', 'blue', 'specif'),
#  ('character', 'scale', 'specif'),
#  ('pattern', 'blue', 'scale'),
#  ('pattern', 'blue', 'specif'),
#  ('pattern', 'blue', 'chord'),
#  ('pattern', 'scale', 'specif'),
#  ('pattern', 'scale', 'chord'),
#  ('pattern', 'specif', 'chord'),
#  ('blue', 'scale', 'specif'),
#  ('blue', 'scale', 'chord'),
#  ('blue', 'scale', 'progress'),
#  ('blue', 'specif', 'chord'),
#  ('blue', 'specif', 'progress'),
#  ('blue', 'chord', 'progress'),
#  ('scale', 'specif', 'chord'),
#  ('scale', 'specif', 'progress'),
#  ('scale', 'specif', 'blue'),
#  ('scale', 'chord', 'progress'),
#  ('scale', 'chord', 'blue'),
#  ('scale', 'progress', 'blue'),
#  ('specif', 'chord', 'progress'),
#  ('specif', 'chord', 'blue'),
#  ('specif', 'chord', 'common'),
#  ('specif', 'progress', 'blue'),
#  ('specif', 'progress', 'common'),
#  ('specif', 'blue', 'common'),
#  ('chord', 'progress', 'blue'),
#  ('chord', 'progress', 'common'),
#  ('chord', 'progress', 'blue'),
#  ('chord', 'blue', 'common'),
#  ('chord', 'blue', 'blue'),
#  ('chord', 'common', 'blue'),
#  ('progress', 'blue', 'common'),
#  ('progress', 'blue', 'blue'),
#  ('progress', 'blue', 'note'),
#  ('progress', 'common', 'blue'),
#  ('progress', 'common', 'note'),
#  ('progress', 'blue', 'note'),
#  ('blue', 'common', 'blue'),
#  ('blue', 'common', 'note'),
#  ('blue', 'common', 'worri'),
#  ('blue', 'blue', 'note'),
#  ('blue', 'blue', 'worri'),
#  ('blue', 'note', 'worri'),
#  ('common', 'blue', 'note'),
#  ('common', 'blue', 'worri'),
#  ('common', 'blue', 'note'),
#  ('common', 'note', 'worri'),
#  ('common', 'note', 'note'),
#  ('common', 'worri', 'note'),
#  ('blue', 'note', 'worri'),
#  ('blue', 'note', 'note'),
#  ('blue', 'note', 'usual'),
#  ('blue', 'worri', 'note'),
#  ('blue', 'worri', 'usual'),
#  ('blue', 'note', 'usual'),
#  ('note', 'worri', 'note'),
#  ('note', 'worri', 'usual'),
#  ('note', 'worri', 'third'),
#  ('note', 'note', 'usual'),
#  ('note', 'note', 'third'),
#  ('note', 'usual', 'third'),
#  ('worri', 'note', 'usual'),
#  ('worri', 'note', 'third'),
#  ('worri', 'note', 'fifth'),
#  ('worri', 'usual', 'third'),
#  ('worri', 'usual', 'fifth'),
#  ('worri', 'third', 'fifth'),
#  ('note', 'usual', 'third'),
#  ('note', 'usual', 'fifth'),
#  ('note', 'usual', 'flatten'),
#  ('note', 'third', 'fifth'),
#  ('note', 'third', 'flatten'),
#  ('note', 'fifth', 'flatten'),
#  ('usual', 'third', 'fifth'),
#  ('usual', 'third', 'flatten'),
#  ('usual', 'third', 'pitch'),
#  ('usual', 'fifth', 'flatten'),
#  ('usual', 'fifth', 'pitch'),
#  ('usual', 'flatten', 'pitch'),
#  ('third', 'fifth', 'flatten'),
#  ('third', 'fifth', 'pitch'),
#  ('third', 'fifth', 'also'),
#  ('third', 'flatten', 'pitch'),
#  ('third', 'flatten', 'also'),
#  ('third', 'pitch', 'also'),
#  ('fifth', 'flatten', 'pitch'),
#  ('fifth', 'flatten', 'also'),
#  ('fifth', 'flatten', 'essenti'),
#  ('fifth', 'pitch', 'also'),
#  ('fifth', 'pitch', 'essenti'),
#  ('fifth', 'also', 'essenti'),
#  ('flatten', 'pitch', 'also'),
#  ('flatten', 'pitch', 'essenti'),
#  ('flatten', 'pitch', 'part'),
#  ('flatten', 'also', 'essenti'),
#  ('flatten', 'also', 'part'),
#  ('flatten', 'essenti', 'part'),
#  ('pitch', 'also', 'essenti'),
#  ('pitch', 'also', 'part'),
#  ('pitch', 'also', 'sound'),
#  ('pitch', 'essenti', 'part'),
#  ('pitch', 'essenti', 'sound'),
#  ('pitch', 'part', 'sound'),
#  ('also', 'essenti', 'part'),
#  ('also', 'essenti', 'sound'),
#  ('also', 'essenti', 'blue'),
#  ('also', 'part', 'sound'),
#  ('also', 'part', 'blue'),
#  ('also', 'sound', 'blue'),
#  ('essenti', 'part', 'sound'),
#  ('essenti', 'part', 'blue'),
#  ('essenti', 'part', 'shuffl'),
#  ('essenti', 'sound', 'blue'),
#  ('essenti', 'sound', 'shuffl'),
#  ('essenti', 'blue', 'shuffl'),
#  ('part', 'sound', 'blue'),
#  ('part', 'sound', 'shuffl'),
#  ('part', 'sound', 'walk'),
#  ('part', 'blue', 'shuffl'),
#  ('part', 'blue', 'walk'),
#  ('part', 'shuffl', 'walk'),
#  ('sound', 'blue', 'shuffl'),
#  ('sound', 'blue', 'walk'),
#  ('sound', 'blue', 'bass'),
#  ('sound', 'shuffl', 'walk'),
#  ('sound', 'shuffl', 'bass'),
#  ('sound', 'walk', 'bass'),
#  ('blue', 'shuffl', 'walk'),
#  ('blue', 'shuffl', 'bass'),
#  ('blue', 'shuffl', 'reinforc'),
#  ('blue', 'walk', 'bass'),
#  ('blue', 'walk', 'reinforc'),
#  ('blue', 'bass', 'reinforc'),
#  ('shuffl', 'walk', 'bass'),
#  ('shuffl', 'walk', 'reinforc'),
#  ('shuffl', 'walk', 'rhythm'),
#  ('shuffl', 'bass', 'reinforc'),
#  ('shuffl', 'bass', 'rhythm'),
#  ('shuffl', 'reinforc', 'rhythm'),
#  ('walk', 'bass', 'reinforc'),
#  ('walk', 'bass', 'rhythm'),
#  ('walk', 'bass', 'form'),
#  ('walk', 'reinforc', 'rhythm'),
#  ('walk', 'reinforc', 'form'),
#  ('walk', 'rhythm', 'form'),
#  ('bass', 'reinforc', 'rhythm'),
#  ('bass', 'reinforc', 'form'),
#  ('bass', 'reinforc', 'repetit'),
#  ('bass', 'rhythm', 'form'),
#  ('bass', 'rhythm', 'repetit'),
#  ('bass', 'form', 'repetit'),
#  ('reinforc', 'rhythm', 'form'),
#  ('reinforc', 'rhythm', 'repetit'),
#  ('reinforc', 'rhythm', 'effect'),
#  ('reinforc', 'form', 'repetit'),
#  ('reinforc', 'form', 'effect'),
#  ('reinforc', 'repetit', 'effect'),
#  ('rhythm', 'form', 'repetit'),
#  ('rhythm', 'form', 'effect'),
#  ('rhythm', 'form', 'known'),
#  ('rhythm', 'repetit', 'effect'),
#  ('rhythm', 'repetit', 'known'),
#  ('rhythm', 'effect', 'known'),
#  ('form', 'repetit', 'effect'),
#  ('form', 'repetit', 'known'),
#  ('form', 'repetit', 'groov'),
#  ('form', 'effect', 'known'),
#  ('form', 'effect', 'groov'),
#  ('form', 'known', 'groov'),
#  ('repetit', 'effect', 'known'),
#  ('repetit', 'effect', 'groov'),
#  ('repetit', 'effect', 'blue'),
#  ('repetit', 'known', 'groov'),
#  ('repetit', 'known', 'blue'),
#  ('repetit', 'groov', 'blue'),
#  ('effect', 'known', 'groov'),
#  ('effect', 'known', 'blue'),
#  ('effect', 'known', 'genr'),
#  ('effect', 'groov', 'blue'),
#  ('effect', 'groov', 'genr'),
#  ('effect', 'blue', 'genr'),
#  ('known', 'groov', 'blue'),
#  ('known', 'groov', 'genr'),
#  ('known', 'groov', 'also'),
#  ('known', 'blue', 'genr'),
#  ('known', 'blue', 'also'),
#  ('known', 'genr', 'also'),
#  ('groov', 'blue', 'genr'),
#  ('groov', 'blue', 'also'),
#  ('groov', 'blue', 'character'),
#  ('groov', 'genr', 'also'),
#  ('groov', 'genr', 'character'),
#  ('groov', 'also', 'character'),
#  ('blue', 'genr', 'also'),
#  ('blue', 'genr', 'character'),
#  ('blue', 'genr', 'lyric'),
#  ('blue', 'also', 'character'),
#  ('blue', 'also', 'lyric'),
#  ('blue', 'character', 'lyric'),
#  ('genr', 'also', 'character'),
#  ('genr', 'also', 'lyric'),
#  ('genr', 'also', 'bass'),
#  ('genr', 'character', 'lyric'),
#  ('genr', 'character', 'bass'),
#  ('genr', 'lyric', 'bass'),
#  ('also', 'character', 'lyric'),
#  ('also', 'character', 'bass'),
#  ('also', 'character', 'line'),
#  ('also', 'lyric', 'bass'),
#  ('also', 'lyric', 'line'),
#  ('also', 'bass', 'line'),
#  ('character', 'lyric', 'bass'),
#  ('character', 'lyric', 'line'),
#  ('character', 'lyric', 'instrument'),
#  ('character', 'bass', 'line'),
#  ('character', 'bass', 'instrument'),
#  ('character', 'line', 'instrument'),
#  ('lyric', 'bass', 'line'),
#  ('lyric', 'bass', 'instrument'),
#  ('lyric', 'bass', 'earli'),
#  ('lyric', 'line', 'instrument'),
#  ('lyric', 'line', 'earli'),
#  ('lyric', 'instrument', 'earli'),
#  ('bass', 'line', 'instrument'),
#  ('bass', 'line', 'earli'),
#  ('bass', 'line', 'tradit'),
#  ('bass', 'instrument', 'earli'),
#  ('bass', 'instrument', 'tradit'),
#  ('bass', 'earli', 'tradit'),
#  ('line', 'instrument', 'earli'),
#  ('line', 'instrument', 'tradit'),
#  ('line', 'instrument', 'blue'),
#  ('line', 'earli', 'tradit'),
#  ('line', 'earli', 'blue'),
#  ('line', 'tradit', 'blue'),
#  ('instrument', 'earli', 'tradit'),
#  ('instrument', 'earli', 'blue'),
#  ('instrument', 'earli', 'vers'),
#  ('instrument', 'tradit', 'blue'),
#  ('instrument', 'tradit', 'vers'),
#  ('instrument', 'blue', 'vers'),
#  ('earli', 'tradit', 'blue'),
#  ('earli', 'tradit', 'vers'),
#  ('earli', 'tradit', 'consist'),
#  ('earli', 'blue', 'vers'),
#  ('earli', 'blue', 'consist'),
#  ('earli', 'vers', 'consist'),
#  ('tradit', 'blue', 'vers'),
#  ('tradit', 'blue', 'consist'),
#  ('tradit', 'blue', 'singl'),
#  ('tradit', 'vers', 'consist'),
#  ('tradit', 'vers', 'singl'),
#  ('tradit', 'consist', 'singl'),
#  ('blue', 'vers', 'consist'),
#  ('blue', 'vers', 'singl'),
#  ('blue', 'vers', 'line'),
#  ('blue', 'consist', 'singl'),
#  ('blue', 'consist', 'line'),
#  ('blue', 'singl', 'line'),
#  ('vers', 'consist', 'singl'),
#  ('vers', 'consist', 'line'),
#  ('vers', 'consist', 'repeat'),
#  ('vers', 'singl', 'line'),
#  ('vers', 'singl', 'repeat'),
#  ('vers', 'line', 'repeat'),
#  ('consist', 'singl', 'line'),
#  ('consist', 'singl', 'repeat'),
#  ('consist', 'singl', 'four'),
#  ('consist', 'line', 'repeat'),
#  ('consist', 'line', 'four'),
#  ('consist', 'repeat', 'four'),
#  ('singl', 'line', 'repeat'),
#  ('singl', 'line', 'four'),
#  ('singl', 'line', 'time'),
#  ('singl', 'repeat', 'four'),
#  ('singl', 'repeat', 'time'),
#  ('singl', 'four', 'time'),
#  ('line', 'repeat', 'four'),
#  ('line', 'repeat', 'time'),
#  ('line', 'repeat', 'wa'),
#  ('line', 'four', 'time'),
#  ('line', 'four', 'wa'),
#  ('line', 'time', 'wa'),
#  ('repeat', 'four', 'time'),
#  ('repeat', 'four', 'wa'),
#  ('repeat', 'four', 'onli'),
#  ('repeat', 'time', 'wa'),
#  ('repeat', 'time', 'onli'),
#  ('repeat', 'wa', 'onli'),
#  ('four', 'time', 'wa'),
#  ('four', 'time', 'onli'),
#  ('four', 'time', 'first'),
#  ('four', 'wa', 'onli'),
#  ('four', 'wa', 'first'),
#  ('four', 'onli', 'first'),
#  ('time', 'wa', 'onli'),
#  ('time', 'wa', 'first'),
#  ('time', 'wa', 'decad'),
#  ('time', 'onli', 'first'),
#  ('time', 'onli', 'decad'),
#  ('time', 'first', 'decad'),
#  ('wa', 'onli', 'first'),
#  ('wa', 'onli', 'decad'),
#  ('wa', 'onli', 'centuri'),
#  ('wa', 'first', 'decad'),
#  ('wa', 'first', 'centuri'),
#  ('wa', 'decad', 'centuri'),
#  ('onli', 'first', 'decad'),
#  ('onli', 'first', 'centuri'),
#  ('onli', 'first', 'common'),
#  ('onli', 'decad', 'centuri'),
#  ('onli', 'decad', 'common'),
#  ('onli', 'centuri', 'common'),
#  ('first', 'decad', 'centuri'),
#  ('first', 'decad', 'common'),
#  ('first', 'decad', 'current'),
#  ('first', 'centuri', 'common'),
#  ('first', 'centuri', 'current'),
#  ('first', 'common', 'current'),
#  ('decad', 'centuri', 'common'),
#  ('decad', 'centuri', 'current'),
#  ('decad', 'centuri', 'structur'),
#  ('decad', 'common', 'current'),
#  ('decad', 'common', 'structur'),
#  ('decad', 'current', 'structur'),
#  ('centuri', 'common', 'current'),
#  ('centuri', 'common', 'structur'),
#  ('centuri', 'common', 'becam'),
#  ('centuri', 'current', 'structur'),
#  ('centuri', 'current', 'becam'),
#  ('centuri', 'structur', 'becam'),
#  ('common', 'current', 'structur'),
#  ('common', 'current', 'becam'),
#  ('common', 'current', 'standard'),
#  ('common', 'structur', 'becam'),
#  ('common', 'structur', 'standard'),
#  ('common', 'becam', 'standard'),
#  ('current', 'structur', 'becam'),
#  ('current', 'structur', 'standard'),
#  ('current', 'structur', 'aab'),
#  ('current', 'becam', 'standard'),
#  ('current', 'becam', 'aab'),
#  ('current', 'standard', 'aab'),
#  ('structur', 'becam', 'standard'),
#  ('structur', 'becam', 'aab'),
#  ('structur', 'becam', 'pattern'),
#  ('structur', 'standard', 'aab'),
#  ('structur', 'standard', 'pattern'),
#  ('structur', 'aab', 'pattern'),
#  ('becam', 'standard', 'aab'),
#  ('becam', 'standard', 'pattern'),
#  ('becam', 'standard', 'consist'),
#  ('becam', 'aab', 'pattern'),
#  ('becam', 'aab', 'consist'),
#  ('becam', 'pattern', 'consist'),
#  ('standard', 'aab', 'pattern'),
#  ('standard', 'aab', 'consist'),
#  ('standard', 'aab', 'line'),
#  ('standard', 'pattern', 'consist'),
#  ('standard', 'pattern', 'line'),
#  ('standard', 'consist', 'line'),
#  ('aab', 'pattern', 'consist'),
#  ('aab', 'pattern', 'line'),
#  ('aab', 'pattern', 'sung'),
#  ('aab', 'consist', 'line'),
#  ('aab', 'consist', 'sung'),
#  ('aab', 'line', 'sung'),
#  ('pattern', 'consist', 'line'),
#  ('pattern', 'consist', 'sung'),
#  ('pattern', 'consist', 'four'),
#  ('pattern', 'line', 'sung'),
#  ('pattern', 'line', 'four'),
#  ('pattern', 'sung', 'four'),
#  ('consist', 'line', 'sung'),
#  ('consist', 'line', 'four'),
#  ('consist', 'line', 'first'),
#  ('consist', 'sung', 'four'),
#  ('consist', 'sung', 'first'),
#  ('consist', 'four', 'first'),
#  ('line', 'sung', 'four'),
#  ('line', 'sung', 'first'),
#  ('line', 'sung', 'bar'),
#  ('line', 'four', 'first'),
#  ('line', 'four', 'bar'),
#  ('line', 'first', 'bar'),
#  ('sung', 'four', 'first'),
#  ('sung', 'four', 'bar'),
#  ('sung', 'four', 'repetit'),
#  ('sung', 'first', 'bar'),
#  ('sung', 'first', 'repetit'),
#  ('sung', 'bar', 'repetit'),
#  ('four', 'first', 'bar'),
#  ('four', 'first', 'repetit'),
#  ('four', 'first', 'next'),
#  ('four', 'bar', 'repetit'),
#  ('four', 'bar', 'next'),
#  ('four', 'repetit', 'next'),
#  ('first', 'bar', 'repetit'),
#  ('first', 'bar', 'next'),
#  ('first', 'bar', 'four'),
#  ('first', 'repetit', 'next'),
#  ('first', 'repetit', 'four'),
#  ('first', 'next', 'four'),
#  ('bar', 'repetit', 'next'),
#  ('bar', 'repetit', 'four'),
#  ('bar', 'repetit', 'longer'),
#  ('bar', 'next', 'four'),
#  ('bar', 'next', 'longer'),
#  ('bar', 'four', 'longer'),
#  ('repetit', 'next', 'four'),
#  ('repetit', 'next', 'longer'),
#  ('repetit', 'next', 'conclud'),
#  ('repetit', 'four', 'longer'),
#  ('repetit', 'four', 'conclud'),
#  ('repetit', 'longer', 'conclud'),
#  ('next', 'four', 'longer'),
#  ('next', 'four', 'conclud'),
#  ('next', 'four', 'line'),
#  ('next', 'longer', 'conclud'),
#  ('next', 'longer', 'line'),
#  ('next', 'conclud', 'line'),
#  ('four', 'longer', 'conclud'),
#  ('four', 'longer', 'line'),
#  ('four', 'longer', 'last'),
#  ('four', 'conclud', 'line'),
#  ('four', 'conclud', 'last'),
#  ('four', 'line', 'last'),
#  ('longer', 'conclud', 'line'),
#  ('longer', 'conclud', 'last'),
#  ('longer', 'conclud', 'bar'),
#  ('longer', 'line', 'last'),
#  ('longer', 'line', 'bar'),
#  ('longer', 'last', 'bar'),
#  ('conclud', 'line', 'last'),
#  ('conclud', 'line', 'bar'),
#  ('conclud', 'line', 'earli'),
#  ('conclud', 'last', 'bar'),
#  ('conclud', 'last', 'earli'),
#  ('conclud', 'bar', 'earli'),
#  ('line', 'last', 'bar'),
#  ('line', 'last', 'earli'),
#  ('line', 'last', 'blue'),
#  ('line', 'bar', 'earli'),
#  ('line', 'bar', 'blue'),
#  ('line', 'earli', 'blue'),
#  ('last', 'bar', 'earli'),
#  ('last', 'bar', 'blue'),
#  ('last', 'bar', 'frequent'),
#  ('last', 'earli', 'blue'),
#  ('last', 'earli', 'frequent'),
#  ('last', 'blue', 'frequent'),
#  ('bar', 'earli', 'blue'),
#  ('bar', 'earli', 'frequent'),
#  ('bar', 'earli', 'took'),
#  ('bar', 'blue', 'frequent'),
#  ('bar', 'blue', 'took'),
#  ('bar', 'frequent', 'took'),
#  ('earli', 'blue', 'frequent'),
#  ('earli', 'blue', 'took'),
#  ('earli', 'blue', 'form'),
#  ('earli', 'frequent', 'took'),
#  ('earli', 'frequent', 'form'),
#  ('earli', 'took', 'form'),
#  ('blue', 'frequent', 'took'),
#  ('blue', 'frequent', 'form'),
#  ('blue', 'frequent', 'loos'),
#  ('blue', 'took', 'form'),
#  ('blue', 'took', 'loos'),
#  ('blue', 'form', 'loos'),
#  ('frequent', 'took', 'form'),
#  ('frequent', 'took', 'loos'),
#  ('frequent', 'took', 'narr'),
#  ('frequent', 'form', 'loos'),
#  ('frequent', 'form', 'narr'),
#  ('frequent', 'loos', 'narr'),
#  ('took', 'form', 'loos'),
#  ('took', 'form', 'narr'),
#  ('took', 'form', 'often'),
#  ('took', 'loos', 'narr'),
#  ('took', 'loos', 'often'),
#  ('took', 'narr', 'often'),
#  ('form', 'loos', 'narr'),
#  ('form', 'loos', 'often'),
#  ('form', 'loos', 'relat'),
#  ('form', 'narr', 'often'),
#  ('form', 'narr', 'relat'),
#  ('form', 'often', 'relat'),
#  ('loos', 'narr', 'often'),
#  ('loos', 'narr', 'relat'),
#  ('loos', 'narr', 'racial'),
#  ('loos', 'often', 'relat'),
#  ('loos', 'often', 'racial'),
#  ('loos', 'relat', 'racial'),
#  ('narr', 'often', 'relat'),
#  ('narr', 'often', 'racial'),
#  ('narr', 'often', 'discrimin'),
#  ('narr', 'relat', 'racial'),
#  ('narr', 'relat', 'discrimin'),
#  ('narr', 'racial', 'discrimin'),
#  ('often', 'relat', 'racial'),
#  ('often', 'relat', 'discrimin'),
#  ('often', 'relat', 'challeng'),
#  ('often', 'racial', 'discrimin'),
#  ('often', 'racial', 'challeng'),
#  ('often', 'discrimin', 'challeng'),
#  ('relat', 'racial', 'discrimin'),
#  ('relat', 'racial', 'challeng'),
#  ('relat', 'racial', 'experienc'),
#  ('relat', 'discrimin', 'challeng'),
#  ('relat', 'discrimin', 'experienc'),
#  ('relat', 'challeng', 'experienc'),
#  ('racial', 'discrimin', 'challeng'),
#  ('racial', 'discrimin', 'experienc'),
#  ('racial', 'discrimin', 'mani'),
#  ('racial', 'challeng', 'experienc'),
#  ('racial', 'challeng', 'mani'),
#  ('racial', 'experienc', 'mani'),
#  ('discrimin', 'challeng', 'experienc'),
#  ('discrimin', 'challeng', 'mani'),
#  ('discrimin', 'challeng', 'element'),
#  ('discrimin', 'experienc', 'mani'),
#  ('discrimin', 'experienc', 'element'),
#  ('discrimin', 'mani', 'element'),
#  ('challeng', 'experienc', 'mani'),
#  ('challeng', 'experienc', 'element'),
#  ('challeng', 'experienc', 'format'),
#  ('challeng', 'mani', 'element'),
#  ('challeng', 'mani', 'format'),
#  ('challeng', 'element', 'format'),
#  ('experienc', 'mani', 'element'),
#  ('experienc', 'mani', 'format'),
#  ('experienc', 'mani', 'use'),
#  ('experienc', 'element', 'format'),
#  ('experienc', 'element', 'use'),
#  ('experienc', 'format', 'use'),
#  ('mani', 'element', 'format'),
#  ('mani', 'element', 'use'),
#  ('mani', 'element', 'blue'),
#  ('mani', 'format', 'use'),
#  ('mani', 'format', 'blue'),
#  ('mani', 'use', 'blue'),
#  ('element', 'format', 'use'),
#  ('element', 'format', 'blue'),
#  ('element', 'format', 'note'),
#  ('element', 'use', 'blue'),
#  ('element', 'use', 'note'),
#  ('element', 'blue', 'note'),
#  ('format', 'use', 'blue'),
#  ('format', 'use', 'note'),
#  ('format', 'use', 'trace'),
#  ('format', 'blue', 'note'),
#  ('format', 'blue', 'trace'),
#  ('format', 'note', 'trace'),
#  ('use', 'blue', 'note'),
#  ('use', 'blue', 'trace'),
#  ('use', 'blue', 'back'),
#  ('use', 'note', 'trace'),
#  ('use', 'note', 'back'),
#  ('use', 'trace', 'back'),
#  ('blue', 'note', 'trace'),
#  ('blue', 'note', 'back'),
#  ('blue', 'note', 'music'),
#  ('blue', 'trace', 'back'),
#  ('blue', 'trace', 'music'),
#  ('blue', 'back', 'music'),
#  ('note', 'trace', 'back'),
#  ('note', 'trace', 'music'),
#  ('note', 'trace', 'africa'),
#  ('note', 'back', 'music'),
#  ('note', 'back', 'africa'),
#  ('note', 'music', 'africa'),
#  ('trace', 'back', 'music'),
#  ('trace', 'back', 'africa'),
#  ('trace', 'back', 'origin'),
#  ('trace', 'music', 'africa'),
#  ('trace', 'music', 'origin'),
#  ('trace', 'africa', 'origin'),
#  ('back', 'music', 'africa'),
#  ('back', 'music', 'origin'),
#  ('back', 'music', 'blue'),
#  ('back', 'africa', 'origin'),
#  ('back', 'africa', 'blue'),
#  ('back', 'origin', 'blue'),
#  ('music', 'africa', 'origin'),
#  ('music', 'africa', 'blue'),
#  ('music', 'africa', 'also'),
#  ('music', 'origin', 'blue'),
#  ('music', 'origin', 'also'),
#  ('music', 'blue', 'also'),
#  ('africa', 'origin', 'blue'),
#  ('africa', 'origin', 'also'),
#  ('africa', 'origin', 'close'),
#  ('africa', 'blue', 'also'),
#  ('africa', 'blue', 'close'),
#  ('africa', 'also', 'close'),
#  ('origin', 'blue', 'also'),
#  ('origin', 'blue', 'close'),
#  ('origin', 'blue', 'relat'),
#  ('origin', 'also', 'close'),
#  ('origin', 'also', 'relat'),
#  ('origin', 'close', 'relat'),
#  ('blue', 'also', 'close'),
#  ('blue', 'also', 'relat'),
#  ('blue', 'also', 'religi'),
#  ('blue', 'close', 'relat'),
#  ('blue', 'close', 'religi'),
#  ('blue', 'relat', 'religi'),
#  ('also', 'close', 'relat'),
#  ('also', 'close', 'religi'),
#  ('also', 'close', 'music'),
#  ('also', 'relat', 'religi'),
#  ('also', 'relat', 'music'),
#  ('also', 'religi', 'music'),
#  ('close', 'relat', 'religi'),
#  ('close', 'relat', 'music'),
#  ('close', 'relat', 'commun'),
#  ('close', 'religi', 'music'),
#  ('close', 'religi', 'commun'),
#  ('close', 'music', 'commun'),
#  ('relat', 'religi', 'music'),
#  ('relat', 'religi', 'commun'),
#  ('relat', 'religi', 'spiritu'),
#  ('relat', 'music', 'commun'),
#  ('relat', 'music', 'spiritu'),
#  ('relat', 'commun', 'spiritu'),
#  ('religi', 'music', 'commun'),
#  ('religi', 'music', 'spiritu'),
#  ('religi', 'music', 'first'),
#  ('religi', 'commun', 'spiritu'),
#  ('religi', 'commun', 'first'),
#  ('religi', 'spiritu', 'first'),
#  ('music', 'commun', 'spiritu'),
#  ('music', 'commun', 'first'),
#  ('music', 'commun', 'appear'),
#  ('music', 'spiritu', 'first'),
#  ('music', 'spiritu', 'appear'),
#  ('music', 'first', 'appear'),
#  ('commun', 'spiritu', 'first'),
#  ('commun', 'spiritu', 'appear'),
#  ('commun', 'spiritu', 'blue'),
#  ('commun', 'first', 'appear'),
#  ('commun', 'first', 'blue'),
#  ('commun', 'appear', 'blue'),
#  ('spiritu', 'first', 'appear'),
#  ('spiritu', 'first', 'blue'),
#  ('spiritu', 'first', 'often'),
#  ('spiritu', 'appear', 'blue'),
#  ('spiritu', 'appear', 'often'),
#  ('spiritu', 'blue', 'often'),
#  ('first', 'appear', 'blue'),
#  ('first', 'appear', 'often'),
#  ('first', 'appear', 'date'),
#  ('first', 'blue', 'often'),
#  ('first', 'blue', 'date'),
#  ('first', 'often', 'date'),
#  ('appear', 'blue', 'often'),
#  ('appear', 'blue', 'date'),
#  ('appear', 'blue', 'end'),
#  ('appear', 'often', 'date'),
#  ('appear', 'often', 'end'),
#  ('appear', 'date', 'end'),
#  ('blue', 'often', 'date'),
#  ('blue', 'often', 'end'),
#  ('blue', 'often', 'slaveri'),
#  ('blue', 'date', 'end'),
#  ('blue', 'date', 'slaveri'),
#  ('blue', 'end', 'slaveri'),
#  ('often', 'date', 'end'),
#  ('often', 'date', 'slaveri'),
#  ('often', 'date', 'later'),
#  ('often', 'end', 'slaveri'),
#  ('often', 'end', 'later'),
#  ('often', 'slaveri', 'later'),
#  ('date', 'end', 'slaveri'),
#  ('date', 'end', 'later'),
#  ('date', 'end', 'develop'),
#  ('date', 'slaveri', 'later'),
#  ('date', 'slaveri', 'develop'),
#  ('date', 'later', 'develop'),
#  ('end', 'slaveri', 'later'),
#  ('end', 'slaveri', 'develop'),
#  ('end', 'slaveri', 'juke'),
#  ('end', 'later', 'develop'),
#  ('end', 'later', 'juke'),
#  ('end', 'develop', 'juke'),
#  ('slaveri', 'later', 'develop'),
#  ('slaveri', 'later', 'juke'),
#  ('slaveri', 'later', 'joint'),
#  ('slaveri', 'develop', 'juke'),
#  ...]

# %%
# Check skipgrams with quadgrams and 2 skips
music_skipgrams_4_2 = skipgrams(music_df['normalized_tokens'].sum(), 4, 2)
print('There are {} skipgrams with n=4, k=2'.format(len(list(music_skipgrams_4_2))))
music_skipgrams_4_2 = skipgrams(music_df['normalized_tokens'].sum(), 4, 2)
list(music_skipgrams_4_2)
# Out:
# There are 266815 skipgrams with n=4, k=2
# [('blue', 'music', 'genr', 'music'),
#  ('blue', 'music', 'genr', 'form'),
#  ('blue', 'music', 'genr', 'origin'),
#  ('blue', 'music', 'music', 'form'),
#  ('blue', 'music', 'music', 'origin'),
#  ('blue', 'music', 'form', 'origin'),
#  ('blue', 'genr', 'music', 'form'),
#  ('blue', 'genr', 'music', 'origin'),
#  ('blue', 'genr', 'form', 'origin'),
#  ('blue', 'music', 'form', 'origin'),
#  ('music', 'genr', 'music', 'form'),
#  ('music', 'genr', 'music', 'origin'),
#  ('music', 'genr', 'music', 'african'),
#  ('music', 'genr', 'form', 'origin'),
#  ('music', 'genr', 'form', 'african'),
#  ('music', 'genr', 'origin', 'african'),
#  ('music', 'music', 'form', 'origin'),
#  ('music', 'music', 'form', 'african'),
#  ('music', 'music', 'origin', 'african'),
#  ('music', 'form', 'origin', 'african'),
#  ('genr', 'music', 'form', 'origin'),
#  ('genr', 'music', 'form', 'african'),
#  ('genr', 'music', 'form', 'american'),
#  ('genr', 'music', 'origin', 'african'),
#  ('genr', 'music', 'origin', 'american'),
#  ('genr', 'music', 'african', 'american'),
#  ('genr', 'form', 'origin', 'african'),
#  ('genr', 'form', 'origin', 'american'),
#  ('genr', 'form', 'african', 'american'),
#  ('genr', 'origin', 'african', 'american'),
#  ('music', 'form', 'origin', 'african'),
#  ('music', 'form', 'origin', 'american'),
#  ('music', 'form', 'origin', 'deep'),
#  ('music', 'form', 'african', 'american'),
#  ('music', 'form', 'african', 'deep'),
#  ('music', 'form', 'american', 'deep'),
#  ('music', 'origin', 'african', 'american'),
#  ('music', 'origin', 'african', 'deep'),
#  ('music', 'origin', 'american', 'deep'),
#  ('music', 'african', 'american', 'deep'),
#  ('form', 'origin', 'african', 'american'),
#  ('form', 'origin', 'african', 'deep'),
#  ('form', 'origin', 'african', 'south'),
#  ('form', 'origin', 'american', 'deep'),
#  ('form', 'origin', 'american', 'south'),
#  ('form', 'origin', 'deep', 'south'),
#  ('form', 'african', 'american', 'deep'),
#  ('form', 'african', 'american', 'south'),
#  ('form', 'african', 'deep', 'south'),
#  ('form', 'american', 'deep', 'south'),
#  ('origin', 'african', 'american', 'deep'),
#  ('origin', 'african', 'american', 'south'),
#  ('origin', 'african', 'american', 'unit'),
#  ('origin', 'african', 'deep', 'south'),
#  ('origin', 'african', 'deep', 'unit'),
#  ('origin', 'african', 'south', 'unit'),
#  ('origin', 'american', 'deep', 'south'),
#  ('origin', 'american', 'deep', 'unit'),
#  ('origin', 'american', 'south', 'unit'),
#  ('origin', 'deep', 'south', 'unit'),
#  ('african', 'american', 'deep', 'south'),
#  ('african', 'american', 'deep', 'unit'),
#  ('african', 'american', 'deep', 'state'),
#  ('african', 'american', 'south', 'unit'),
#  ('african', 'american', 'south', 'state'),
#  ('african', 'american', 'unit', 'state'),
#  ('african', 'deep', 'south', 'unit'),
#  ('african', 'deep', 'south', 'state'),
#  ('african', 'deep', 'unit', 'state'),
#  ('african', 'south', 'unit', 'state'),
#  ('american', 'deep', 'south', 'unit'),
#  ('american', 'deep', 'south', 'state'),
#  ('american', 'deep', 'south', 'around'),
#  ('american', 'deep', 'unit', 'state'),
#  ('american', 'deep', 'unit', 'around'),
#  ('american', 'deep', 'state', 'around'),
#  ('american', 'south', 'unit', 'state'),
#  ('american', 'south', 'unit', 'around'),
#  ('american', 'south', 'state', 'around'),
#  ('american', 'unit', 'state', 'around'),
#  ('deep', 'south', 'unit', 'state'),
#  ('deep', 'south', 'unit', 'around'),
#  ('deep', 'south', 'unit', 'end'),
#  ('deep', 'south', 'state', 'around'),
#  ('deep', 'south', 'state', 'end'),
#  ('deep', 'south', 'around', 'end'),
#  ('deep', 'unit', 'state', 'around'),
#  ('deep', 'unit', 'state', 'end'),
#  ('deep', 'unit', 'around', 'end'),
#  ('deep', 'state', 'around', 'end'),
#  ('south', 'unit', 'state', 'around'),
#  ('south', 'unit', 'state', 'end'),
#  ('south', 'unit', 'state', 'centuri'),
#  ('south', 'unit', 'around', 'end'),
#  ('south', 'unit', 'around', 'centuri'),
#  ('south', 'unit', 'end', 'centuri'),
#  ('south', 'state', 'around', 'end'),
#  ('south', 'state', 'around', 'centuri'),
#  ('south', 'state', 'end', 'centuri'),
#  ('south', 'around', 'end', 'centuri'),
#  ('unit', 'state', 'around', 'end'),
#  ('unit', 'state', 'around', 'centuri'),
#  ('unit', 'state', 'around', 'genr'),
#  ('unit', 'state', 'end', 'centuri'),
#  ('unit', 'state', 'end', 'genr'),
#  ('unit', 'state', 'centuri', 'genr'),
#  ('unit', 'around', 'end', 'centuri'),
#  ('unit', 'around', 'end', 'genr'),
#  ('unit', 'around', 'centuri', 'genr'),
#  ('unit', 'end', 'centuri', 'genr'),
#  ('state', 'around', 'end', 'centuri'),
#  ('state', 'around', 'end', 'genr'),
#  ('state', 'around', 'end', 'develop'),
#  ('state', 'around', 'centuri', 'genr'),
#  ('state', 'around', 'centuri', 'develop'),
#  ('state', 'around', 'genr', 'develop'),
#  ('state', 'end', 'centuri', 'genr'),
#  ('state', 'end', 'centuri', 'develop'),
#  ('state', 'end', 'genr', 'develop'),
#  ('state', 'centuri', 'genr', 'develop'),
#  ('around', 'end', 'centuri', 'genr'),
#  ('around', 'end', 'centuri', 'develop'),
#  ('around', 'end', 'centuri', 'root'),
#  ('around', 'end', 'genr', 'develop'),
#  ('around', 'end', 'genr', 'root'),
#  ('around', 'end', 'develop', 'root'),
#  ('around', 'centuri', 'genr', 'develop'),
#  ('around', 'centuri', 'genr', 'root'),
#  ('around', 'centuri', 'develop', 'root'),
#  ('around', 'genr', 'develop', 'root'),
#  ('end', 'centuri', 'genr', 'develop'),
#  ('end', 'centuri', 'genr', 'root'),
#  ('end', 'centuri', 'genr', 'african'),
#  ('end', 'centuri', 'develop', 'root'),
#  ('end', 'centuri', 'develop', 'african'),
#  ('end', 'centuri', 'root', 'african'),
#  ('end', 'genr', 'develop', 'root'),
#  ('end', 'genr', 'develop', 'african'),
#  ('end', 'genr', 'root', 'african'),
#  ('end', 'develop', 'root', 'african'),
#  ('centuri', 'genr', 'develop', 'root'),
#  ('centuri', 'genr', 'develop', 'african'),
#  ('centuri', 'genr', 'develop', 'music'),
#  ('centuri', 'genr', 'root', 'african'),
#  ('centuri', 'genr', 'root', 'music'),
#  ('centuri', 'genr', 'african', 'music'),
#  ('centuri', 'develop', 'root', 'african'),
#  ('centuri', 'develop', 'root', 'music'),
#  ('centuri', 'develop', 'african', 'music'),
#  ('centuri', 'root', 'african', 'music'),
#  ('genr', 'develop', 'root', 'african'),
#  ('genr', 'develop', 'root', 'music'),
#  ('genr', 'develop', 'root', 'tradit'),
#  ('genr', 'develop', 'african', 'music'),
#  ('genr', 'develop', 'african', 'tradit'),
#  ('genr', 'develop', 'music', 'tradit'),
#  ('genr', 'root', 'african', 'music'),
#  ('genr', 'root', 'african', 'tradit'),
#  ('genr', 'root', 'music', 'tradit'),
#  ('genr', 'african', 'music', 'tradit'),
#  ('develop', 'root', 'african', 'music'),
#  ('develop', 'root', 'african', 'tradit'),
#  ('develop', 'root', 'african', 'work'),
#  ('develop', 'root', 'music', 'tradit'),
#  ('develop', 'root', 'music', 'work'),
#  ('develop', 'root', 'tradit', 'work'),
#  ('develop', 'african', 'music', 'tradit'),
#  ('develop', 'african', 'music', 'work'),
#  ('develop', 'african', 'tradit', 'work'),
#  ('develop', 'music', 'tradit', 'work'),
#  ('root', 'african', 'music', 'tradit'),
#  ('root', 'african', 'music', 'work'),
#  ('root', 'african', 'music', 'song'),
#  ('root', 'african', 'tradit', 'work'),
#  ('root', 'african', 'tradit', 'song'),
#  ('root', 'african', 'work', 'song'),
#  ('root', 'music', 'tradit', 'work'),
#  ('root', 'music', 'tradit', 'song'),
#  ('root', 'music', 'work', 'song'),
#  ('root', 'tradit', 'work', 'song'),
#  ('african', 'music', 'tradit', 'work'),
#  ('african', 'music', 'tradit', 'song'),
#  ('african', 'music', 'tradit', 'spiritu'),
#  ('african', 'music', 'work', 'song'),
#  ('african', 'music', 'work', 'spiritu'),
#  ('african', 'music', 'song', 'spiritu'),
#  ('african', 'tradit', 'work', 'song'),
#  ('african', 'tradit', 'work', 'spiritu'),
#  ('african', 'tradit', 'song', 'spiritu'),
#  ('african', 'work', 'song', 'spiritu'),
#  ('music', 'tradit', 'work', 'song'),
#  ('music', 'tradit', 'work', 'spiritu'),
#  ('music', 'tradit', 'work', 'folk'),
#  ('music', 'tradit', 'song', 'spiritu'),
#  ('music', 'tradit', 'song', 'folk'),
#  ('music', 'tradit', 'spiritu', 'folk'),
#  ('music', 'work', 'song', 'spiritu'),
#  ('music', 'work', 'song', 'folk'),
#  ('music', 'work', 'spiritu', 'folk'),
#  ('music', 'song', 'spiritu', 'folk'),
#  ('tradit', 'work', 'song', 'spiritu'),
#  ('tradit', 'work', 'song', 'folk'),
#  ('tradit', 'work', 'song', 'music'),
#  ('tradit', 'work', 'spiritu', 'folk'),
#  ('tradit', 'work', 'spiritu', 'music'),
#  ('tradit', 'work', 'folk', 'music'),
#  ('tradit', 'song', 'spiritu', 'folk'),
#  ('tradit', 'song', 'spiritu', 'music'),
#  ('tradit', 'song', 'folk', 'music'),
#  ('tradit', 'spiritu', 'folk', 'music'),
#  ('work', 'song', 'spiritu', 'folk'),
#  ('work', 'song', 'spiritu', 'music'),
#  ('work', 'song', 'spiritu', 'white'),
#  ('work', 'song', 'folk', 'music'),
#  ('work', 'song', 'folk', 'white'),
#  ('work', 'song', 'music', 'white'),
#  ('work', 'spiritu', 'folk', 'music'),
#  ('work', 'spiritu', 'folk', 'white'),
#  ('work', 'spiritu', 'music', 'white'),
#  ('work', 'folk', 'music', 'white'),
#  ('song', 'spiritu', 'folk', 'music'),
#  ('song', 'spiritu', 'folk', 'white'),
#  ('song', 'spiritu', 'folk', 'american'),
#  ('song', 'spiritu', 'music', 'white'),
#  ('song', 'spiritu', 'music', 'american'),
#  ('song', 'spiritu', 'white', 'american'),
#  ('song', 'folk', 'music', 'white'),
#  ('song', 'folk', 'music', 'american'),
#  ('song', 'folk', 'white', 'american'),
#  ('song', 'music', 'white', 'american'),
#  ('spiritu', 'folk', 'music', 'white'),
#  ('spiritu', 'folk', 'music', 'american'),
#  ('spiritu', 'folk', 'music', 'european'),
#  ('spiritu', 'folk', 'white', 'american'),
#  ('spiritu', 'folk', 'white', 'european'),
#  ('spiritu', 'folk', 'american', 'european'),
#  ('spiritu', 'music', 'white', 'american'),
#  ('spiritu', 'music', 'white', 'european'),
#  ('spiritu', 'music', 'american', 'european'),
#  ('spiritu', 'white', 'american', 'european'),
#  ('folk', 'music', 'white', 'american'),
#  ('folk', 'music', 'white', 'european'),
#  ('folk', 'music', 'white', 'heritag'),
#  ('folk', 'music', 'american', 'european'),
#  ('folk', 'music', 'american', 'heritag'),
#  ('folk', 'music', 'european', 'heritag'),
#  ('folk', 'white', 'american', 'european'),
#  ('folk', 'white', 'american', 'heritag'),
#  ('folk', 'white', 'european', 'heritag'),
#  ('folk', 'american', 'european', 'heritag'),
#  ('music', 'white', 'american', 'european'),
#  ('music', 'white', 'american', 'heritag'),
#  ('music', 'white', 'american', 'blue'),
#  ('music', 'white', 'european', 'heritag'),
#  ('music', 'white', 'european', 'blue'),
#  ('music', 'white', 'heritag', 'blue'),
#  ('music', 'american', 'european', 'heritag'),
#  ('music', 'american', 'european', 'blue'),
#  ('music', 'american', 'heritag', 'blue'),
#  ('music', 'european', 'heritag', 'blue'),
#  ('white', 'american', 'european', 'heritag'),
#  ('white', 'american', 'european', 'blue'),
#  ('white', 'american', 'european', 'incorpor'),
#  ('white', 'american', 'heritag', 'blue'),
#  ('white', 'american', 'heritag', 'incorpor'),
#  ('white', 'american', 'blue', 'incorpor'),
#  ('white', 'european', 'heritag', 'blue'),
#  ('white', 'european', 'heritag', 'incorpor'),
#  ('white', 'european', 'blue', 'incorpor'),
#  ('white', 'heritag', 'blue', 'incorpor'),
#  ('american', 'european', 'heritag', 'blue'),
#  ('american', 'european', 'heritag', 'incorpor'),
#  ('american', 'european', 'heritag', 'spiritu'),
#  ('american', 'european', 'blue', 'incorpor'),
#  ('american', 'european', 'blue', 'spiritu'),
#  ('american', 'european', 'incorpor', 'spiritu'),
#  ('american', 'heritag', 'blue', 'incorpor'),
#  ('american', 'heritag', 'blue', 'spiritu'),
#  ('american', 'heritag', 'incorpor', 'spiritu'),
#  ('american', 'blue', 'incorpor', 'spiritu'),
#  ('european', 'heritag', 'blue', 'incorpor'),
#  ('european', 'heritag', 'blue', 'spiritu'),
#  ('european', 'heritag', 'blue', 'work'),
#  ('european', 'heritag', 'incorpor', 'spiritu'),
#  ('european', 'heritag', 'incorpor', 'work'),
#  ('european', 'heritag', 'spiritu', 'work'),
#  ('european', 'blue', 'incorpor', 'spiritu'),
#  ('european', 'blue', 'incorpor', 'work'),
#  ('european', 'blue', 'spiritu', 'work'),
#  ('european', 'incorpor', 'spiritu', 'work'),
#  ('heritag', 'blue', 'incorpor', 'spiritu'),
#  ('heritag', 'blue', 'incorpor', 'work'),
#  ('heritag', 'blue', 'incorpor', 'song'),
#  ('heritag', 'blue', 'spiritu', 'work'),
#  ('heritag', 'blue', 'spiritu', 'song'),
#  ('heritag', 'blue', 'work', 'song'),
#  ('heritag', 'incorpor', 'spiritu', 'work'),
#  ('heritag', 'incorpor', 'spiritu', 'song'),
#  ('heritag', 'incorpor', 'work', 'song'),
#  ('heritag', 'spiritu', 'work', 'song'),
#  ('blue', 'incorpor', 'spiritu', 'work'),
#  ('blue', 'incorpor', 'spiritu', 'song'),
#  ('blue', 'incorpor', 'spiritu', 'field'),
#  ('blue', 'incorpor', 'work', 'song'),
#  ('blue', 'incorpor', 'work', 'field'),
#  ('blue', 'incorpor', 'song', 'field'),
#  ('blue', 'spiritu', 'work', 'song'),
#  ('blue', 'spiritu', 'work', 'field'),
#  ('blue', 'spiritu', 'song', 'field'),
#  ('blue', 'work', 'song', 'field'),
#  ('incorpor', 'spiritu', 'work', 'song'),
#  ('incorpor', 'spiritu', 'work', 'field'),
#  ('incorpor', 'spiritu', 'work', 'holler'),
#  ('incorpor', 'spiritu', 'song', 'field'),
#  ('incorpor', 'spiritu', 'song', 'holler'),
#  ('incorpor', 'spiritu', 'field', 'holler'),
#  ('incorpor', 'work', 'song', 'field'),
#  ('incorpor', 'work', 'song', 'holler'),
#  ('incorpor', 'work', 'field', 'holler'),
#  ('incorpor', 'song', 'field', 'holler'),
#  ('spiritu', 'work', 'song', 'field'),
#  ('spiritu', 'work', 'song', 'holler'),
#  ('spiritu', 'work', 'song', 'shout'),
#  ('spiritu', 'work', 'field', 'holler'),
#  ('spiritu', 'work', 'field', 'shout'),
#  ('spiritu', 'work', 'holler', 'shout'),
#  ('spiritu', 'song', 'field', 'holler'),
#  ('spiritu', 'song', 'field', 'shout'),
#  ('spiritu', 'song', 'holler', 'shout'),
#  ('spiritu', 'field', 'holler', 'shout'),
#  ('work', 'song', 'field', 'holler'),
#  ('work', 'song', 'field', 'shout'),
#  ('work', 'song', 'field', 'chant'),
#  ('work', 'song', 'holler', 'shout'),
#  ('work', 'song', 'holler', 'chant'),
#  ('work', 'song', 'shout', 'chant'),
#  ('work', 'field', 'holler', 'shout'),
#  ('work', 'field', 'holler', 'chant'),
#  ('work', 'field', 'shout', 'chant'),
#  ('work', 'holler', 'shout', 'chant'),
#  ('song', 'field', 'holler', 'shout'),
#  ('song', 'field', 'holler', 'chant'),
#  ('song', 'field', 'holler', 'rhyme'),
#  ('song', 'field', 'shout', 'chant'),
#  ('song', 'field', 'shout', 'rhyme'),
#  ('song', 'field', 'chant', 'rhyme'),
#  ('song', 'holler', 'shout', 'chant'),
#  ('song', 'holler', 'shout', 'rhyme'),
#  ('song', 'holler', 'chant', 'rhyme'),
#  ('song', 'shout', 'chant', 'rhyme'),
#  ('field', 'holler', 'shout', 'chant'),
#  ('field', 'holler', 'shout', 'rhyme'),
#  ('field', 'holler', 'shout', 'simpl'),
#  ('field', 'holler', 'chant', 'rhyme'),
#  ('field', 'holler', 'chant', 'simpl'),
#  ('field', 'holler', 'rhyme', 'simpl'),
#  ('field', 'shout', 'chant', 'rhyme'),
#  ('field', 'shout', 'chant', 'simpl'),
#  ('field', 'shout', 'rhyme', 'simpl'),
#  ('field', 'chant', 'rhyme', 'simpl'),
#  ('holler', 'shout', 'chant', 'rhyme'),
#  ('holler', 'shout', 'chant', 'simpl'),
#  ('holler', 'shout', 'chant', 'narr'),
#  ('holler', 'shout', 'rhyme', 'simpl'),
#  ('holler', 'shout', 'rhyme', 'narr'),
#  ('holler', 'shout', 'simpl', 'narr'),
#  ('holler', 'chant', 'rhyme', 'simpl'),
#  ('holler', 'chant', 'rhyme', 'narr'),
#  ('holler', 'chant', 'simpl', 'narr'),
#  ('holler', 'rhyme', 'simpl', 'narr'),
#  ('shout', 'chant', 'rhyme', 'simpl'),
#  ('shout', 'chant', 'rhyme', 'narr'),
#  ('shout', 'chant', 'rhyme', 'ballad'),
#  ('shout', 'chant', 'simpl', 'narr'),
#  ('shout', 'chant', 'simpl', 'ballad'),
#  ('shout', 'chant', 'narr', 'ballad'),
#  ('shout', 'rhyme', 'simpl', 'narr'),
#  ('shout', 'rhyme', 'simpl', 'ballad'),
#  ('shout', 'rhyme', 'narr', 'ballad'),
#  ('shout', 'simpl', 'narr', 'ballad'),
#  ('chant', 'rhyme', 'simpl', 'narr'),
#  ('chant', 'rhyme', 'simpl', 'ballad'),
#  ('chant', 'rhyme', 'simpl', 'blue'),
#  ('chant', 'rhyme', 'narr', 'ballad'),
#  ('chant', 'rhyme', 'narr', 'blue'),
#  ('chant', 'rhyme', 'ballad', 'blue'),
#  ('chant', 'simpl', 'narr', 'ballad'),
#  ('chant', 'simpl', 'narr', 'blue'),
#  ('chant', 'simpl', 'ballad', 'blue'),
#  ('chant', 'narr', 'ballad', 'blue'),
#  ('rhyme', 'simpl', 'narr', 'ballad'),
#  ('rhyme', 'simpl', 'narr', 'blue'),
#  ('rhyme', 'simpl', 'narr', 'form'),
#  ('rhyme', 'simpl', 'ballad', 'blue'),
#  ('rhyme', 'simpl', 'ballad', 'form'),
#  ('rhyme', 'simpl', 'blue', 'form'),
#  ('rhyme', 'narr', 'ballad', 'blue'),
#  ('rhyme', 'narr', 'ballad', 'form'),
#  ('rhyme', 'narr', 'blue', 'form'),
#  ('rhyme', 'ballad', 'blue', 'form'),
#  ('simpl', 'narr', 'ballad', 'blue'),
#  ('simpl', 'narr', 'ballad', 'form'),
#  ('simpl', 'narr', 'ballad', 'ubiquit'),
#  ('simpl', 'narr', 'blue', 'form'),
#  ('simpl', 'narr', 'blue', 'ubiquit'),
#  ('simpl', 'narr', 'form', 'ubiquit'),
#  ('simpl', 'ballad', 'blue', 'form'),
#  ('simpl', 'ballad', 'blue', 'ubiquit'),
#  ('simpl', 'ballad', 'form', 'ubiquit'),
#  ('simpl', 'blue', 'form', 'ubiquit'),
#  ('narr', 'ballad', 'blue', 'form'),
#  ('narr', 'ballad', 'blue', 'ubiquit'),
#  ('narr', 'ballad', 'blue', 'jazz'),
#  ('narr', 'ballad', 'form', 'ubiquit'),
#  ('narr', 'ballad', 'form', 'jazz'),
#  ('narr', 'ballad', 'ubiquit', 'jazz'),
#  ('narr', 'blue', 'form', 'ubiquit'),
#  ('narr', 'blue', 'form', 'jazz'),
#  ('narr', 'blue', 'ubiquit', 'jazz'),
#  ('narr', 'form', 'ubiquit', 'jazz'),
#  ('ballad', 'blue', 'form', 'ubiquit'),
#  ('ballad', 'blue', 'form', 'jazz'),
#  ('ballad', 'blue', 'form', 'rhythm'),
#  ('ballad', 'blue', 'ubiquit', 'jazz'),
#  ('ballad', 'blue', 'ubiquit', 'rhythm'),
#  ('ballad', 'blue', 'jazz', 'rhythm'),
#  ('ballad', 'form', 'ubiquit', 'jazz'),
#  ('ballad', 'form', 'ubiquit', 'rhythm'),
#  ('ballad', 'form', 'jazz', 'rhythm'),
#  ('ballad', 'ubiquit', 'jazz', 'rhythm'),
#  ('blue', 'form', 'ubiquit', 'jazz'),
#  ('blue', 'form', 'ubiquit', 'rhythm'),
#  ('blue', 'form', 'ubiquit', 'blue'),
#  ('blue', 'form', 'jazz', 'rhythm'),
#  ('blue', 'form', 'jazz', 'blue'),
#  ('blue', 'form', 'rhythm', 'blue'),
#  ('blue', 'ubiquit', 'jazz', 'rhythm'),
#  ('blue', 'ubiquit', 'jazz', 'blue'),
#  ('blue', 'ubiquit', 'rhythm', 'blue'),
#  ('blue', 'jazz', 'rhythm', 'blue'),
#  ('form', 'ubiquit', 'jazz', 'rhythm'),
#  ('form', 'ubiquit', 'jazz', 'blue'),
#  ('form', 'ubiquit', 'jazz', 'rock'),
#  ('form', 'ubiquit', 'rhythm', 'blue'),
#  ('form', 'ubiquit', 'rhythm', 'rock'),
#  ('form', 'ubiquit', 'blue', 'rock'),
#  ('form', 'jazz', 'rhythm', 'blue'),
#  ('form', 'jazz', 'rhythm', 'rock'),
#  ('form', 'jazz', 'blue', 'rock'),
#  ('form', 'rhythm', 'blue', 'rock'),
#  ('ubiquit', 'jazz', 'rhythm', 'blue'),
#  ('ubiquit', 'jazz', 'rhythm', 'rock'),
#  ('ubiquit', 'jazz', 'rhythm', 'roll'),
#  ('ubiquit', 'jazz', 'blue', 'rock'),
#  ('ubiquit', 'jazz', 'blue', 'roll'),
#  ('ubiquit', 'jazz', 'rock', 'roll'),
#  ('ubiquit', 'rhythm', 'blue', 'rock'),
#  ('ubiquit', 'rhythm', 'blue', 'roll'),
#  ('ubiquit', 'rhythm', 'rock', 'roll'),
#  ('ubiquit', 'blue', 'rock', 'roll'),
#  ('jazz', 'rhythm', 'blue', 'rock'),
#  ('jazz', 'rhythm', 'blue', 'roll'),
#  ('jazz', 'rhythm', 'blue', 'character'),
#  ('jazz', 'rhythm', 'rock', 'roll'),
#  ('jazz', 'rhythm', 'rock', 'character'),
#  ('jazz', 'rhythm', 'roll', 'character'),
#  ('jazz', 'blue', 'rock', 'roll'),
#  ('jazz', 'blue', 'rock', 'character'),
#  ('jazz', 'blue', 'roll', 'character'),
#  ('jazz', 'rock', 'roll', 'character'),
#  ('rhythm', 'blue', 'rock', 'roll'),
#  ('rhythm', 'blue', 'rock', 'character'),
#  ('rhythm', 'blue', 'rock', 'pattern'),
#  ('rhythm', 'blue', 'roll', 'character'),
#  ('rhythm', 'blue', 'roll', 'pattern'),
#  ('rhythm', 'blue', 'character', 'pattern'),
#  ('rhythm', 'rock', 'roll', 'character'),
#  ('rhythm', 'rock', 'roll', 'pattern'),
#  ('rhythm', 'rock', 'character', 'pattern'),
#  ('rhythm', 'roll', 'character', 'pattern'),
#  ('blue', 'rock', 'roll', 'character'),
#  ('blue', 'rock', 'roll', 'pattern'),
#  ('blue', 'rock', 'roll', 'blue'),
#  ('blue', 'rock', 'character', 'pattern'),
#  ('blue', 'rock', 'character', 'blue'),
#  ('blue', 'rock', 'pattern', 'blue'),
#  ('blue', 'roll', 'character', 'pattern'),
#  ('blue', 'roll', 'character', 'blue'),
#  ('blue', 'roll', 'pattern', 'blue'),
#  ('blue', 'character', 'pattern', 'blue'),
#  ('rock', 'roll', 'character', 'pattern'),
#  ('rock', 'roll', 'character', 'blue'),
#  ('rock', 'roll', 'character', 'scale'),
#  ('rock', 'roll', 'pattern', 'blue'),
#  ('rock', 'roll', 'pattern', 'scale'),
#  ('rock', 'roll', 'blue', 'scale'),
#  ('rock', 'character', 'pattern', 'blue'),
#  ('rock', 'character', 'pattern', 'scale'),
#  ('rock', 'character', 'blue', 'scale'),
#  ('rock', 'pattern', 'blue', 'scale'),
#  ('roll', 'character', 'pattern', 'blue'),
#  ('roll', 'character', 'pattern', 'scale'),
#  ('roll', 'character', 'pattern', 'specif'),
#  ('roll', 'character', 'blue', 'scale'),
#  ('roll', 'character', 'blue', 'specif'),
#  ('roll', 'character', 'scale', 'specif'),
#  ('roll', 'pattern', 'blue', 'scale'),
#  ('roll', 'pattern', 'blue', 'specif'),
#  ('roll', 'pattern', 'scale', 'specif'),
#  ('roll', 'blue', 'scale', 'specif'),
#  ('character', 'pattern', 'blue', 'scale'),
#  ('character', 'pattern', 'blue', 'specif'),
#  ('character', 'pattern', 'blue', 'chord'),
#  ('character', 'pattern', 'scale', 'specif'),
#  ('character', 'pattern', 'scale', 'chord'),
#  ('character', 'pattern', 'specif', 'chord'),
#  ('character', 'blue', 'scale', 'specif'),
#  ('character', 'blue', 'scale', 'chord'),
#  ('character', 'blue', 'specif', 'chord'),
#  ('character', 'scale', 'specif', 'chord'),
#  ('pattern', 'blue', 'scale', 'specif'),
#  ('pattern', 'blue', 'scale', 'chord'),
#  ('pattern', 'blue', 'scale', 'progress'),
#  ('pattern', 'blue', 'specif', 'chord'),
#  ('pattern', 'blue', 'specif', 'progress'),
#  ('pattern', 'blue', 'chord', 'progress'),
#  ('pattern', 'scale', 'specif', 'chord'),
#  ('pattern', 'scale', 'specif', 'progress'),
#  ('pattern', 'scale', 'chord', 'progress'),
#  ('pattern', 'specif', 'chord', 'progress'),
#  ('blue', 'scale', 'specif', 'chord'),
#  ('blue', 'scale', 'specif', 'progress'),
#  ('blue', 'scale', 'specif', 'blue'),
#  ('blue', 'scale', 'chord', 'progress'),
#  ('blue', 'scale', 'chord', 'blue'),
#  ('blue', 'scale', 'progress', 'blue'),
#  ('blue', 'specif', 'chord', 'progress'),
#  ('blue', 'specif', 'chord', 'blue'),
#  ('blue', 'specif', 'progress', 'blue'),
#  ('blue', 'chord', 'progress', 'blue'),
#  ('scale', 'specif', 'chord', 'progress'),
#  ('scale', 'specif', 'chord', 'blue'),
#  ('scale', 'specif', 'chord', 'common'),
#  ('scale', 'specif', 'progress', 'blue'),
#  ('scale', 'specif', 'progress', 'common'),
#  ('scale', 'specif', 'blue', 'common'),
#  ('scale', 'chord', 'progress', 'blue'),
#  ('scale', 'chord', 'progress', 'common'),
#  ('scale', 'chord', 'blue', 'common'),
#  ('scale', 'progress', 'blue', 'common'),
#  ('specif', 'chord', 'progress', 'blue'),
#  ('specif', 'chord', 'progress', 'common'),
#  ('specif', 'chord', 'progress', 'blue'),
#  ('specif', 'chord', 'blue', 'common'),
#  ('specif', 'chord', 'blue', 'blue'),
#  ('specif', 'chord', 'common', 'blue'),
#  ('specif', 'progress', 'blue', 'common'),
#  ('specif', 'progress', 'blue', 'blue'),
#  ('specif', 'progress', 'common', 'blue'),
#  ('specif', 'blue', 'common', 'blue'),
#  ('chord', 'progress', 'blue', 'common'),
#  ('chord', 'progress', 'blue', 'blue'),
#  ('chord', 'progress', 'blue', 'note'),
#  ('chord', 'progress', 'common', 'blue'),
#  ('chord', 'progress', 'common', 'note'),
#  ('chord', 'progress', 'blue', 'note'),
#  ('chord', 'blue', 'common', 'blue'),
#  ('chord', 'blue', 'common', 'note'),
#  ('chord', 'blue', 'blue', 'note'),
#  ('chord', 'common', 'blue', 'note'),
#  ('progress', 'blue', 'common', 'blue'),
#  ('progress', 'blue', 'common', 'note'),
#  ('progress', 'blue', 'common', 'worri'),
#  ('progress', 'blue', 'blue', 'note'),
#  ('progress', 'blue', 'blue', 'worri'),
#  ('progress', 'blue', 'note', 'worri'),
#  ('progress', 'common', 'blue', 'note'),
#  ('progress', 'common', 'blue', 'worri'),
#  ('progress', 'common', 'note', 'worri'),
#  ('progress', 'blue', 'note', 'worri'),
#  ('blue', 'common', 'blue', 'note'),
#  ('blue', 'common', 'blue', 'worri'),
#  ('blue', 'common', 'blue', 'note'),
#  ('blue', 'common', 'note', 'worri'),
#  ('blue', 'common', 'note', 'note'),
#  ('blue', 'common', 'worri', 'note'),
#  ('blue', 'blue', 'note', 'worri'),
#  ('blue', 'blue', 'note', 'note'),
#  ('blue', 'blue', 'worri', 'note'),
#  ('blue', 'note', 'worri', 'note'),
#  ('common', 'blue', 'note', 'worri'),
#  ('common', 'blue', 'note', 'note'),
#  ('common', 'blue', 'note', 'usual'),
#  ('common', 'blue', 'worri', 'note'),
#  ('common', 'blue', 'worri', 'usual'),
#  ('common', 'blue', 'note', 'usual'),
#  ('common', 'note', 'worri', 'note'),
#  ('common', 'note', 'worri', 'usual'),
#  ('common', 'note', 'note', 'usual'),
#  ('common', 'worri', 'note', 'usual'),
#  ('blue', 'note', 'worri', 'note'),
#  ('blue', 'note', 'worri', 'usual'),
#  ('blue', 'note', 'worri', 'third'),
#  ('blue', 'note', 'note', 'usual'),
#  ('blue', 'note', 'note', 'third'),
#  ('blue', 'note', 'usual', 'third'),
#  ('blue', 'worri', 'note', 'usual'),
#  ('blue', 'worri', 'note', 'third'),
#  ('blue', 'worri', 'usual', 'third'),
#  ('blue', 'note', 'usual', 'third'),
#  ('note', 'worri', 'note', 'usual'),
#  ('note', 'worri', 'note', 'third'),
#  ('note', 'worri', 'note', 'fifth'),
#  ('note', 'worri', 'usual', 'third'),
#  ('note', 'worri', 'usual', 'fifth'),
#  ('note', 'worri', 'third', 'fifth'),
#  ('note', 'note', 'usual', 'third'),
#  ('note', 'note', 'usual', 'fifth'),
#  ('note', 'note', 'third', 'fifth'),
#  ('note', 'usual', 'third', 'fifth'),
#  ('worri', 'note', 'usual', 'third'),
#  ('worri', 'note', 'usual', 'fifth'),
#  ('worri', 'note', 'usual', 'flatten'),
#  ('worri', 'note', 'third', 'fifth'),
#  ('worri', 'note', 'third', 'flatten'),
#  ('worri', 'note', 'fifth', 'flatten'),
#  ('worri', 'usual', 'third', 'fifth'),
#  ('worri', 'usual', 'third', 'flatten'),
#  ('worri', 'usual', 'fifth', 'flatten'),
#  ('worri', 'third', 'fifth', 'flatten'),
#  ('note', 'usual', 'third', 'fifth'),
#  ('note', 'usual', 'third', 'flatten'),
#  ('note', 'usual', 'third', 'pitch'),
#  ('note', 'usual', 'fifth', 'flatten'),
#  ('note', 'usual', 'fifth', 'pitch'),
#  ('note', 'usual', 'flatten', 'pitch'),
#  ('note', 'third', 'fifth', 'flatten'),
#  ('note', 'third', 'fifth', 'pitch'),
#  ('note', 'third', 'flatten', 'pitch'),
#  ('note', 'fifth', 'flatten', 'pitch'),
#  ('usual', 'third', 'fifth', 'flatten'),
#  ('usual', 'third', 'fifth', 'pitch'),
#  ('usual', 'third', 'fifth', 'also'),
#  ('usual', 'third', 'flatten', 'pitch'),
#  ('usual', 'third', 'flatten', 'also'),
#  ('usual', 'third', 'pitch', 'also'),
#  ('usual', 'fifth', 'flatten', 'pitch'),
#  ('usual', 'fifth', 'flatten', 'also'),
#  ('usual', 'fifth', 'pitch', 'also'),
#  ('usual', 'flatten', 'pitch', 'also'),
#  ('third', 'fifth', 'flatten', 'pitch'),
#  ('third', 'fifth', 'flatten', 'also'),
#  ('third', 'fifth', 'flatten', 'essenti'),
#  ('third', 'fifth', 'pitch', 'also'),
#  ('third', 'fifth', 'pitch', 'essenti'),
#  ('third', 'fifth', 'also', 'essenti'),
#  ('third', 'flatten', 'pitch', 'also'),
#  ('third', 'flatten', 'pitch', 'essenti'),
#  ('third', 'flatten', 'also', 'essenti'),
#  ('third', 'pitch', 'also', 'essenti'),
#  ('fifth', 'flatten', 'pitch', 'also'),
#  ('fifth', 'flatten', 'pitch', 'essenti'),
#  ('fifth', 'flatten', 'pitch', 'part'),
#  ('fifth', 'flatten', 'also', 'essenti'),
#  ('fifth', 'flatten', 'also', 'part'),
#  ('fifth', 'flatten', 'essenti', 'part'),
#  ('fifth', 'pitch', 'also', 'essenti'),
#  ('fifth', 'pitch', 'also', 'part'),
#  ('fifth', 'pitch', 'essenti', 'part'),
#  ('fifth', 'also', 'essenti', 'part'),
#  ('flatten', 'pitch', 'also', 'essenti'),
#  ('flatten', 'pitch', 'also', 'part'),
#  ('flatten', 'pitch', 'also', 'sound'),
#  ('flatten', 'pitch', 'essenti', 'part'),
#  ('flatten', 'pitch', 'essenti', 'sound'),
#  ('flatten', 'pitch', 'part', 'sound'),
#  ('flatten', 'also', 'essenti', 'part'),
#  ('flatten', 'also', 'essenti', 'sound'),
#  ('flatten', 'also', 'part', 'sound'),
#  ('flatten', 'essenti', 'part', 'sound'),
#  ('pitch', 'also', 'essenti', 'part'),
#  ('pitch', 'also', 'essenti', 'sound'),
#  ('pitch', 'also', 'essenti', 'blue'),
#  ('pitch', 'also', 'part', 'sound'),
#  ('pitch', 'also', 'part', 'blue'),
#  ('pitch', 'also', 'sound', 'blue'),
#  ('pitch', 'essenti', 'part', 'sound'),
#  ('pitch', 'essenti', 'part', 'blue'),
#  ('pitch', 'essenti', 'sound', 'blue'),
#  ('pitch', 'part', 'sound', 'blue'),
#  ('also', 'essenti', 'part', 'sound'),
#  ('also', 'essenti', 'part', 'blue'),
#  ('also', 'essenti', 'part', 'shuffl'),
#  ('also', 'essenti', 'sound', 'blue'),
#  ('also', 'essenti', 'sound', 'shuffl'),
#  ('also', 'essenti', 'blue', 'shuffl'),
#  ('also', 'part', 'sound', 'blue'),
#  ('also', 'part', 'sound', 'shuffl'),
#  ('also', 'part', 'blue', 'shuffl'),
#  ('also', 'sound', 'blue', 'shuffl'),
#  ('essenti', 'part', 'sound', 'blue'),
#  ('essenti', 'part', 'sound', 'shuffl'),
#  ('essenti', 'part', 'sound', 'walk'),
#  ('essenti', 'part', 'blue', 'shuffl'),
#  ('essenti', 'part', 'blue', 'walk'),
#  ('essenti', 'part', 'shuffl', 'walk'),
#  ('essenti', 'sound', 'blue', 'shuffl'),
#  ('essenti', 'sound', 'blue', 'walk'),
#  ('essenti', 'sound', 'shuffl', 'walk'),
#  ('essenti', 'blue', 'shuffl', 'walk'),
#  ('part', 'sound', 'blue', 'shuffl'),
#  ('part', 'sound', 'blue', 'walk'),
#  ('part', 'sound', 'blue', 'bass'),
#  ('part', 'sound', 'shuffl', 'walk'),
#  ('part', 'sound', 'shuffl', 'bass'),
#  ('part', 'sound', 'walk', 'bass'),
#  ('part', 'blue', 'shuffl', 'walk'),
#  ('part', 'blue', 'shuffl', 'bass'),
#  ('part', 'blue', 'walk', 'bass'),
#  ('part', 'shuffl', 'walk', 'bass'),
#  ('sound', 'blue', 'shuffl', 'walk'),
#  ('sound', 'blue', 'shuffl', 'bass'),
#  ('sound', 'blue', 'shuffl', 'reinforc'),
#  ('sound', 'blue', 'walk', 'bass'),
#  ('sound', 'blue', 'walk', 'reinforc'),
#  ('sound', 'blue', 'bass', 'reinforc'),
#  ('sound', 'shuffl', 'walk', 'bass'),
#  ('sound', 'shuffl', 'walk', 'reinforc'),
#  ('sound', 'shuffl', 'bass', 'reinforc'),
#  ('sound', 'walk', 'bass', 'reinforc'),
#  ('blue', 'shuffl', 'walk', 'bass'),
#  ('blue', 'shuffl', 'walk', 'reinforc'),
#  ('blue', 'shuffl', 'walk', 'rhythm'),
#  ('blue', 'shuffl', 'bass', 'reinforc'),
#  ('blue', 'shuffl', 'bass', 'rhythm'),
#  ('blue', 'shuffl', 'reinforc', 'rhythm'),
#  ('blue', 'walk', 'bass', 'reinforc'),
#  ('blue', 'walk', 'bass', 'rhythm'),
#  ('blue', 'walk', 'reinforc', 'rhythm'),
#  ('blue', 'bass', 'reinforc', 'rhythm'),
#  ('shuffl', 'walk', 'bass', 'reinforc'),
#  ('shuffl', 'walk', 'bass', 'rhythm'),
#  ('shuffl', 'walk', 'bass', 'form'),
#  ('shuffl', 'walk', 'reinforc', 'rhythm'),
#  ('shuffl', 'walk', 'reinforc', 'form'),
#  ('shuffl', 'walk', 'rhythm', 'form'),
#  ('shuffl', 'bass', 'reinforc', 'rhythm'),
#  ('shuffl', 'bass', 'reinforc', 'form'),
#  ('shuffl', 'bass', 'rhythm', 'form'),
#  ('shuffl', 'reinforc', 'rhythm', 'form'),
#  ('walk', 'bass', 'reinforc', 'rhythm'),
#  ('walk', 'bass', 'reinforc', 'form'),
#  ('walk', 'bass', 'reinforc', 'repetit'),
#  ('walk', 'bass', 'rhythm', 'form'),
#  ('walk', 'bass', 'rhythm', 'repetit'),
#  ('walk', 'bass', 'form', 'repetit'),
#  ('walk', 'reinforc', 'rhythm', 'form'),
#  ('walk', 'reinforc', 'rhythm', 'repetit'),
#  ('walk', 'reinforc', 'form', 'repetit'),
#  ('walk', 'rhythm', 'form', 'repetit'),
#  ('bass', 'reinforc', 'rhythm', 'form'),
#  ('bass', 'reinforc', 'rhythm', 'repetit'),
#  ('bass', 'reinforc', 'rhythm', 'effect'),
#  ('bass', 'reinforc', 'form', 'repetit'),
#  ('bass', 'reinforc', 'form', 'effect'),
#  ('bass', 'reinforc', 'repetit', 'effect'),
#  ('bass', 'rhythm', 'form', 'repetit'),
#  ('bass', 'rhythm', 'form', 'effect'),
#  ('bass', 'rhythm', 'repetit', 'effect'),
#  ('bass', 'form', 'repetit', 'effect'),
#  ('reinforc', 'rhythm', 'form', 'repetit'),
#  ('reinforc', 'rhythm', 'form', 'effect'),
#  ('reinforc', 'rhythm', 'form', 'known'),
#  ('reinforc', 'rhythm', 'repetit', 'effect'),
#  ('reinforc', 'rhythm', 'repetit', 'known'),
#  ('reinforc', 'rhythm', 'effect', 'known'),
#  ('reinforc', 'form', 'repetit', 'effect'),
#  ('reinforc', 'form', 'repetit', 'known'),
#  ('reinforc', 'form', 'effect', 'known'),
#  ('reinforc', 'repetit', 'effect', 'known'),
#  ('rhythm', 'form', 'repetit', 'effect'),
#  ('rhythm', 'form', 'repetit', 'known'),
#  ('rhythm', 'form', 'repetit', 'groov'),
#  ('rhythm', 'form', 'effect', 'known'),
#  ('rhythm', 'form', 'effect', 'groov'),
#  ('rhythm', 'form', 'known', 'groov'),
#  ('rhythm', 'repetit', 'effect', 'known'),
#  ('rhythm', 'repetit', 'effect', 'groov'),
#  ('rhythm', 'repetit', 'known', 'groov'),
#  ('rhythm', 'effect', 'known', 'groov'),
#  ('form', 'repetit', 'effect', 'known'),
#  ('form', 'repetit', 'effect', 'groov'),
#  ('form', 'repetit', 'effect', 'blue'),
#  ('form', 'repetit', 'known', 'groov'),
#  ('form', 'repetit', 'known', 'blue'),
#  ('form', 'repetit', 'groov', 'blue'),
#  ('form', 'effect', 'known', 'groov'),
#  ('form', 'effect', 'known', 'blue'),
#  ('form', 'effect', 'groov', 'blue'),
#  ('form', 'known', 'groov', 'blue'),
#  ('repetit', 'effect', 'known', 'groov'),
#  ('repetit', 'effect', 'known', 'blue'),
#  ('repetit', 'effect', 'known', 'genr'),
#  ('repetit', 'effect', 'groov', 'blue'),
#  ('repetit', 'effect', 'groov', 'genr'),
#  ('repetit', 'effect', 'blue', 'genr'),
#  ('repetit', 'known', 'groov', 'blue'),
#  ('repetit', 'known', 'groov', 'genr'),
#  ('repetit', 'known', 'blue', 'genr'),
#  ('repetit', 'groov', 'blue', 'genr'),
#  ('effect', 'known', 'groov', 'blue'),
#  ('effect', 'known', 'groov', 'genr'),
#  ('effect', 'known', 'groov', 'also'),
#  ('effect', 'known', 'blue', 'genr'),
#  ('effect', 'known', 'blue', 'also'),
#  ('effect', 'known', 'genr', 'also'),
#  ('effect', 'groov', 'blue', 'genr'),
#  ('effect', 'groov', 'blue', 'also'),
#  ('effect', 'groov', 'genr', 'also'),
#  ('effect', 'blue', 'genr', 'also'),
#  ('known', 'groov', 'blue', 'genr'),
#  ('known', 'groov', 'blue', 'also'),
#  ('known', 'groov', 'blue', 'character'),
#  ('known', 'groov', 'genr', 'also'),
#  ('known', 'groov', 'genr', 'character'),
#  ('known', 'groov', 'also', 'character'),
#  ('known', 'blue', 'genr', 'also'),
#  ('known', 'blue', 'genr', 'character'),
#  ('known', 'blue', 'also', 'character'),
#  ('known', 'genr', 'also', 'character'),
#  ('groov', 'blue', 'genr', 'also'),
#  ('groov', 'blue', 'genr', 'character'),
#  ('groov', 'blue', 'genr', 'lyric'),
#  ('groov', 'blue', 'also', 'character'),
#  ('groov', 'blue', 'also', 'lyric'),
#  ('groov', 'blue', 'character', 'lyric'),
#  ('groov', 'genr', 'also', 'character'),
#  ('groov', 'genr', 'also', 'lyric'),
#  ('groov', 'genr', 'character', 'lyric'),
#  ('groov', 'also', 'character', 'lyric'),
#  ('blue', 'genr', 'also', 'character'),
#  ('blue', 'genr', 'also', 'lyric'),
#  ('blue', 'genr', 'also', 'bass'),
#  ('blue', 'genr', 'character', 'lyric'),
#  ('blue', 'genr', 'character', 'bass'),
#  ('blue', 'genr', 'lyric', 'bass'),
#  ('blue', 'also', 'character', 'lyric'),
#  ('blue', 'also', 'character', 'bass'),
#  ('blue', 'also', 'lyric', 'bass'),
#  ('blue', 'character', 'lyric', 'bass'),
#  ('genr', 'also', 'character', 'lyric'),
#  ('genr', 'also', 'character', 'bass'),
#  ('genr', 'also', 'character', 'line'),
#  ('genr', 'also', 'lyric', 'bass'),
#  ('genr', 'also', 'lyric', 'line'),
#  ('genr', 'also', 'bass', 'line'),
#  ('genr', 'character', 'lyric', 'bass'),
#  ('genr', 'character', 'lyric', 'line'),
#  ('genr', 'character', 'bass', 'line'),
#  ('genr', 'lyric', 'bass', 'line'),
#  ('also', 'character', 'lyric', 'bass'),
#  ('also', 'character', 'lyric', 'line'),
#  ('also', 'character', 'lyric', 'instrument'),
#  ('also', 'character', 'bass', 'line'),
#  ('also', 'character', 'bass', 'instrument'),
#  ('also', 'character', 'line', 'instrument'),
#  ('also', 'lyric', 'bass', 'line'),
#  ('also', 'lyric', 'bass', 'instrument'),
#  ('also', 'lyric', 'line', 'instrument'),
#  ('also', 'bass', 'line', 'instrument'),
#  ('character', 'lyric', 'bass', 'line'),
#  ('character', 'lyric', 'bass', 'instrument'),
#  ('character', 'lyric', 'bass', 'earli'),
#  ('character', 'lyric', 'line', 'instrument'),
#  ('character', 'lyric', 'line', 'earli'),
#  ('character', 'lyric', 'instrument', 'earli'),
#  ('character', 'bass', 'line', 'instrument'),
#  ('character', 'bass', 'line', 'earli'),
#  ('character', 'bass', 'instrument', 'earli'),
#  ('character', 'line', 'instrument', 'earli'),
#  ('lyric', 'bass', 'line', 'instrument'),
#  ('lyric', 'bass', 'line', 'earli'),
#  ('lyric', 'bass', 'line', 'tradit'),
#  ('lyric', 'bass', 'instrument', 'earli'),
#  ('lyric', 'bass', 'instrument', 'tradit'),
#  ('lyric', 'bass', 'earli', 'tradit'),
#  ('lyric', 'line', 'instrument', 'earli'),
#  ('lyric', 'line', 'instrument', 'tradit'),
#  ('lyric', 'line', 'earli', 'tradit'),
#  ('lyric', 'instrument', 'earli', 'tradit'),
#  ('bass', 'line', 'instrument', 'earli'),
#  ('bass', 'line', 'instrument', 'tradit'),
#  ('bass', 'line', 'instrument', 'blue'),
#  ('bass', 'line', 'earli', 'tradit'),
#  ('bass', 'line', 'earli', 'blue'),
#  ('bass', 'line', 'tradit', 'blue'),
#  ('bass', 'instrument', 'earli', 'tradit'),
#  ('bass', 'instrument', 'earli', 'blue'),
#  ('bass', 'instrument', 'tradit', 'blue'),
#  ('bass', 'earli', 'tradit', 'blue'),
#  ('line', 'instrument', 'earli', 'tradit'),
#  ('line', 'instrument', 'earli', 'blue'),
#  ('line', 'instrument', 'earli', 'vers'),
#  ('line', 'instrument', 'tradit', 'blue'),
#  ('line', 'instrument', 'tradit', 'vers'),
#  ('line', 'instrument', 'blue', 'vers'),
#  ('line', 'earli', 'tradit', 'blue'),
#  ('line', 'earli', 'tradit', 'vers'),
#  ('line', 'earli', 'blue', 'vers'),
#  ('line', 'tradit', 'blue', 'vers'),
#  ('instrument', 'earli', 'tradit', 'blue'),
#  ('instrument', 'earli', 'tradit', 'vers'),
#  ('instrument', 'earli', 'tradit', 'consist'),
#  ('instrument', 'earli', 'blue', 'vers'),
#  ('instrument', 'earli', 'blue', 'consist'),
#  ('instrument', 'earli', 'vers', 'consist'),
#  ('instrument', 'tradit', 'blue', 'vers'),
#  ('instrument', 'tradit', 'blue', 'consist'),
#  ('instrument', 'tradit', 'vers', 'consist'),
#  ('instrument', 'blue', 'vers', 'consist'),
#  ('earli', 'tradit', 'blue', 'vers'),
#  ('earli', 'tradit', 'blue', 'consist'),
#  ('earli', 'tradit', 'blue', 'singl'),
#  ('earli', 'tradit', 'vers', 'consist'),
#  ('earli', 'tradit', 'vers', 'singl'),
#  ('earli', 'tradit', 'consist', 'singl'),
#  ('earli', 'blue', 'vers', 'consist'),
#  ('earli', 'blue', 'vers', 'singl'),
#  ('earli', 'blue', 'consist', 'singl'),
#  ('earli', 'vers', 'consist', 'singl'),
#  ('tradit', 'blue', 'vers', 'consist'),
#  ('tradit', 'blue', 'vers', 'singl'),
#  ('tradit', 'blue', 'vers', 'line'),
#  ('tradit', 'blue', 'consist', 'singl'),
#  ('tradit', 'blue', 'consist', 'line'),
#  ('tradit', 'blue', 'singl', 'line'),
#  ('tradit', 'vers', 'consist', 'singl'),
#  ('tradit', 'vers', 'consist', 'line'),
#  ('tradit', 'vers', 'singl', 'line'),
#  ('tradit', 'consist', 'singl', 'line'),
#  ('blue', 'vers', 'consist', 'singl'),
#  ('blue', 'vers', 'consist', 'line'),
#  ('blue', 'vers', 'consist', 'repeat'),
#  ('blue', 'vers', 'singl', 'line'),
#  ('blue', 'vers', 'singl', 'repeat'),
#  ('blue', 'vers', 'line', 'repeat'),
#  ('blue', 'consist', 'singl', 'line'),
#  ('blue', 'consist', 'singl', 'repeat'),
#  ('blue', 'consist', 'line', 'repeat'),
#  ('blue', 'singl', 'line', 'repeat'),
#  ('vers', 'consist', 'singl', 'line'),
#  ('vers', 'consist', 'singl', 'repeat'),
#  ('vers', 'consist', 'singl', 'four'),
#  ('vers', 'consist', 'line', 'repeat'),
#  ('vers', 'consist', 'line', 'four'),
#  ('vers', 'consist', 'repeat', 'four'),
#  ('vers', 'singl', 'line', 'repeat'),
#  ('vers', 'singl', 'line', 'four'),
#  ('vers', 'singl', 'repeat', 'four'),
#  ('vers', 'line', 'repeat', 'four'),
#  ('consist', 'singl', 'line', 'repeat'),
#  ('consist', 'singl', 'line', 'four'),
#  ('consist', 'singl', 'line', 'time'),
#  ('consist', 'singl', 'repeat', 'four'),
#  ('consist', 'singl', 'repeat', 'time'),
#  ('consist', 'singl', 'four', 'time'),
#  ('consist', 'line', 'repeat', 'four'),
#  ('consist', 'line', 'repeat', 'time'),
#  ('consist', 'line', 'four', 'time'),
#  ('consist', 'repeat', 'four', 'time'),
#  ('singl', 'line', 'repeat', 'four'),
#  ('singl', 'line', 'repeat', 'time'),
#  ('singl', 'line', 'repeat', 'wa'),
#  ('singl', 'line', 'four', 'time'),
#  ('singl', 'line', 'four', 'wa'),
#  ('singl', 'line', 'time', 'wa'),
#  ('singl', 'repeat', 'four', 'time'),
#  ('singl', 'repeat', 'four', 'wa'),
#  ('singl', 'repeat', 'time', 'wa'),
#  ('singl', 'four', 'time', 'wa'),
#  ('line', 'repeat', 'four', 'time'),
#  ('line', 'repeat', 'four', 'wa'),
#  ('line', 'repeat', 'four', 'onli'),
#  ('line', 'repeat', 'time', 'wa'),
#  ('line', 'repeat', 'time', 'onli'),
#  ('line', 'repeat', 'wa', 'onli'),
#  ('line', 'four', 'time', 'wa'),
#  ('line', 'four', 'time', 'onli'),
#  ('line', 'four', 'wa', 'onli'),
#  ('line', 'time', 'wa', 'onli'),
#  ('repeat', 'four', 'time', 'wa'),
#  ('repeat', 'four', 'time', 'onli'),
#  ('repeat', 'four', 'time', 'first'),
#  ('repeat', 'four', 'wa', 'onli'),
#  ('repeat', 'four', 'wa', 'first'),
#  ('repeat', 'four', 'onli', 'first'),
#  ('repeat', 'time', 'wa', 'onli'),
#  ('repeat', 'time', 'wa', 'first'),
#  ('repeat', 'time', 'onli', 'first'),
#  ('repeat', 'wa', 'onli', 'first'),
#  ...]

# %% [markdown]
# # Distributional distances
#
# If we want to compare different corpora, we need a distance or divergence that compares the two distributions.
#
# We will use the:
#
# + Kullback-Leibler (KL) divergence
# + $\chi^2$ divergence
# + Kolmogorov-Smirnov (KS) distance
# + Wasserstein distance
#
# ### Kullback-Leibler and $x^2$ divergences ###
#
# KL and $\chi^2$ divergences are members of the broader <a "href=https://en.wikipedia.org/wiki/F-divergence" target="_blank">$f$-divergence</a> family, a function of $D_f (P || Q)$ that calculates the difference between two probability distributions P and Q. The KL $f(t)$ is $ t \text{ log } t $, while the $\chi^2$ is $t^2-1$. KL comes from information and $\chi^2$ from measure theory. As such, the KL divergence computes the relative entropy between two distributions--how they differ in bits, while the $\chi^2$ whether the same statistical inferences can be drawn from them both.
#
# Specifically, given two discrete probability distributions $P$ and $Q$, the Kullback-Leibler divergence from $Q$ to $P$ is defined as:
#
# $D_{\mathrm{KL}}(P\|Q) = \sum_i P(i) \, \log\frac{P(i)}{Q(i)}$.
#
# The [scipy.stats.entropy()](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.entropy.html) function does the calculation for you, which takes in two arrays of probabilities and computes the KL divergence. Note that the KL divergence is in general not commutative, i.e. $D_{\mathrm{KL}}(P\|Q) \neq D_{\mathrm{KL}}(Q\|P)$ .
#
# Also note that the KL divernce is the sum of elementwise divergences. Scipy provides [scipy.special.kl_div()](https://docs.scipy.org/doc/scipy/reference/generated/scipy.special.kl_div.html#scipy-special-kl-div) which calculates elementwise divergences for you.
#
# The $\chi^2$ Divergence is defined as:
#
# $D_{\mathrm{\chi^2}}(P\|Q) = \sum_i \left(\frac{P(i)}{Q(i)}-1\right)^2$.
#
# This is also noncommutative, and the code can be drawn directly from scipy.
#
# ### Kolmogorov-Smirnov ###
#
# The two-sample Kolmogovorov-Smirnov test statistic calculates the distance between the cumulative distribution function of the two distributions to be compared, and, along with the $x^2$ divergence, is among the most common approaches two calculating a distance in statistics. It can be interpreted as a test of whether two distributions are drawn from the same underlying distribution. As with the others, the code is readily available in scipy.
#
# ### Wasserstein Distance ###
#
# When this is computed on a Euclidian metric structure (e.g., numbers of words), this is also known as the earth mover’s distance, because it can be seen as the minimum amount of "work" required to transform $P$ into $Q$, where "work" is measured as the amount of distribution weight that must be moved, multiplied by the distance it has to be moved.
#
# ### Computing ###
#
# To do this we will need to create the arrays, lets compare the Whitehouse releases with the Kennedy releases. First we have to download them and load them into a DataFrame.

# %%
kenReleases = getGithubFiles('https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Kennedy', maxFiles = 10)
kenReleases[:5]
# Out:
#                                         download_url  \
# 0  https://raw.githubusercontent.com/lintool/Grim...
# 1  https://raw.githubusercontent.com/lintool/Grim...
# 2  https://raw.githubusercontent.com/lintool/Grim...
# 3  https://raw.githubusercontent.com/lintool/Grim...
# 4  https://raw.githubusercontent.com/lintool/Grim...
#
#                                             html_url                    name  \
# 0  https://github.com/lintool/GrimmerSenatePressR...  01Apr2005Kennedy14.txt
# 1  https://github.com/lintool/GrimmerSenatePressR...  01Aug2005Kennedy12.txt
# 2  https://github.com/lintool/GrimmerSenatePressR...  01Aug2006Kennedy10.txt
# 3  https://github.com/lintool/GrimmerSenatePressR...  01Aug2006Kennedy11.txt
# 4  https://github.com/lintool/GrimmerSenatePressR...  01Aug2006Kennedy12.txt
#
#                                  path  \
# 0  raw/Kennedy/01Apr2005Kennedy14.txt
# 1  raw/Kennedy/01Aug2005Kennedy12.txt
# 2  raw/Kennedy/01Aug2006Kennedy10.txt
# 3  raw/Kennedy/01Aug2006Kennedy11.txt
# 4  raw/Kennedy/01Aug2006Kennedy12.txt
#
#                                                 text
# 0           FOR IMMEDIATE RELEASE   FOR IMMEDIATE...
# 1           FOR IMMEDIATE RELEASE   FOR IMMEDIATE...
# 2           FOR IMMEDIATE RELEASE  FOR IMMEDIATE ...
# 3           FOR IMMEDIATE RELEASE  FOR IMMEDIATE ...
# 4           FOR IMMEDIATE RELEASE  FOR IMMEDIATE ...

# %% [markdown]
# Then we can tokenize, stem and remove stop words, like we did for the Whitehouse press releases

# %%
kenReleases['tokenized_text'] = kenReleases['text'].apply(lambda x: nltk.word_tokenize(x))
kenReleases['normalized_tokens'] = kenReleases['tokenized_text'].apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, stemmer = snowball))

# %% [markdown]
# Now we need to compare the two collection of words, remove those not found in both, and assign the remaining ones indices.

# %%
whWords = set(whReleases['normalized_tokens'].sum())
kenWords = set(kenReleases['normalized_tokens'].sum())

#Change & to | if you want to keep all words
overlapWords = whWords & kenWords

overlapWordsDict = {word: index for index, word in enumerate(overlapWords)}
overlapWordsDict['student']
# Out:
# 29

# %% [markdown]
# Now we can count the occurrences of each word in the corpora and create our arrays. Note that we don't have to use numpy arrays as we do here. We could just use a list, but the arrays are faster in numpy so we encourage you to get in the habit of using them.

# %%
def makeProbsArray(dfColumn, overlapDict):
    words = dfColumn.sum()
    countList = [0] * len(overlapDict)
    for word in words:
        try:
            countList[overlapDict[word]] += 1
        except KeyError:
            #The word is not common so we skip it
            pass
    countArray = np.array(countList)
    return countArray / countArray.sum()

whProbArray = makeProbsArray(whReleases['normalized_tokens'], overlapWordsDict)
kenProbArray = makeProbsArray(kenReleases['normalized_tokens'], overlapWordsDict)
kenProbArray.sum()
#There is a little bit of a floating point math error
#but it's too small to see with print and too small matter here
# Out:
# 1.0

# %% [markdown]
# We can now compute the KL divergence. Pay attention to the asymmetry. Use [the Jensen–Shannon divergence](https://en.wikipedia.org/wiki/Jensen%E2%80%93Shannon_divergence), which is the average KL divergence between each distribution and the average of both distributions (i.e., the midpoint), if you want symmetry.

# %%
wh_kenDivergence = scipy.stats.entropy(whProbArray, kenProbArray)
print (wh_kenDivergence)
ken_whDivergence = scipy.stats.entropy(kenProbArray, whProbArray)
print (ken_whDivergence)
# Out:
# 0.6176419677476952
# 0.5877085657188859

# %% [markdown]
# Then, we can do the elementwise calculation and see which words best distinguish the two corpora.

# %%
wh_kenDivergence_ew = scipy.special.kl_div(whProbArray, kenProbArray)
kl_df = pandas.DataFrame(list(overlapWordsDict.keys()), columns = ['word'], index = list(overlapWordsDict.values()))
kl_df = kl_df.sort_index()
kl_df['elementwise divergence'] = wh_kenDivergence_ew
kl_df[:10]
# Out:
#        word  elementwise divergence
# 0   serious                0.001568
# 1       act                0.001255
# 2      join                0.000063
# 3    requir                0.002662
# 4     white                0.000048
# 5   account                0.000305
# 6   countri                0.009469
# 7     limit                0.002023
# 8  challeng                0.002023
# 9     seven                0.000672

# %%
kl_df.sort_values(by='elementwise divergence', ascending=False)[:10]
# Out:
#          word  elementwise divergence
# 33       iraq                0.086929
# 148      bush                0.042354
# 180      stem                0.021884
# 104       law                0.020547
# 164   protect                0.019358
# 139  american                0.018154
# 38     depart                0.017650
# 25      bring                0.014128
# 128    member                0.012429
# 142       war                0.011739

# %% [markdown]
# Now we will apply what we learned today to the Guternberg texts in nltk and see if we can detect patterns between them.
#
# First, let's transform every text into normalized tokens. Note that in this first step, no stopword is removed.

# %%
fileids = nltk.corpus.gutenberg.fileids()
corpora = []
for fileid in fileids:
    words = nltk.corpus.gutenberg.words(fileid)
    normalized_tokens = normlizeTokens(words, stopwordLst = [], stemmer = snowball)
    corpora.append(normalized_tokens)

# %% [markdown]
# Then, let's separate the normalized tokens into stopwords and non-stopwords.

# %%
corpora_s = []
corpora_nons = []
for corpus in corpora:
    s = []
    nons = []
    for word in corpus:
        if word in stop_words_nltk:
            s.append(word)
        else:
            nons.append(word)
    corpora_s.append(s)
    corpora_nons.append(nons)

# %% [markdown]
# Define some covenient funtions for calculating divergence and distances.

# %%
def kl_divergence(X, Y):
    P = X.copy()
    Q = Y.copy()
    P.columns = ['P']
    Q.columns = ['Q']
    df = Q.join(P).fillna(0)
    p = df.iloc[:,1]
    q = df.iloc[:,0]
    D_kl = scipy.stats.entropy(p, q)
    return D_kl

def chi2_divergence(X,Y):
    P = X.copy()
    Q = Y.copy()
    P.columns = ['P']
    Q.columns = ['Q']
    df = Q.join(P).fillna(0)
    p = df.iloc[:,1]
    q = df.iloc[:,0]
    return scipy.stats.chisquare(p, q).statistic

def Divergence(corpus1, corpus2, difference="KL"):
    """Difference parameter can equal KL, Chi2, or Wass"""
    freqP = nltk.FreqDist(corpus1)
    P = pandas.DataFrame(list(freqP.values()), columns = ['frequency'], index = list(freqP.keys()))
    freqQ = nltk.FreqDist(corpus2)
    Q = pandas.DataFrame(list(freqQ.values()), columns = ['frequency'], index = list(freqQ.keys()))
    if difference == "KL":
        return kl_divergence(P, Q)
    elif difference == "Chi2":
        return chi2_divergence(P, Q)
    elif difference == "KS":
        try:
            return scipy.stats.ks_2samp(P['frequency'], Q['frequency']).statistic
        except:
            return scipy.stats.ks_2samp(P['frequency'], Q['frequency'])
    elif difference == "Wasserstein":
        try:
            return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None).statistic
        except:
            return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None)

# %% [markdown]
# Now we will calculate the KL divergence for each pair of corpora, turn the results into a matrix, and visualize the matrix as a heatmap. Recall that $D_{\mathrm{KL}}(P\|Q)$ measures the amount of information loss when $Q$ is used to approximate $P$. Here, the rows are the $P$s used for calculating KL divergences, and the columns are the $Q$s. So, each cell measures the amount of information loss when the word distribution of the column text is used to approximate the word distribution of the row text. Because the KL divergence is directional, such that the divergence of $P$ from $Q$ is different from the same of $Q$ from $P$, the matrix is assymetric and contains unique information above and below the diagonal. The same is true for the $\chi^2$ divergence.

# %%
L = []
for p in corpora:
    l = []
    for q in corpora:
        l.append(Divergence(p,q, difference = 'KL'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# Note that works by the same author have the lowest within-group KL divergences.
#
# To reveal more patterns, let's do a multidimensional scaling of the matrix.

# %%
mds = sklearn.manifold.MDS()
pos = mds.fit(M).embedding_
x = pos[:,0]
y = pos[:,1]
fig, ax = plt.subplots(figsize = (6,6))
plt.plot(x, y, ' ')
for i, txt in enumerate(fileids):
    ax.annotate(txt, (x[i],y[i]))
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/manifold/mds.py:411: UserWarning: The MDS API has changed. ``fit`` now constructs an dissimilarity matrix from data. To use a custom dissimilarity matrix, set ``dissimilarity='precomputed'``.
#   warnings.warn("The MDS API has changed. ``fit`` now constructs an"

# %% [markdown]
# Do you see any patterns in the image shown above? Does it make sense?
#
# We may just want to focus on the distrbution of stopwords or non-stopwords. Let's do the analysis again first for stopwords and then for non-stopwords.

# %%
L = []
for p in corpora_s:
    l = []
    for q in corpora_s:
        l.append(Divergence(p,q, difference='KL'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %%
L = []
for p in corpora_nons:
    l = []
    for q in corpora_nons:
        l.append(Divergence(p,q, difference='KL'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# Now we compute the same for the assymmetric $\chi^2$ Divergence.

# %%
L = []
for p in corpora_nons:
    l = []
    for q in corpora_nons:
        l.append(Divergence(p,q, difference='Chi2'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# For the KS distance:

# %%
L = []
for p in corpora_nons:
    l = []
    for q in corpora_nons:
        l.append(Divergence(p,q, difference='KS'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# And finally for the Wasserstein or "earth mover's" Distance.

# %%
L = []
for p in corpora_nons:
    l = []
    for q in corpora_nons:
        l.append(Divergence(p,q, difference='Wasserstein'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# You can see that the Bible is highly divergent and this makes reading the plot somewhat difficult. Let's fix this by taking the log of each cell, which will reduce the distance of the Bible from other texts as an outlier.

# %%
ax = sns.heatmap(div.apply(np.log).replace([np.inf, -np.inf], np.nan))
plt.show()

# %% [markdown]
# This is more legible, as it continues to show that the Bible is divergent, but other structure is also visible, such as the divergence of Austen's *Emma* and *Sense and Sensibility*, and Edgeworth's *The Parent's Assistant*.
#
# If we want to rerun this on a new data set of our own composition, we can be a bit more efficient with our coding. Let's use the Shakespeare texts from last week as example:

# %%
shakespeare_df = lucem_illud.loadTextDirectory('../data/Shakespeare')

# %% [markdown]
# Now we stem and remove stopwords

# %%
shakespeare_df['tokenized_text'] = shakespeare_df['text'].apply(lambda x: nltk.word_tokenize(x))
shakespeare_df['normalized_tokens'] = shakespeare_df['tokenized_text'].apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, stemmer = porter))

# %% [markdown]
# Create the corpus file and generate the heatmap:

# %%
measure = 'KS' #"KL", "Chi2", "KS", "Wasserstein"
num_of_texts = 10 #The bigger this number the slower it will run, you can also try selecting your own plays
fileids_sp = list(shakespeare_df[:num_of_texts].index)
corpora_sp = list(shakespeare_df[:num_of_texts]['normalized_tokens'])
L = []
for p in corpora_sp:
    l = []
    for q in corpora_sp:
        l.append(Divergence(p,q, difference=measure))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids_sp, index = fileids_sp)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# What are "The Passionate Pilgrim" and "The Phoenix and the Turtle"? Little known poems by Shakespeare that are unsurprisingly hard to classify, as they are so different from everything else he wrote.

# %% [markdown]
# ## <span style="color:red">*Exercise 4*</span>
#
# <span style="color:red">Construct cells immediately below this that calculate the KL and $\chi^2$ divergences, and the KS and Wasserstein distances between four separate corpora, plot these with heatmaps, and then array them in two dimensions with multidimensional scaling as above. What does this reveal about relations between the corpora? Which analysis (and divergence or distribution) distinguishes the authors or documents better?
#
# <span style="color:red">**Stretch**: Calculate the <a "href=https://en.wikipedia.org/wiki/Jensen–Shannon_divergence" target="_blank">Jensen-Shannon Divergence</a> between your four corpora. What is the relationship between the KL and JS divergences?</span>

# %%
# In this part, I would treat each Wikipedia page of a music type as a corpora.
# Since I've already downloaded and read those into memory, I would directly
# use them in this part. 
blues_normalized = music_df['normalized_tokens'].iloc[0]
house_normalized = music_df['normalized_tokens'].iloc[1]
gospel_normalized = music_df['normalized_tokens'].iloc[2]
hiphop_normalized = music_df['normalized_tokens'].iloc[3]

# %%
music_corpora = [blues_normalized, house_normalized, gospel_normalized, hiphop_normalized]

# %%
music_types = ['Blues Music', 'House Music', 'Gospel Music', 'Hip Hop Music']

L = []
for p in music_corpora:
    l = []
    for q in music_corpora:
        l.append(Divergence(p,q, difference = 'KL'))
    L.append(l)
M = np.array(L)
print('The matrix with KL is:')
print(M)
fig = plt.figure()
div = pandas.DataFrame(M, columns = music_types, index = music_types)
ax = sns.heatmap(div)
plt.title('Figure: Heatmap with KL')
plt.show()
# Out:
# The matrix with KL is:
# [[0.         1.54432741 1.07112473 1.50346137]
#  [1.47770379 0.         1.41750317 1.1291098 ]
#  [1.35343052 1.53328217 0.         1.84667238]
#  [1.36896353 0.99660458 0.92715924 0.        ]]

# %%
mds = sklearn.manifold.MDS()
pos = mds.fit(M).embedding_
x = pos[:,0]
y = pos[:,1]
fig, ax = plt.subplots(figsize = (6,6))
plt.plot(x, y, ' ')
plt.title('Figure: Multidimensional Scaling with KL')
for i, txt in enumerate(music_types):
    ax.annotate(txt, (x[i],y[i]))
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/manifold/mds.py:411: UserWarning: The MDS API has changed. ``fit`` now constructs an dissimilarity matrix from data. To use a custom dissimilarity matrix, set ``dissimilarity='precomputed'``.
#   warnings.warn("The MDS API has changed. ``fit`` now constructs an"

# %%
L = []
for p in music_corpora:
    l = []
    for q in music_corpora:
        l.append(Divergence(p,q, difference = 'Chi2'))
    L.append(l)
M = np.array(L)
print('The matrix with Chi-square is:')
print(M)
fig = plt.figure()
div = pandas.DataFrame(M, columns = music_types, index = music_types)
ax = sns.heatmap(div)
plt.title('Figure: Heatmap with Chi-square')
plt.show()
# Out:
# The matrix with Chi-square is:
# [[     0.         127277.62187686  38525.43700991 127564.85936786]
#  [ 27752.59129835      0.          20674.51608305  11308.31873742]
#  [  4720.30581293   3624.08910517      0.          13769.83407969]
#  [150331.29565635  54029.68035948  20707.51958549      0.        ]]

# %%
pos = mds.fit(M).embedding_
x = pos[:,0]
y = pos[:,1]
fig, ax = plt.subplots(figsize = (6,6))
plt.plot(x, y, ' ')
plt.title('Figure: Multidimensional Scaling with Chi-square')
for i, txt in enumerate(music_types):
    ax.annotate(txt, (x[i],y[i]))
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/manifold/mds.py:411: UserWarning: The MDS API has changed. ``fit`` now constructs an dissimilarity matrix from data. To use a custom dissimilarity matrix, set ``dissimilarity='precomputed'``.
#   warnings.warn("The MDS API has changed. ``fit`` now constructs an"

# %%
L = []
for p in music_corpora:
    l = []
    for q in music_corpora:
        l.append(Divergence(p,q, difference = 'KS'))
    L.append(l)
print('The matrix with KS is:')
print(M)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = music_types, index = music_types)
ax = sns.heatmap(div)
plt.title('Figure: Heatmap with KS')
plt.show()
# Out:
# The matrix with KS is:
# [[     0.         127277.62187686  38525.43700991 127564.85936786]
#  [ 27752.59129835      0.          20674.51608305  11308.31873742]
#  [  4720.30581293   3624.08910517      0.          13769.83407969]
#  [150331.29565635  54029.68035948  20707.51958549      0.        ]]

# %%
pos = mds.fit(M).embedding_
x = pos[:,0]
y = pos[:,1]
fig, ax = plt.subplots(figsize = (6,6))
plt.plot(x, y, ' ')
plt.title('Figure: Multidimensional Scaling with KS')
for i, txt in enumerate(music_types):
    ax.annotate(txt, (x[i],y[i]))
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/manifold/mds.py:411: UserWarning: The MDS API has changed. ``fit`` now constructs an dissimilarity matrix from data. To use a custom dissimilarity matrix, set ``dissimilarity='precomputed'``.
#   warnings.warn("The MDS API has changed. ``fit`` now constructs an"

# %%
L = []
for p in music_corpora:
    l = []
    for q in music_corpora:
        l.append(Divergence(p,q, difference = 'Wasserstein'))
    L.append(l)
print('The matrix with Wasserstein distance is:')
print(M)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = music_types, index = music_types)
ax = sns.heatmap(div)
plt.title('Figure: Heatmap with Wasserstein Distance')
plt.show()
# Out:
# The matrix with Wasserstein distance is:
# [[0.         0.02722606 0.05229323 0.03574744]
#  [0.02722606 0.         0.04482624 0.06297349]
#  [0.05229323 0.04482624 0.         0.08656423]
#  [0.03574744 0.06297349 0.08656423 0.        ]]

# %%
pos = mds.fit(M).embedding_
x = pos[:,0]
y = pos[:,1]
fig, ax = plt.subplots(figsize = (6,6))
plt.plot(x, y, ' ')
plt.title('Figure: Multidimensional Scaling with Wasserstein Distance')
for i, txt in enumerate(music_types):
    ax.annotate(txt, (x[i],y[i]))
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/manifold/mds.py:411: UserWarning: The MDS API has changed. ``fit`` now constructs an dissimilarity matrix from data. To use a custom dissimilarity matrix, set ``dissimilarity='precomputed'``.
#   warnings.warn("The MDS API has changed. ``fit`` now constructs an"

# %%
# Define the function to calculate the Jensen-Shannon Divergence
import numpy as np

def get_JSD(X, Y):
    """Compute the Jensen-Shannon divergence between two probability distributions.

    Input
    -----
    P, Q : array-like
        Probability distributions of equal length that sum to 1
    """

    def _kldiv(A, B):
        return np.sum([v for v in A * np.log2(A/B) if not np.isnan(v)])

    P = X.copy()
    Q = Y.copy()
    P.columns = ['P']
    Q.columns = ['Q']
    df = Q.join(P).fillna(0)
    p = df.iloc[:,1]
    q = df.iloc[:,0]
    #P = np.array(P)
    #Q = np.array(Q)

    M = 0.5 * (p + q)

    return 0.5 * (_kldiv(p, M) +_kldiv(q, M))

# %%
# Redifined the function to get the divergence
def Divergence(corpus1, corpus2, difference="KL"):
    """Difference parameter can equal KL, Chi2, or Wass"""
    freqP = nltk.FreqDist(corpus1)
    P = pandas.DataFrame(list(freqP.values()), columns = ['frequency'], index = list(freqP.keys()))
    freqQ = nltk.FreqDist(corpus2)
    Q = pandas.DataFrame(list(freqQ.values()), columns = ['frequency'], index = list(freqQ.keys()))
    if difference == "KL":
        return kl_divergence(P, Q)
    elif difference == "Chi2":
        return chi2_divergence(P, Q)
    elif difference == "KS":
        try:
            return scipy.stats.ks_2samp(P['frequency'], Q['frequency']).statistic
        except:
            return scipy.stats.ks_2samp(P['frequency'], Q['frequency'])
    elif difference == "Wasserstein":
        try:
            return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None).statistic
        except:
            return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None)
    elif difference == "JSD":
        return get_JSD(P, Q)

# %%
L = []
for p in music_corpora:
    l = []
    for q in music_corpora:
        l.append(Divergence(p,q, difference = 'JSD'))
    L.append(l)
print('The matrix with Jensen-Shannon Divergence is:')
print(M)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = music_types, index = music_types)
ax = sns.heatmap(div)
plt.title('Figure: Heatmap with Jensen-Shannon Divergence')
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in log2
# The matrix with Jensen-Shannon Divergence is:
# [[0.         0.31546746 0.82063485 0.69887954]
#  [0.31546746 0.         0.74534658 0.65335834]
#  [0.82063485 0.74534658 0.         1.35882128]
#  [0.69887954 0.65335834 1.35882128 0.        ]]

# %%
pos = mds.fit(M).embedding_
x = pos[:,0]
y = pos[:,1]
fig, ax = plt.subplots(figsize = (6,6))
plt.plot(x, y, ' ')
plt.title('Figure: Multidimensional Scaling with Jensen–Shannon Divergence')
for i, txt in enumerate(music_types):
    ax.annotate(txt, (x[i],y[i]))
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/manifold/mds.py:411: UserWarning: The MDS API has changed. ``fit`` now constructs an dissimilarity matrix from data. To use a custom dissimilarity matrix, set ``dissimilarity='precomputed'``.
#   warnings.warn("The MDS API has changed. ``fit`` now constructs an"

# %% [markdown]
# The heat maps above shows that the distance among these four seperate corporas are unstable. We need to be very careful when choosing among the methods above.
